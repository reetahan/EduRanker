# %% [markdown]
# # Main Document to Load and Traverse Data
#
# > Expected Data: school admissions preferences, number of students admitted per attribute category, etc.

# %%
import pandas as pd
import numpy as np
import os
import random

import uuid
import editdistance
from difflib import SequenceMatcher

from tqdm import tqdm

cwd = os.getcwd()
testing = False  # ******
# TODO: make 1shot code simulation(#schools, #students) = resulting selection (Note: seats, student # choices, scores, etc. can be assumed)

# %%
# HELPERS:
stoi_limit = 2**32 - 1
def seed_stoi(s):
    """ somewhat janky conversion of string to int for numpy random states 
    (since np.random.seed() cant take a string) """
    res = 1
    for c in s:
        res += abs(ord(c))
        if res > stoi_limit:
            res -= 2*abs(ord(c))
    return res


def match_schools(all_schools, lst, use_edit=False):
    """ matches schools based on edit distance """
    result = []
    for name in lst:
        if use_edit:  # Levenshtein distance metric for matching schools
            dists = [(str(schol), editdistance.eval(name, schol.name)) for schol in all_schools.values()]
            result.append(min(dists, key=lambda x: x[1])[0])
        else:
            dists = [(str(schol), SequenceMatcher(None, name, schol.name).ratio()) for schol in all_schools.values()]
            result.append(max(dists, key=lambda x: x[1])[0])  # add the school with the min edit distance
    return result


def add_fake_gpa(students):
    """ adds a gpa attribute based on the students ELA and Math scores """
    students["fake_gpa"] = students["Math_score"] + students["ELA_score"]
    max_score = max(students["fake_gpa"])
    students["fake_gpa"] = students["fake_gpa"].apply(lambda score: round(4*score/max_score, 2))  # gpa-normalized
    return students

def get_distributions():
    """ returns quantile distribution of gpa based on real data 
    used for seat/screen calculations """
    student_df = pd.read_csv(cwd+"/Data/student_info_with_demographics.csv")
    student_df = add_fake_gpa(student_df)
    
    edopt_dist = [student_df["fake_gpa"].quantile(i/3) for i in range(2, 0, -1)]
    screen_dist = [student_df["fake_gpa"].quantile(i/5) for i in range(4, 0, -1)]
    return edopt_dist, screen_dist
# edopt_dist, screen_dist = get_distributions()
def set_place(x, dist):
    """ returns a number representing which placement of a number x based on a distribution dist """
    for i, num in enumerate(dist):
        if x >= num:
            return i+1
    return len(dist)+1

# distributions according to: https://www.schools.nyc.gov/enrollment/enroll-grade-by-grade/high-school
screen_dist = [94, 89.66, 82.75, 76.33]  # https://www.schools.nyc.gov/enrollment/enroll-grade-by-grade/high-school/screened-admissions
edopt_dist = [88.25, 77.5]  #https://www.schools.nyc.gov/enrollment/enroll-grade-by-grade/high-school/educational-option-ed-opt-admissions-method

print("EDOPT DISTRIBUTION: ", edopt_dist)
print("SCREEN DISTRIBUTION: ", screen_dist)


# USED FOR SEAT/SCREEN CALCULATIONS
seated = lambda x: set_place(x, edopt_dist) 
screened = lambda x: set_place(x, screen_dist)
# Out:
# EDOPT DISTRIBUTION:  [88.25, 77.5]
# SCREEN DISTRIBUTION:  [94, 89.66, 82.75, 76.33]

# %%
# MAIN STRUCTURES
MAX_NUM_SCHOOLS = 12

class Student:
    def __init__(self, seed, lottery="", schools=[], score=-1):
        # necessary info
        self.id = seed
        random.seed(seed) # set the seed
        
        if lottery != "": # signifies that this is a real student whose data we are inputting
            self.name = seed
            self.lottery = lottery
            self.schools = schools
            self.num_schools = len(schools)
            
            self.selection_policy = -1
            self.ranking_policy = -1
        else:
            self.lottery = uuid.UUID(int=random.getrandbits(128), version=4).hex  # note: can do duplicate check if necessary

            seed_nums = random.sample(range(1, 3), 2)  # necessary to get 2 independent numbers
            # integer representation of how likely a student is to select a given school
            self.selection_policy = seed_nums[0]
            # integer representation of how highly a student is to rank a school, given they've already selected it
            self.ranking_policy = seed_nums[1]

            self.num_schools = MAX_NUM_SCHOOLS
            self.schools = []  # to be updated later based on self.selection_policy
            self.name = ""
        
        # calculate buckets for score-based decisions
        self.test_score = score if score != -1 else self.get_rand_score(seed)
        self.seat = seated(self.test_score)
        self.screen = screened(self.test_score)
        
        # extra / potential additions
        self.district = 0
        self.borough = None
        self.location = None
        
    def get_rand_score(self, new_seed):
        """ generates a random gpa based on assumed normal distribution of nyc highschool data """
        random.seed(new_seed)
        num = round(np.random.normal(68, 8.89, 1)[0], 2)
        if num < 0:
            num = 0
        elif num > 100:
            num = 100
        return num
    
    def update_choice(self, schools):
        """ used to update a student object with custom school information """
        self.schools = schools
        self.num_schools = len(schools)
        
    def info(self, simple=False):
        """ shows basic information generated from seed/id """
        basics = "ID: " + self.id + "\nLottery: " + self.lottery
        scores = "\nScores: " + str([self.test_score, self.seat, self.screen])
        policies = "\nPolicies: " + str([self.selection_policy, self.ranking_policy])
        if simple:
            return basics
        else:
            return basics + scores + policies
        
    def to_list(self):
        """ export all data for dataframe conversion """
        return [self.id, self.lottery, self.selection_policy, self.ranking_policy, self.num_schools, 
                self.test_score, self.seat, self.screen,
                self.name, self.district, self.borough, self.location]
        
    def __str__(self):
        """ return unique hashable identifier """
        return self.id
#     sorted(students, key=lambda x: int(x.lottery, 16))
        

# stats on nyc schools
mean_school_cap = 145  # capacity
std_school_cap = 128.5
mean_ens = 2.453505  # ens = expected number of students applied per seat
std_ens = 4.072874
class School:
    def __init__(self, seed, cap=-1, pop=-1, like=-1, name=""):
        # necessary info
        self.dbn = seed  # ID
        random.seed(seed) # set the seed
        
        self.policy = random.randint(1,3)
        self.capacity = self.get_rand_cap(seed) if cap<0 else cap
        # TODO add distribution of capacity and popularity (use classification on quintile for applications)
        
        # NOTE: popularity is how likely a school is to be on a student's list
        if pop == -1:  # weighted by mean & std of popularity / mean capacity
            np.random.seed(seed_stoi(seed))
            new_pop = np.random.normal(mean_ens, std_ens, 1)[0]
            if new_pop < 0:
                new_pop = 0
            self.popularity = round(self.capacity * new_pop, 2)
        else:
            self.popularity = pop
        # NOTE: likeability is how high on a students list a given school should appear
        self.likeability = random.randint(1,MAX_NUM_SCHOOLS) if like == -1 else like    
        
        # extra info
        self.name = name
        self.district = 0
        self.borough = None
        self.location = None
        
    def get_rand_cap(self, new_seed):
        """ generate a random school capacity based on normal distribution of nyc highschool data """
        np.random.seed(seed_stoi(new_seed))
        num = round(np.random.normal(mean_school_cap, std_school_cap, 1)[0])  
        if num < 1:
            num = 1
        return num    
        
    def info(self, simple=False):
        """ display basic info """
        basics = "ID: " + self.dbn
        if self.name != "":
            basics += ", Name: " + self.name
        basics += "\nPolicy: " + str(self.policy)
        additional = "\nCap/Pop/Like: " + str([self.capacity, self.popularity, self.likeability])
        return basics + additional if not simple else ""
    
    def to_list(self):
        """ export all information"""
        return [self.dbn, self.policy, self.popularity, self.likeability,
                self.name, self.district, self.borough, self.location]
        
    def __str__(self):
        """ return unique hashable id """
        return self.dbn
    
""" AUTHOR'S NOTE:
These structures are meant to loosely mirror the relationship between schools and students
in the highschool matching process...
- for reproducability sake, both objects require a seed.__str__() that will determine its random state
"""

# just making sure everything is generated properly
tester = Student("student test")
print(tester.info())
print()
tester2 = School("school test1")
print(tester2.info())
# Out:
# ID: student test
# Lottery: 062cb39d480343f5a4ed5796933fca98
# Scores: [65.87, 3, 5]
# Policies: [1, 2]
#
# ID: school test1
# Policy: 2
# Cap/Pop/Like: [146, 363.05, 1]

# %%
# GENERATORS (with random seeds)
# 2022 default = 71250 students ranked alongside 437 schools
LARGE_NUM = 9999999999  # used to set upperbound for sampling range

def generate_students(seed, size=71250):
    """ generate students based on seeded random sampling """
    random.seed(seed)
    return [Student("Student #"+str(i)) for i in random.sample(range(LARGE_NUM*size), size)]

def generate_schools(seed, size=437):
    """ generate schools based on seeded random sampling"""
    random.seed(seed)
    return [School("School #"+str(i)) for i in random.sample(range(LARGE_NUM*size), size)]

def generate_nyc_schools(seed, school_info_dir="Data/schools_info_incomplete.npy"):
    """ generate schools based on nyc school applicant data """
    school_info = np.load(school_info_dir, allow_pickle=True).item()
    # {name: (dbn, capacity, true applicants, total applicants)}
    new_schools = []
    for name, info in school_info.items():
        # Note: can add seeded variance in popularity & likeability
        tmp_like = 0 if info[1]==0 or info[3]==0 else round(info[3]/info[1], 3)  # applicant rate (proxy for true_ar)
        schol = School(info[0], info[1], info[3], tmp_like, name)
        new_schools.append(schol)
    random.seed(seed)
    random.shuffle(new_schools)  # shuffle because order can affect tiebreakers
    return new_schools
    
  
""" AUTHOR'S NOTE:
In a previous iteration the random sample was based on size to ensure reproducibilty...
For some reason the random state carried over from previous iterations resulting in non-random matches.
- to mitigate this the functions are now exclusively random
- if you'd like to reproduce a previous generation, simply generate students/schools with the same id/dbn
"""

#test
test_students = generate_students(1, 2)
for stud in test_students:
    print(stud.info())
    print()
test_schools = generate_nyc_schools(1)[:2] # generate_schools(1, 2)
for schol in test_schools:
    print(schol.name)
    print(schol.info())
    print()
# Out:
# ID: Student #17756959221
# Lottery: 682842c1ebdd4701b299f9b6226ff07b
# Scores: [65.39, 3, 5]
# Policies: [2, 1]
#
# ID: Student #3280387012
# Lottery: 8153c77963fe44eb942e0c6fce9b322d
# Scores: [70.63, 3, 5]
# Policies: [2, 1]
#
# Professional Performing Arts High School (PPAS)
# ID: 02M408
# Policy: 3
# Cap/Pop/Like: [124, 576, 4.645]
#
# Tottenville High School
# ID: 31R455
# Policy: 2
# Cap/Pop/Like: [580, 2321, 4.002]

# %%
# SIMULATIONS
def simulate_student_choices(students, schools):
    """ takes in a dict of students and schools and generates choices based on student.selection_policy
     ordered by student.ranking_policy 
     Note: also outputs a school_to_student helper dict such that {school.dbn: set(school_id)}
     """
    choices = dict([[str(stud), []] for stud in students])
    
    # generate lists of schools for each strategy & shuffle
    full_random = list(schools.keys())
    popularity_weights = [schools[schol].popularity for schol in full_random]
    
    school_to_student = dict([[str(schol), set()] for schol in schools])  # helper for school choices
    for stud in tqdm(students.values()):
        # for each student, choose schools depending on strategy based on seed
        ranks = []
        random.seed(str(stud))
        if stud.selection_policy == 1:  # fully randomized
            ranks = random.choices(population=full_random, k=stud.num_schools)
        else:  # popularity weighted randomized
            ranks = random.choices(population=full_random, weights=popularity_weights, k=stud.num_schools)
        
        # order based on student policy
        if stud.ranking_policy != 1:  # rank by 
            ranks.sort(key=lambda schol: schools[schol].likeability, reverse=True)
            # NOTE: ties are handled by how the list was previously sorted which is depended on the seed
        choices[str(stud)] = ranks
        
        for schol_id in ranks:  # add ranks to helper
            school_to_student[schol_id].add(str(stud))
    return choices, school_to_student

def simulate_school_choices(school_to_student, students, schools):
    """ takes in a dict of students and schools as well as the student's rankings and generatings 
        the school's choices based on them
    """
    choices = {}
    # sort students by school policy
    for schol_id, student_ids in tqdm(school_to_student.items()):
        ranks = []
        if schools[schol_id].policy == 1:
            ranks = sorted(student_ids, key=lambda stud_id: students[stud_id].lottery)
        elif schools[schol_id].policy == 2:
            ranks = sorted(student_ids, key=lambda stud_id: (students[stud_id].seat, students[stud_id].lottery))
        else:
            ranks = sorted(student_ids, key=lambda stud_id: (students[stud_id].screen, students[stud_id].lottery))
        choices[schol_id] = ranks
    return choices

# %%
# OVERALL FUNCTIONS**
def oneshot(seed, nyc=True, verbose=False):
    """ runs a basic simulation that generates schools and students and simulates their preferences:
        - student_preference_profile = {student_id : [school_ids_ranked]}
        - school_preference_profile = {school ids : [student_ids_ranked]} 
        - students = {student_id : [self.id, self.lottery, self.selection_policy, self.ranking_policy,
                                    self.num_schools,  self.test_score, self.seat, self.screen, 
                                    self.name, self.district, self.borough, self.location] }
        - schools = {school_dbn : [self.dbn, self.policy, self.popularity, self.likeability,
                                   self.name, self.district, self.borough, self.location] }
                                   
        seed determines the simulation state,
        nyc determines if you want to use real nyc school data from 2023
    """
    random.seed(seed)
    student_seed, school_seed = random.sample(range(LARGE_NUM), 2)
    if verbose: print("Base Seed", seed, "created student seed", student_seed, "and school seed", school_seed)
    
    # generate students and schools
    students = dict([[str(stud), stud] for stud in generate_students(student_seed)])
    if nyc:
        schools = dict([[str(schol), schol] for schol in generate_nyc_schools(school_seed)])
    else:
        schools = dict([[str(schol), schol] for schol in generate_schools(school_seed)])
    if verbose: 
        total_seats = sum([schol.capacity for schol in schools.values()])
        print("Generated", len(schools), "schools and", len(students), "students with", total_seats, "seats\n")
    
    if verbose: print("Student choices simulating...")
    student_preference_profile, school_to_student = simulate_student_choices(students, schools)
    
    if verbose: print("School choices simulating...")
    # Note: no random seed since lottery# informs the tiebreaks
    school_preference_profile = simulate_school_choices(school_to_student, students, schools)
    
    return student_preference_profile, school_preference_profile, students, schools


def oneshot_with_input(seed, lottery_num, my_schools, gpa=-1, student_name="injected_student", verbose=False):
    """ runs a simulation based on NYC data with a single student as input
    Note: for student, lottery# & schools required, percentile scale gpa recommended, name possible
    """
    assert len(my_schools) <= MAX_NUM_SCHOOLS, "you can only rank "+str(MAX_NUM_SCHOOLS)+" schools"
    
    # tldr to a normal oneshot() simulation, then add in the student before the school preferences are simulated
    random.seed(seed)
    student_seed, school_seed = random.sample(range(LARGE_NUM), 2)
    if verbose: print("Base Seed", seed, "created student seed", student_seed, "and school seed", school_seed)
    
    students = dict([[str(stud), stud] for stud in generate_students(student_seed)])
    schools = dict([[str(schol), schol] for schol in generate_nyc_schools(school_seed)])
    if verbose: 
        total_seats = sum([schol.capacity for schol in schools.values()])
        print("Generated", len(schools), "schools and", len(students), "students with", total_seats, "seats\n")
    
    if verbose: print("Student choices simulating...")
    student_preference_profile, school_to_student = simulate_student_choices(students, schools)
    
    # inject student into data
    if verbose: print("Injecting new student into data...")
    choices = match_schools(schools, my_schools)  # match choices with schools in present data set
    new_student = Student(student_name, lottery_num, choices, gpa)  # make student obj
    students[str(new_student)] = new_student  # add student to data
    student_preference_profile[str(new_student)] = choices  # add student's list to preference profile
    for schol in choices:  # add student's choices to school dict
        school_to_student[schol].add(str(new_student))  # Note: make sure there is no student with an identical id
    
    if verbose: print("School choices simulating...")
    school_preference_profile = simulate_school_choices(school_to_student, students, schools)
    
    return student_preference_profile, school_preference_profile, students, schools

# %%
# %%time

# TESTING
simstate = 1
student_prefs, school_prefs, students, schools = oneshot(simstate, True, True)
# student_prefs, school_prefs, students, schools = oneshot_with_input(simstate, "04628abdceed442c918f54ed2f39055e",
#                                                          ["Quest to Learn", "East Side Community",
#                                                           "Forsyth Satellite Academy",
#                                                           "Lower Manhattan Arts Academyy"], 
#                                                          90, "Kora", True)
# Out:
# Base Seed 1 created student seed 9167024629 and school seed 3280387012
# Generated 447 schools and 71250 students with 64848 seats
#
# Student choices simulating...
# 100%|███████████████████████████████████████| 71250/71250 [00:02<00:00, 33919.18it/s]
# School choices simulating...
# 100%|█████████████████████████████████████████████| 447/447 [00:01<00:00, 358.37it/s]
# CPU times: user 7.05 s, sys: 866 ms, total: 7.92 s
# Wall time: 8.55 s

# %%
# ensuring injected student is in profile and their preferences are stored 
# for schol in student_prefs["Kora"]:
#     print(schools[schol].info())
#     print()

# %%
# Sanity Check:
zero_count = 0
avg_count = 0
for schol, studs in school_prefs.items():
    if len(studs) == 0:
        zero_count += 1
    avg_count += len(studs)
avg_count /= len(schools)
print("Simulation resulted in", zero_count, "of", len(schools), "schools with no student applications")
print("On average, each school ranked", round(avg_count), "of", len(students), "students")
# Out:
# Simulation resulted in 0 of 447 schools with no student applications
# On average, each school ranked 1837 of 71250 students

# %%
# checking that students with policy[1]=2 have schools ranked from largest to smallest likeability
s = list(student_prefs.keys())[0]
print(students[s].info())
print("*\n")
for sch in student_prefs[s]:
    print(schools[sch].info())
    print()
# Out:
# ID: Student #609348707388531
# Lottery: 8b0c6057f77b4978b78dfc40c663e2e9
# Scores: [65.87, 3, 5]
# Policies: [1, 2]
# *
#
# ID: 02M294, Name: Essex Street Academy
# Policy: 2
# Cap/Pop/Like: [81, 608, 7.506]
#
# ID: 30Q575, Name: Academy of American Studies
# Policy: 3
# Cap/Pop/Like: [170, 1150, 6.765]
#
# ID: 09X505, Name: Bronx School for Law, Government and Justice
# Policy: 3
# Cap/Pop/Like: [104, 347, 3.337]
#
# ID: 09X324, Name: Bronx Early College Academy for Teaching & Learning
# Policy: 3
# Cap/Pop/Like: [81, 197, 2.432]
#
# ID: 08X269, Name: Bronx Studio School for Writers and Artists
# Policy: 3
# Cap/Pop/Like: [81, 163, 2.012]
#
# ID: 14K454, Name: Williamsburg High School of Art and Technology, The
# Policy: 2
# Cap/Pop/Like: [116, 206, 1.776]
#
# ID: 07X548, Name: Careers in Sports High School
# Policy: 1
# Cap/Pop/Like: [125, 166, 1.328]
#
# ID: 20K609, Name: Urban Assembly School for Leadership and Empowerment
# Policy: 2
# Cap/Pop/Like: [81, 103, 1.272]
#
# ID: 30Q555, Name: Newcomers High School
# Policy: 2
# Cap/Pop/Like: [81, 85, 1.049]
#
# ID: 19K639, Name: Brooklyn Lab School
# Policy: 1
# Cap/Pop/Like: [102, 101, 0.99]
#
# ID: 18K629, Name: Cultural Academy for the Arts and Sciences
# Policy: 3
# Cap/Pop/Like: [108, 77, 0.713]
#
# ID: 02M419, Name: Landmark High School
# Policy: 1
# Cap/Pop/Like: [100, 54, 0.54]

# %%
# checking that schools with policy > 1 have students loosely ranked from largest to smallest test score
s = list(school_prefs.keys())[0]
print(schools[s].info())
print("*\n")
for stud in school_prefs[s]:
    print(students[stud].info())
    print()
# Out:
# ID: 02M305, Name: Urban Assembly Academy of Government and Law, The
# Policy: 1
# Cap/Pop/Like: [100, 59, 0.59]
# *
#
# ID: Student #522631938530426
# Lottery: 0027dd977b5d468baefc8d64f7c9c97e
# Scores: [72.47, 3, 5]
# Policies: [1, 2]
#
# ID: Student #471787388019980
# Lottery: 0054146e9495410da6836f0ab30a364c
# Scores: [75.07, 3, 5]
# Policies: [1, 2]
#
# ID: Student #407462084557829
# Lottery: 006f38b3000746b89fdfd6fd9acc0715
# Scores: [78.22, 2, 4]
# Policies: [2, 1]
#
# ID: Student #351598623463561
# Lottery: 00a166467d0448b0bec286cc256f0e77
# Scores: [68.5, 3, 5]
# Policies: [1, 2]
#
# ID: Student #533804101163056
# Lottery: 013a67acae8b4afd8741eb069b2c6ae3
# Scores: [59.52, 3, 5]
# Policies: [1, 2]
#
# ID: Student #638748409626487
# Lottery: 015600d5b6474421b3287e766f8eff76
# Scores: [54.69, 3, 5]
# Policies: [1, 2]
#
# ID: Student #611357795177208
# Lottery: 01b07fe1ab7041c59a5dee60d08670cd
# Scores: [68.21, 3, 5]
# Policies: [1, 2]
#
# ID: Student #73640918598186
# Lottery: 01ced39d2df04a39bf7dbf44f1c993e9
# Scores: [72.89, 3, 5]
# Policies: [1, 2]
#
# ID: Student #298986833464933
# Lottery: 021d6fd393d74750b6307d902b028ff5
# Scores: [68.03, 3, 5]
# Policies: [1, 2]
#
# ID: Student #667097663257863
# Lottery: 0277c339d8774dd0bc11c6d92c63e8f6
# Scores: [69.09, 3, 5]
# Policies: [1, 2]
#
# ID: Student #408590042690162
# Lottery: 0278d249008b4bd9be8611bd56c5e084
# Scores: [62.75, 3, 5]
# Policies: [1, 2]
#
# ID: Student #271896687843034
# Lottery: 02a20cd6f3e7447e999bddd5e8f913e9
# Scores: [75.2, 3, 5]
# Policies: [1, 2]
#
# ID: Student #66352853743312
# Lottery: 0302af4226214e4da8248bbf37417dad
# Scores: [68.2, 3, 5]
# Policies: [1, 2]
#
# ID: Student #664169454145305
# Lottery: 0314feca0897474caceea045aa22a145
# Scores: [62.58, 3, 5]
# Policies: [1, 2]
#
# ID: Student #571484725600661
# Lottery: 034da523291645a3b1c95f8cdd5b162b
# Scores: [81.18, 2, 4]
# Policies: [1, 2]
#
# ID: Student #393454906924941
# Lottery: 036a92a6b9414e50a0fb274fabcd5c4b
# Scores: [93.03, 1, 2]
# Policies: [1, 2]
#
# ID: Student #172480448781176
# Lottery: 036ab5c30000442d927c8950b2af97fa
# Scores: [73.88, 3, 5]
# Policies: [1, 2]
#
# ID: Student #42200939094902
# Lottery: 03971a795dcc422fb4dbee80b7a1fb6d
# Scores: [66.09, 3, 5]
# Policies: [2, 1]
#
# ID: Student #560628317433795
# Lottery: 04047b3972694758bc8484627838f351
# Scores: [64.58, 3, 5]
# Policies: [1, 2]
#
# ID: Student #64790680635108
# Lottery: 0448b213be1448febd7ecec4a21d04f8
# Scores: [75.44, 3, 5]
# Policies: [1, 2]
#
# ID: Student #578104732453719
# Lottery: 04628abdceed442c918f54ed2f39055e
# Scores: [60.38, 3, 5]
# Policies: [1, 2]
#
# ID: Student #98183509296862
# Lottery: 046c1fb86dfb45eea9752cf6008d38fc
# Scores: [74.68, 3, 5]
# Policies: [1, 2]
#
# ID: Student #161773727601078
# Lottery: 04893dded52a4ca1b260a010724bb681
# Scores: [59.22, 3, 5]
# Policies: [1, 2]
#
# ID: Student #295860443796457
# Lottery: 048a5013caa04f16a1720c1b007d0820
# Scores: [73.09, 3, 5]
# Policies: [1, 2]
#
# ID: Student #50878053228530
# Lottery: 04b46b87af484e66b74c928551504b83
# Scores: [55.79, 3, 5]
# Policies: [1, 2]
#
# ID: Student #316537925442338
# Lottery: 051df44497aa425dbb5b2b560b8620ed
# Scores: [56.96, 3, 5]
# Policies: [1, 2]
#
# ID: Student #298015666857795
# Lottery: 057591ec86fd4c339df6dc7e8b38e152
# Scores: [64.2, 3, 5]
# Policies: [1, 2]
#
# ID: Student #711173303087524
# Lottery: 0588f2f2b9d1449f90c4dea533691146
# Scores: [83.08, 2, 3]
# Policies: [1, 2]
#
# ID: Student #139204593588053
# Lottery: 058f336f1ab2420196f11cd7e0025b73
# Scores: [60.31, 3, 5]
# Policies: [1, 2]
#
# ID: Student #220493635183793
# Lottery: 059a7d0d002140959ffb16acbdb2fd58
# Scores: [92.07, 1, 2]
# Policies: [1, 2]
#
# ID: Student #139982979395735
# Lottery: 05c358810e9a454f9c113db37a903a02
# Scores: [97.12, 1, 1]
# Policies: [1, 2]
#
# ID: Student #489143952695903
# Lottery: 0626a82c004142a8816a269ed8b601fe
# Scores: [63.64, 3, 5]
# Policies: [1, 2]
#
# ID: Student #317498076614398
# Lottery: 0627aeea3b3a43ea9ecf2f11000f7543
# Scores: [71.62, 3, 5]
# Policies: [1, 2]
#
# ID: Student #667845118297647
# Lottery: 0645bfe0a4a74f8088a805f98ffab3c6
# Scores: [76.76, 3, 4]
# Policies: [1, 2]
#
# ID: Student #385519272697586
# Lottery: 065faa29006e4b419084b3534e87cfc5
# Scores: [72.07, 3, 5]
# Policies: [1, 2]
#
# ID: Student #449694048325391
# Lottery: 06808b6db5e94dc4957e3a75c03abc5c
# Scores: [70.13, 3, 5]
# Policies: [1, 2]
#
# ID: Student #221728900947483
# Lottery: 069395be18064763868d495ec0f5bb7a
# Scores: [55.17, 3, 5]
# Policies: [2, 1]
#
# ID: Student #527132361106344
# Lottery: 06c3822f000a41ef81789bf53ae09362
# Scores: [71.91, 3, 5]
# Policies: [1, 2]
#
# ID: Student #291575549285861
# Lottery: 07104407809943189133230c8f23bdab
# Scores: [69.79, 3, 5]
# Policies: [1, 2]
#
# ID: Student #686045875637016
# Lottery: 074ec6ca267b42409b452ed0e4031e2f
# Scores: [72.28, 3, 5]
# Policies: [1, 2]
#
# ID: Student #394409808213195
# Lottery: 07a23178d751497f849ccc31a880d2f8
# Scores: [86.86, 2, 3]
# Policies: [2, 1]
#
# ID: Student #96522041133314
# Lottery: 07e01a5ddf3545468f9aa9491555c90d
# Scores: [60.57, 3, 5]
# Policies: [2, 1]
#
# ID: Student #693635499424813
# Lottery: 0821b8f058834e989c361bef32c45c1d
# Scores: [67.92, 3, 5]
# Policies: [1, 2]
#
# ID: Student #4621500299685
# Lottery: 084959f01eb8410397604cc3007ecbe4
# Scores: [72.17, 3, 5]
# Policies: [1, 2]
#
# ID: Student #673786010670840
# Lottery: 085b418d13e34584a953415c000ed021
# Scores: [78.88, 2, 4]
# Policies: [2, 1]
#
# ID: Student #572454542684428
# Lottery: 08c5fea9255d4038a4e34b748ee9a5e2
# Scores: [63.76, 3, 5]
# Policies: [1, 2]
#
# ID: Student #393438390455142
# Lottery: 08cc9e8bf756498a8efc1926f643120a
# Scores: [77.96, 2, 4]
# Policies: [1, 2]
#
# ID: Student #100983914132440
# Lottery: 09238cfb188a4c60ba3b6c3a00363786
# Scores: [58.1, 3, 5]
# Policies: [1, 2]
#
# ID: Student #112405807326476
# Lottery: 09285219a626454786e211f5000ec854
# Scores: [75.46, 3, 5]
# Policies: [1, 2]
#
# ID: Student #363496735486905
# Lottery: 09609fcadb114979bbb870358ba8a826
# Scores: [72.92, 3, 5]
# Policies: [1, 2]
#
# ID: Student #195729983322824
# Lottery: 0976a4fdc6fb40bf913f24e6c5ce2ef9
# Scores: [83.81, 2, 3]
# Policies: [1, 2]
#
# ID: Student #343400840899858
# Lottery: 098b2bfc9c104e8fad71b22b35a7ee79
# Scores: [58.78, 3, 5]
# Policies: [2, 1]
#
# ID: Student #378230856950488
# Lottery: 09b70be24a92437dac8284e4b5599f8c
# Scores: [71.12, 3, 5]
# Policies: [1, 2]
#
# ID: Student #356944400316999
# Lottery: 0a21997cb77d44cabed2d333b6c620a1
# Scores: [73.05, 3, 5]
# Policies: [1, 2]
#
# ID: Student #711149230285913
# Lottery: 0a40f39600894a76acc2620851d54b66
# Scores: [53.08, 3, 5]
# Policies: [1, 2]
#
# ID: Student #469145666729540
# Lottery: 0a441a75de954136a2543bd4007c1dea
# Scores: [48.78, 3, 5]
# Policies: [1, 2]
#
# ID: Student #587899903859435
# Lottery: 0a46851c1ebf4e56a80dafca583d98ce
# Scores: [65.95, 3, 5]
# Policies: [1, 2]
#
# ID: Student #632061816918267
# Lottery: 0a6d2e8b78944f5baf6dffed55665327
# Scores: [74.7, 3, 5]
# Policies: [1, 2]
#
# ID: Student #594297621701350
# Lottery: 0a79f287000844c0805c53b2e949d830
# Scores: [75.2, 3, 5]
# Policies: [2, 1]
#
# ID: Student #373866786606907
# Lottery: 0a95222f1be24893b575321e05632069
# Scores: [73.66, 3, 5]
# Policies: [1, 2]
#
# ID: Student #346008342310865
# Lottery: 0b072a56098e44a6be92eb9c07522cf8
# Scores: [72.29, 3, 5]
# Policies: [1, 2]
#
# ID: Student #287347453825826
# Lottery: 0b5fd98195aa4f4285b046010f4ce6d9
# Scores: [61.36, 3, 5]
# Policies: [1, 2]
#
# ID: Student #194356868362324
# Lottery: 0b8e3804c6414ee0a68c90d9dcea55ac
# Scores: [66.17, 3, 5]
# Policies: [1, 2]
#
# ID: Student #575353442697691
# Lottery: 0ba7c7f39cb841ee86a869dde07f2b96
# Scores: [60.33, 3, 5]
# Policies: [1, 2]
#
# ID: Student #69521287629857
# Lottery: 0bd90cf917234718b11478282eea97ff
# Scores: [55.58, 3, 5]
# Policies: [1, 2]
#
# ID: Student #215269268589207
# Lottery: 0bf5e45582e64affa19d070d5578225f
# Scores: [77.26, 3, 4]
# Policies: [1, 2]
#
# ID: Student #460221091014166
# Lottery: 0c1205bd008e4d29a7160dccf26d3504
# Scores: [71.24, 3, 5]
# Policies: [1, 2]
#
# ID: Student #669168236703772
# Lottery: 0c29dc770481446d858ec55a6346f8c4
# Scores: [66.28, 3, 5]
# Policies: [1, 2]
#
# ID: Student #377035568649905
# Lottery: 0c303079a097482abda340fc6c415981
# Scores: [58.45, 3, 5]
# Policies: [2, 1]
#
# ID: Student #134968895600787
# Lottery: 0c7e21723c9e43328259bfc5a2cfda2a
# Scores: [63.46, 3, 5]
# Policies: [1, 2]
#
# ID: Student #35176500193462
# Lottery: 0c8e09d0cf68417b8d4680bbee4b9015
# Scores: [67.82, 3, 5]
# Policies: [1, 2]
#
# ID: Student #378454667262553
# Lottery: 0c9d08edab4141989a873ccedb5b61ca
# Scores: [58.48, 3, 5]
# Policies: [1, 2]
#
# ID: Student #16657763963071
# Lottery: 0cc38ce916174f6b81367a57953f77ac
# Scores: [76.12, 3, 5]
# Policies: [1, 2]
#
# ID: Student #509516452826010
# Lottery: 0d0cd4bf6569482794adc6f499afead3
# Scores: [58.15, 3, 5]
# Policies: [1, 2]
#
# ID: Student #138800265338002
# Lottery: 0d84eda2ecd94b5fa79c14944ae7d7d3
# Scores: [88.09, 2, 3]
# Policies: [1, 2]
#
# ID: Student #756812260065
# Lottery: 0d8867cd7b5841acb09888359e925461
# Scores: [58.74, 3, 5]
# Policies: [1, 2]
#
# ID: Student #695923408825398
# Lottery: 0d97af3b55fa4aab936aa580162706a0
# Scores: [66.04, 3, 5]
# Policies: [1, 2]
#
# ID: Student #301785203702564
# Lottery: 0da292ce004b49b4a3a7dd1e749bda94
# Scores: [79.95, 2, 4]
# Policies: [1, 2]
#
# ID: Student #356220579485992
# Lottery: 0db94ea876174ef280b2045da5371b54
# Scores: [57.4, 3, 5]
# Policies: [1, 2]
#
# ID: Student #57847662396496
# Lottery: 0dbb1a5600564f1ea2f576408c384787
# Scores: [53.65, 3, 5]
# Policies: [1, 2]
#
# ID: Student #595128663011523
# Lottery: 0deccc19c1a14580ab686243a20df8de
# Scores: [72.75, 3, 5]
# Policies: [1, 2]
#
# ID: Student #10910773793038
# Lottery: 0df8d579fe574688a3b42930fb999824
# Scores: [78.45, 2, 4]
# Policies: [1, 2]
#
# ID: Student #97249541081220
# Lottery: 0e121bb8d6524a9b8ab82132cf3c763c
# Scores: [73.09, 3, 5]
# Policies: [1, 2]
#
# ID: Student #702331158224190
# Lottery: 0e1763d972674f83825b516fb16e08fd
# Scores: [61.44, 3, 5]
# Policies: [1, 2]
#
# ID: Student #657315193750537
# Lottery: 0e6886c709e64a23a0c5bbd8afc384a6
# Scores: [54.13, 3, 5]
# Policies: [1, 2]
#
# ID: Student #39430530637521
# Lottery: 0e99e479879e43cc8e6f5d11715976c2
# Scores: [85.56, 2, 3]
# Policies: [1, 2]
#
# ID: Student #532562704878670
# Lottery: 0ec1a9e6098742ab95b813379edcfad7
# Scores: [62.87, 3, 5]
# Policies: [2, 1]
#
# ID: Student #251873166417880
# Lottery: 0f0be30e9d0742e5834c454431832dbd
# Scores: [85.37, 2, 3]
# Policies: [1, 2]
#
# ID: Student #373225827417091
# Lottery: 0f1555b21f8f4f61bd779afc1489690f
# Scores: [73.95, 3, 5]
# Policies: [1, 2]
#
# ID: Student #457496953411390
# Lottery: 0f48580197db43f095aa2e54f13a0689
# Scores: [69.14, 3, 5]
# Policies: [2, 1]
#
# ID: Student #415189398271000
# Lottery: 0f4ee6cefcaa44948041120efb65cd43
# Scores: [76.48, 3, 4]
# Policies: [1, 2]
#
# ID: Student #549580423391705
# Lottery: 10169318fe7e4f36ac9397a9001c834c
# Scores: [75.69, 3, 5]
# Policies: [1, 2]
#
# ID: Student #515608014237174
# Lottery: 10c541826290432e85ea84f5da2b87e7
# Scores: [71.57, 3, 5]
# Policies: [1, 2]
#
# ID: Student #116008455142973
# Lottery: 110d69733b924f9993c9c1de7d9bffbd
# Scores: [69.16, 3, 5]
# Policies: [2, 1]
#
# ID: Student #230652618245062
# Lottery: 1110f34e594f4046b9321ac9577c3bae
# Scores: [74.03, 3, 5]
# Policies: [1, 2]
#
# ID: Student #159007888466087
# Lottery: 114150578f8144108abeacb494f587ef
# Scores: [63.36, 3, 5]
# Policies: [1, 2]
#
# ID: Student #136956066782381
# Lottery: 1154788d9e6e40f6a0ff9aa1919b222c
# Scores: [64.86, 3, 5]
# Policies: [1, 2]
#
# ID: Student #238831080434195
# Lottery: 115b87ef48284e03a4a74379164cb1bb
# Scores: [72.86, 3, 5]
# Policies: [1, 2]
#
# ID: Student #511928939883855
# Lottery: 11d335870b364f719622c502be84ecd0
# Scores: [58.21, 3, 5]
# Policies: [1, 2]
#
# ID: Student #69851911013296
# Lottery: 11dd470801174006bbc1f007344692fa
# Scores: [72.35, 3, 5]
# Policies: [1, 2]
#
# ID: Student #131716620569487
# Lottery: 11e3cafbd39d4f46bb01ddaf0001e722
# Scores: [59.67, 3, 5]
# Policies: [1, 2]
#
# ID: Student #465314331222541
# Lottery: 11fff13134ce480081554f702c75c878
# Scores: [86.86, 2, 3]
# Policies: [1, 2]
#
# ID: Student #163053761030898
# Lottery: 121b452e430d44ddb9214571238924ec
# Scores: [63.86, 3, 5]
# Policies: [1, 2]
#
# ID: Student #188711751925758
# Lottery: 121b5f9cab574a7eb4633e070013668a
# Scores: [76.78, 3, 4]
# Policies: [2, 1]
#
# ID: Student #462002563130494
# Lottery: 1227240d7e4e4df680cca69208960eb2
# Scores: [78.79, 2, 4]
# Policies: [1, 2]
#
# ID: Student #495840318321302
# Lottery: 123e8f3933c340eaa958bc6554c5c433
# Scores: [60.75, 3, 5]
# Policies: [2, 1]
#
# ID: Student #207432406623683
# Lottery: 126544e8b5fb4b40b132b7805267429f
# Scores: [69.28, 3, 5]
# Policies: [1, 2]
#
# ID: Student #691935512878745
# Lottery: 12916f70e9cc40a1a842d0b778c47d08
# Scores: [59.3, 3, 5]
# Policies: [1, 2]
#
# ID: Student #174408825419457
# Lottery: 12b0a71519054244be1d289580199f68
# Scores: [79.37, 2, 4]
# Policies: [1, 2]
#
# ID: Student #558323456250667
# Lottery: 12c79d4e263849f898ea7298607bdad7
# Scores: [61.21, 3, 5]
# Policies: [1, 2]
#
# ID: Student #204028345256961
# Lottery: 12ccd851f69a42bb8a02bf6b4bf19030
# Scores: [56.49, 3, 5]
# Policies: [1, 2]
#
# ID: Student #167241961100771
# Lottery: 132bd70f39864cc39744bf06663b002f
# Scores: [65.89, 3, 5]
# Policies: [2, 1]
#
# ID: Student #449799572659962
# Lottery: 13617c8a1bbc44a1b981a82916255767
# Scores: [67.69, 3, 5]
# Policies: [1, 2]
#
# ID: Student #383557090334310
# Lottery: 137e3aaf46904ac195c19f2779bd59a4
# Scores: [83.22, 2, 3]
# Policies: [1, 2]
#
# ID: Student #595963055451948
# Lottery: 1387ba8a6ddf4d71bbef269efbf99a91
# Scores: [70.5, 3, 5]
# Policies: [1, 2]
#
# ID: Student #572597970654778
# Lottery: 13a37477c7d149cfb36a2f57be4de789
# Scores: [74.79, 3, 5]
# Policies: [1, 2]
#
# ID: Student #224536276312578
# Lottery: 13f35c8a00194385a150acbe8c0e2997
# Scores: [72.73, 3, 5]
# Policies: [1, 2]
#
# ID: Student #362302710642202
# Lottery: 140d1177a43c4b6b9d9df991bcb3673a
# Scores: [64.61, 3, 5]
# Policies: [1, 2]
#
# ID: Student #388183380549342
# Lottery: 146b0ed9a76a47eb8626b1f90de7a753
# Scores: [84.8, 2, 3]
# Policies: [1, 2]
#
# ID: Student #564557045999813
# Lottery: 14fb1805dd1e4a9db4ae3041004e2cec
# Scores: [73.6, 3, 5]
# Policies: [1, 2]
#
# ID: Student #301382102178428
# Lottery: 14fbc98157c04ae0bc8328dc4741797c
# Scores: [71.37, 3, 5]
# Policies: [1, 2]
#
# ID: Student #355030870277107
# Lottery: 15111868562a4fa585eb91d42412720f
# Scores: [58.22, 3, 5]
# Policies: [1, 2]
#
# ID: Student #634026650273770
# Lottery: 1560ca85d62149fba87235267dcea8b3
# Scores: [60.11, 3, 5]
# Policies: [1, 2]
#
# ID: Student #545172202609707
# Lottery: 1585a6736a304b91877bdfb7f7a77367
# Scores: [79.75, 2, 4]
# Policies: [1, 2]
#
# ID: Student #599895673034144
# Lottery: 1598d73b59334183ae636d16ec290f7b
# Scores: [53.84, 3, 5]
# Policies: [1, 2]
#
# ID: Student #168037448972920
# Lottery: 15995d6ae7a649ec9464ec2ce19f8180
# Scores: [74.23, 3, 5]
# Policies: [1, 2]
#
# ID: Student #553613638411877
# Lottery: 159be66e3ad94b5e9060bbdc09315f77
# Scores: [85.74, 2, 3]
# Policies: [1, 2]
#
# ID: Student #48947970326131
# Lottery: 15a5315427ee4bedb950fba20059adff
# Scores: [69.14, 3, 5]
# Policies: [1, 2]
#
# ID: Student #310282802312907
# Lottery: 15cf4e43c6374829aef189190069ac70
# Scores: [54.99, 3, 5]
# Policies: [1, 2]
#
# ID: Student #149723978249999
# Lottery: 16278cd6eee548e6ac16b5eea300de33
# Scores: [63.55, 3, 5]
# Policies: [1, 2]
#
# ID: Student #435841050552563
# Lottery: 1649f3b72da14c2eaa1bfec11e262846
# Scores: [66.18, 3, 5]
# Policies: [1, 2]
#
# ID: Student #618451291763362
# Lottery: 167cdc62f95249aa9081cacd537413a7
# Scores: [76.71, 3, 4]
# Policies: [1, 2]
#
# ID: Student #361450842631167
# Lottery: 169901d9b0f54271bf0f7301e55d82e2
# Scores: [65.91, 3, 5]
# Policies: [1, 2]
#
# ID: Student #259295180383178
# Lottery: 16c18b9d7bb44ce9af1e606de4f8ac22
# Scores: [69.46, 3, 5]
# Policies: [1, 2]
#
# ID: Student #342618017362457
# Lottery: 16d459507b004743be9cc0a24d26ef3f
# Scores: [57.73, 3, 5]
# Policies: [1, 2]
#
# ID: Student #253919043764262
# Lottery: 16d90df83fd4498cbc9a450831d2ee9d
# Scores: [74.24, 3, 5]
# Policies: [1, 2]
#
# ID: Student #331347787259210
# Lottery: 16e1b2dae0f04fbf946e3589e039b358
# Scores: [75.36, 3, 5]
# Policies: [1, 2]
#
# ID: Student #167039790666836
# Lottery: 16f71aecef574282a96852dc28e8effb
# Scores: [61.77, 3, 5]
# Policies: [1, 2]
#
# ID: Student #283192810826028
# Lottery: 1714008611de46a6942e5a62ee617bbb
# Scores: [62.52, 3, 5]
# Policies: [1, 2]
#
# ID: Student #98590916959422
# Lottery: 174a9d51c1604ea4aa73c208c34772b5
# Scores: [70.48, 3, 5]
# Policies: [1, 2]
#
# ID: Student #183755115036729
# Lottery: 17754581df6046e79aef930eb250f7c5
# Scores: [75.65, 3, 5]
# Policies: [1, 2]
#
# ID: Student #559882803314721
# Lottery: 17a9b4034f474d1bab578962e8b8868d
# Scores: [58.91, 3, 5]
# Policies: [1, 2]
#
# ID: Student #559070347919964
# Lottery: 17b320be321a435c8ba31203007d677a
# Scores: [65.86, 3, 5]
# Policies: [1, 2]
#
# ID: Student #364988402062779
# Lottery: 17dcecf33f6f4b87b1153a1c2752c16f
# Scores: [72.57, 3, 5]
# Policies: [1, 2]
#
# ID: Student #61119439992082
# Lottery: 183b745579234753be1f2217ccc78f92
# Scores: [59.01, 3, 5]
# Policies: [2, 1]
#
# ID: Student #130964793724741
# Lottery: 18410452dba54e25b78b0123f6e6558d
# Scores: [59.21, 3, 5]
# Policies: [1, 2]
#
# ID: Student #275905163084536
# Lottery: 1887b86d9e5d4e9686b868f7cf81cc59
# Scores: [61.58, 3, 5]
# Policies: [1, 2]
#
# ID: Student #243832214034784
# Lottery: 1889a98260f6469b846f693a5843be2f
# Scores: [64.5, 3, 5]
# Policies: [1, 2]
#
# ID: Student #148339288823521
# Lottery: 19142ab1b25c40438009f7e0abab538a
# Scores: [64.07, 3, 5]
# Policies: [1, 2]
#
# ID: Student #560610071454907
# Lottery: 19310785c6df47adb6c19747d939860e
# Scores: [63.82, 3, 5]
# Policies: [1, 2]
#
# ID: Student #576724409731056
# Lottery: 19913547eef647ccaa17269a2fb885c3
# Scores: [71.87, 3, 5]
# Policies: [1, 2]
#
# ID: Student #554076478450956
# Lottery: 19d5cdf811654781bc892d270f903f2a
# Scores: [66.83, 3, 5]
# Policies: [1, 2]
#
# ID: Student #493056849166611
# Lottery: 1a31258f17ba466388e9e2b30057aca2
# Scores: [56.77, 3, 5]
# Policies: [1, 2]
#
# ID: Student #99655326598492
# Lottery: 1a3f765ae81043d4b552b8cb5c2baa85
# Scores: [90.75, 1, 2]
# Policies: [1, 2]
#
# ID: Student #274998884727394
# Lottery: 1a50a40a00024b4ca17a670ebeb5ffbe
# Scores: [82.23, 2, 4]
# Policies: [1, 2]
#
# ID: Student #128634705947015
# Lottery: 1a687f3c72514336acbd870e6ca7c091
# Scores: [67.14, 3, 5]
# Policies: [1, 2]
#
# ID: Student #351958178556063
# Lottery: 1a77f9200ea94381adf512103a15a139
# Scores: [64.61, 3, 5]
# Policies: [2, 1]
#
# ID: Student #552796740522457
# Lottery: 1abc87c1ec85458d9982be4900818983
# Scores: [87.12, 2, 3]
# Policies: [1, 2]
#
# ID: Student #226838330060146
# Lottery: 1afd5ace81da499c94e8d181ae79777d
# Scores: [60.88, 3, 5]
# Policies: [2, 1]
#
# ID: Student #265346734482705
# Lottery: 1b1192ebd09d4b7e8e44f0f985a998b6
# Scores: [71.44, 3, 5]
# Policies: [1, 2]
#
# ID: Student #169590240786286
# Lottery: 1b897476addd4220b3d1379506bf9d2b
# Scores: [76.07, 3, 5]
# Policies: [1, 2]
#
# ID: Student #669930095616242
# Lottery: 1b8efa1f56e34247b15e39e392b871f1
# Scores: [57.34, 3, 5]
# Policies: [1, 2]
#
# ID: Student #361004479367725
# Lottery: 1bc13fc228ee4957818990b379df813e
# Scores: [55.66, 3, 5]
# Policies: [1, 2]
#
# ID: Student #405014572899058
# Lottery: 1bdb2f5429524fb4a865d0d9002f8a0a
# Scores: [68.86, 3, 5]
# Policies: [1, 2]
#
# ID: Student #459026656273417
# Lottery: 1c3e2f6315314365a48ded96c5ef9227
# Scores: [81.85, 2, 4]
# Policies: [1, 2]
#
# ID: Student #629034878419225
# Lottery: 1ce05e7212cb430184944c8fbbcc8077
# Scores: [57.79, 3, 5]
# Policies: [1, 2]
#
# ID: Student #558534697204605
# Lottery: 1d23bf104b324c56a23c4bffee7ddb60
# Scores: [82.1, 2, 4]
# Policies: [1, 2]
#
# ID: Student #256469177263496
# Lottery: 1e0fe18700744fecbe10597f60ad3367
# Scores: [55.35, 3, 5]
# Policies: [1, 2]
#
# ID: Student #590866128327133
# Lottery: 1e2a2fc5bc5e4ca9b800129a07620290
# Scores: [53.25, 3, 5]
# Policies: [1, 2]
#
# ID: Student #492764077732625
# Lottery: 1e2adbe4bff24105944f3e7a67701217
# Scores: [77.62, 2, 4]
# Policies: [1, 2]
#
# ID: Student #397570463616866
# Lottery: 1e93939694f844f596804621464a8d01
# Scores: [77.46, 3, 4]
# Policies: [2, 1]
#
# ID: Student #643928444030811
# Lottery: 1ec569e9315f44d9a336d38c2e9c4770
# Scores: [64.53, 3, 5]
# Policies: [1, 2]
#
# ID: Student #710895389331300
# Lottery: 1ecb6924efef4e11ac636fbf8ffb75f6
# Scores: [77.19, 3, 4]
# Policies: [1, 2]
#
# ID: Student #41736244571657
# Lottery: 1f273c04dcfd492a9d5c8389d011ca10
# Scores: [68.81, 3, 5]
# Policies: [1, 2]
#
# ID: Student #657604841714855
# Lottery: 1f50750a83724a16ae7dc2174547c057
# Scores: [74.44, 3, 5]
# Policies: [1, 2]
#
# ID: Student #571956268433215
# Lottery: 1f894f53f6f24b059e6bbbc78fdff8df
# Scores: [66.32, 3, 5]
# Policies: [1, 2]
#
# ID: Student #253439161289631
# Lottery: 1fbd392f4b6848b38b5c523b139d1b58
# Scores: [65.29, 3, 5]
# Policies: [1, 2]
#
# ID: Student #27675612914133
# Lottery: 1fecf2b8001248a2891e1525f8b6769b
# Scores: [55.28, 3, 5]
# Policies: [2, 1]
#
# ID: Student #34664377113865
# Lottery: 207dbd01a05b4c97a409bc3633fbb885
# Scores: [80.3, 2, 4]
# Policies: [1, 2]
#
# ID: Student #376606071198562
# Lottery: 20968a383c5c4aa8bf1871a653ebe76b
# Scores: [58.72, 3, 5]
# Policies: [1, 2]
#
# ID: Student #121598501258706
# Lottery: 20b1c13dcb544cf19a8db51b71e0ed5c
# Scores: [56.85, 3, 5]
# Policies: [1, 2]
#
# ID: Student #257793836654869
# Lottery: 20c8dc7dfa9048398320286456ea8985
# Scores: [79.76, 2, 4]
# Policies: [1, 2]
#
# ID: Student #704534951424652
# Lottery: 2174d649047040e5b09f89c252dd8bee
# Scores: [85.43, 2, 3]
# Policies: [1, 2]
#
# ID: Student #274142003622553
# Lottery: 21a5d1b8ced545d0ae379351006f7d30
# Scores: [64.03, 3, 5]
# Policies: [1, 2]
#
# ID: Student #336421484500430
# Lottery: 21b2cc3c787e43aa9545ac7057460c6f
# Scores: [62.25, 3, 5]
# Policies: [1, 2]
#
# ID: Student #319218340497030
# Lottery: 21cf930a774541d7a626f483d0755353
# Scores: [64.04, 3, 5]
# Policies: [1, 2]
#
# ID: Student #632480988453151
# Lottery: 220d65988f4b46d2b9f568214fd0d692
# Scores: [58.64, 3, 5]
# Policies: [1, 2]
#
# ID: Student #634563244999255
# Lottery: 224116be2bed4190b1a9b6da39700576
# Scores: [82.14, 2, 4]
# Policies: [1, 2]
#
# ID: Student #245167993312466
# Lottery: 225cefcb994149968b94a2d5a9832c23
# Scores: [72.01, 3, 5]
# Policies: [1, 2]
#
# ID: Student #74850282645653
# Lottery: 2292d86fbc3b4f3c9e84a906a3c95230
# Scores: [76.36, 3, 4]
# Policies: [1, 2]
#
# ID: Student #562025895797301
# Lottery: 229724a9d89a44c9b4d94c0559f07dae
# Scores: [78.01, 2, 4]
# Policies: [1, 2]
#
# ID: Student #449393528413481
# Lottery: 23122b8718944662a5fb2a4e1d7b1fac
# Scores: [66.66, 3, 5]
# Policies: [1, 2]
#
# ID: Student #436185191546056
# Lottery: 2355d3604c454faa81522846a03b75e2
# Scores: [63.26, 3, 5]
# Policies: [1, 2]
#
# ID: Student #82083663544711
# Lottery: 23a98279007e4734bfd42a064dc06a0d
# Scores: [66.81, 3, 5]
# Policies: [1, 2]
#
# ID: Student #520867544726786
# Lottery: 23baf750b56c4f32b041e357b5a0fb2e
# Scores: [63.65, 3, 5]
# Policies: [1, 2]
#
# ID: Student #474926402772190
# Lottery: 23cd7599dc724191a4aca70e7b82d262
# Scores: [59.27, 3, 5]
# Policies: [1, 2]
#
# ID: Student #157617871028989
# Lottery: 241f7762e071433091f7a53e15608079
# Scores: [67.62, 3, 5]
# Policies: [1, 2]
#
# ID: Student #416652134926190
# Lottery: 24a7c28000364c919aa26867d5dd0101
# Scores: [72.71, 3, 5]
# Policies: [1, 2]
#
# ID: Student #661951412808779
# Lottery: 253394a0f472420a908ad133020e0898
# Scores: [65.69, 3, 5]
# Policies: [1, 2]
#
# ID: Student #576268675657254
# Lottery: 2543be2062e14679b402c68fd30e1f1c
# Scores: [71.25, 3, 5]
# Policies: [1, 2]
#
# ID: Student #62686004536544
# Lottery: 256ff46200434aa7ad9362375ffddcb9
# Scores: [70.08, 3, 5]
# Policies: [1, 2]
#
# ID: Student #663296266687091
# Lottery: 257377bdb9664435828e755682aba3ca
# Scores: [65.45, 3, 5]
# Policies: [1, 2]
#
# ID: Student #356232966582458
# Lottery: 257d10b0a97e4e5aaf2bbb54bfb5518f
# Scores: [51.51, 3, 5]
# Policies: [1, 2]
#
# ID: Student #658492665178919
# Lottery: 25815c36c92d4a54bd2fc9fbf95bd8a9
# Scores: [73.04, 3, 5]
# Policies: [1, 2]
#
# ID: Student #245254097420129
# Lottery: 25c22caeac5343039d190d7400118501
# Scores: [64.74, 3, 5]
# Policies: [1, 2]
#
# ID: Student #73847488178163
# Lottery: 25fdf40c91494dcf872f1b6651094745
# Scores: [83.89, 2, 3]
# Policies: [1, 2]
#
# ID: Student #454590190709272
# Lottery: 2672ceae5f704da086faf4d3da36b4c9
# Scores: [61.91, 3, 5]
# Policies: [1, 2]
#
# ID: Student #277519355690596
# Lottery: 2694646be4b14ffea9d27beeac8cbb4d
# Scores: [79.44, 2, 4]
# Policies: [1, 2]
#
# ID: Student #342319491832112
# Lottery: 26bf7f7b1cc84602a4cd823fe6a67c72
# Scores: [68.79, 3, 5]
# Policies: [1, 2]
#
# ID: Student #341807164381301
# Lottery: 27016bec00614412b0e87d674a8be196
# Scores: [74.1, 3, 5]
# Policies: [1, 2]
#
# ID: Student #244093139382008
# Lottery: 2727d8d8b9ec412f915dda705c6eda12
# Scores: [67.15, 3, 5]
# Policies: [1, 2]
#
# ID: Student #136803257731569
# Lottery: 2770f8c4678443c38772c9eee04900ac
# Scores: [69.88, 3, 5]
# Policies: [1, 2]
#
# ID: Student #48188136788068
# Lottery: 27e27123ed804aa2bf6361ffb516de46
# Scores: [55.71, 3, 5]
# Policies: [2, 1]
#
# ID: Student #25422878288747
# Lottery: 27efdd2ade68470aa787e9824012694e
# Scores: [62.13, 3, 5]
# Policies: [1, 2]
#
# ID: Student #519418823328871
# Lottery: 2800dd53544c405d9a06069ce17935e8
# Scores: [60.4, 3, 5]
# Policies: [1, 2]
#
# ID: Student #115884601981045
# Lottery: 282d279e584f4cc4958f7efc88617324
# Scores: [51.45, 3, 5]
# Policies: [1, 2]
#
# ID: Student #55551683817797
# Lottery: 283a3c86a5ca4802920539d2fdfb9cef
# Scores: [68.16, 3, 5]
# Policies: [1, 2]
#
# ID: Student #393281094080222
# Lottery: 28ca151b19a14c0795e178fbbfac2ff6
# Scores: [66.11, 3, 5]
# Policies: [1, 2]
#
# ID: Student #253420323421912
# Lottery: 28cadbf5047c41bfac4651fd76536839
# Scores: [61.83, 3, 5]
# Policies: [1, 2]
#
# ID: Student #49961217270969
# Lottery: 293b5d45003a4dca885e35edeaaeed71
# Scores: [85.69, 2, 3]
# Policies: [1, 2]
#
# ID: Student #85724779277734
# Lottery: 29885bc5328d4b18ba12149cdef85340
# Scores: [60.41, 3, 5]
# Policies: [1, 2]
#
# ID: Student #421246395768085
# Lottery: 29a10d81895c42d0a5a646540004fdde
# Scores: [66.86, 3, 5]
# Policies: [2, 1]
#
# ID: Student #536024985314973
# Lottery: 29a7fd641eaa47a4ba2df454e090b4bf
# Scores: [74.1, 3, 5]
# Policies: [1, 2]
#
# ID: Student #246686092115083
# Lottery: 29b48e51c8b94eba90860c63b474c018
# Scores: [74.36, 3, 5]
# Policies: [1, 2]
#
# ID: Student #339957026384991
# Lottery: 29d11cada52e4a3280c13fe8b7dfeee7
# Scores: [66.61, 3, 5]
# Policies: [1, 2]
#
# ID: Student #340830839662290
# Lottery: 2a1c38d8e3f74c259d9fe57e3be1131c
# Scores: [62.9, 3, 5]
# Policies: [1, 2]
#
# ID: Student #479506693903421
# Lottery: 2a2fb7f622ae4e6f8a8d83e00020a8fa
# Scores: [61.0, 3, 5]
# Policies: [1, 2]
#
# ID: Student #57135992450646
# Lottery: 2a32881d30ae43169934ef77d69d6fb4
# Scores: [65.44, 3, 5]
# Policies: [1, 2]
#
# ID: Student #270795554195425
# Lottery: 2a340f52752f41bd91b42067f5f1cd29
# Scores: [71.95, 3, 5]
# Policies: [1, 2]
#
# ID: Student #184523904697977
# Lottery: 2a745315000947d28c5db18a8df0e860
# Scores: [76.77, 3, 4]
# Policies: [1, 2]
#
# ID: Student #5408494299087
# Lottery: 2a77d6901010409fa8e5382d8ed073c1
# Scores: [69.78, 3, 5]
# Policies: [1, 2]
#
# ID: Student #109862091238891
# Lottery: 2ad28068f4034239a2db2657de7373e1
# Scores: [65.75, 3, 5]
# Policies: [1, 2]
#
# ID: Student #201370050958148
# Lottery: 2b0f6025e0284219bad87c02b24f0bca
# Scores: [61.67, 3, 5]
# Policies: [1, 2]
#
# ID: Student #456695304784192
# Lottery: 2b4a34d5ca184891970d9b679269ce2d
# Scores: [70.04, 3, 5]
# Policies: [1, 2]
#
# ID: Student #109112650595279
# Lottery: 2baae95cb38c4342be1f6417f345c51f
# Scores: [68.13, 3, 5]
# Policies: [1, 2]
#
# ID: Student #181536843014156
# Lottery: 2bb84dd589194a17bccf8d4b1d28e422
# Scores: [62.26, 3, 5]
# Policies: [1, 2]
#
# ID: Student #319587740410863
# Lottery: 2bc94c190042407ca3c2aa9d21b8d5c5
# Scores: [67.95, 3, 5]
# Policies: [1, 2]
#
# ID: Student #395889525387905
# Lottery: 2bcaaec08cb947529fa1f12263ab6212
# Scores: [63.64, 3, 5]
# Policies: [2, 1]
#
# ID: Student #156243584156235
# Lottery: 2bdf7df6617544cbb6365ca51cafd690
# Scores: [80.28, 2, 4]
# Policies: [1, 2]
#
# ID: Student #451361667900722
# Lottery: 2c01416fcfa9490f8ad353d7c5a58754
# Scores: [72.87, 3, 5]
# Policies: [1, 2]
#
# ID: Student #228834673988136
# Lottery: 2c59a8be6385427abed41da1e9dd1019
# Scores: [48.04, 3, 5]
# Policies: [1, 2]
#
# ID: Student #312743821262726
# Lottery: 2d11801d4250428daaa7f1ec649958d6
# Scores: [59.71, 3, 5]
# Policies: [1, 2]
#
# ID: Student #635622116049725
# Lottery: 2d19ce5cb7554b89a5c9af9f0647eda8
# Scores: [64.76, 3, 5]
# Policies: [2, 1]
#
# ID: Student #691432503601130
# Lottery: 2d3b91efdfb242fa904f069ce3a4f522
# Scores: [55.8, 3, 5]
# Policies: [1, 2]
#
# ID: Student #188996067631060
# Lottery: 2d52dbec05004967bf5a369c5c4d1df2
# Scores: [75.59, 3, 5]
# Policies: [1, 2]
#
# ID: Student #159987383584062
# Lottery: 2d96e5062ef6409bbf26e54704b2bdc9
# Scores: [65.13, 3, 5]
# Policies: [1, 2]
#
# ID: Student #336114803762151
# Lottery: 2da83f0129384ee58cfef80de96da40a
# Scores: [58.91, 3, 5]
# Policies: [1, 2]
#
# ID: Student #536573997128784
# Lottery: 2dc04b5f4683452eaf83965fe75b80f7
# Scores: [55.72, 3, 5]
# Policies: [1, 2]
#
# ID: Student #347645236507756
# Lottery: 2dd349a4fbda4acfa940509abb7f6342
# Scores: [74.1, 3, 5]
# Policies: [1, 2]
#
# ID: Student #590146194922376
# Lottery: 2df292b4a97f4b1f97db47262a68639f
# Scores: [65.08, 3, 5]
# Policies: [1, 2]
#
# ID: Student #393820314155321
# Lottery: 2e0cb0d3e0db4a20821dfe8055b9b191
# Scores: [77.05, 3, 4]
# Policies: [1, 2]
#
# ID: Student #390660890165320
# Lottery: 2e14b252f1714b26906f496ec3fe4ac9
# Scores: [73.84, 3, 5]
# Policies: [1, 2]
#
# ID: Student #128106828502018
# Lottery: 2e1f1804220f4bc39a9a92852add87c8
# Scores: [66.75, 3, 5]
# Policies: [1, 2]
#
# ID: Student #145731807567767
# Lottery: 2e45645f0030432e9c8dc43d165657f1
# Scores: [67.11, 3, 5]
# Policies: [1, 2]
#
# ID: Student #62344748077440
# Lottery: 2e522005d4004c1d995dd76011381a79
# Scores: [69.13, 3, 5]
# Policies: [1, 2]
#
# ID: Student #282139431018259
# Lottery: 2e84a29450f041ea85f1f3f63d6f698d
# Scores: [93.89, 1, 2]
# Policies: [1, 2]
#
# ID: Student #398888547028915
# Lottery: 2eee07b3b31242519192d809177668d3
# Scores: [75.29, 3, 5]
# Policies: [1, 2]
#
# ID: Student #419661547014207
# Lottery: 2f6c37d1a1284c28b7edee4df3f1cade
# Scores: [60.07, 3, 5]
# Policies: [1, 2]
#
# ID: Student #588139160656555
# Lottery: 2f9f1756af794b62a356d7456faf5984
# Scores: [74.47, 3, 5]
# Policies: [1, 2]
#
# ID: Student #103666031815103
# Lottery: 2fbcf64826f34d3181ef6d569dffa7c0
# Scores: [83.45, 2, 3]
# Policies: [1, 2]
#
# ID: Student #440526719368505
# Lottery: 3011756946ba4576b42d3e4bc4f4c72e
# Scores: [54.48, 3, 5]
# Policies: [2, 1]
#
# ID: Student #288933568848048
# Lottery: 307ca820607d4b30ad3e7d6aede1b6b8
# Scores: [77.68, 2, 4]
# Policies: [1, 2]
#
# ID: Student #220939080044889
# Lottery: 312aa7603089462e805c68fcf147eebc
# Scores: [69.49, 3, 5]
# Policies: [1, 2]
#
# ID: Student #616538712487521
# Lottery: 315514b8edcc4f9297edf0a67ada8355
# Scores: [72.86, 3, 5]
# Policies: [1, 2]
#
# ID: Student #440267059296904
# Lottery: 317436a67c7d480fbaf43f0dae227eff
# Scores: [68.17, 3, 5]
# Policies: [1, 2]
#
# ID: Student #452310076764115
# Lottery: 322954f4cab94c98861743df279a8779
# Scores: [71.1, 3, 5]
# Policies: [1, 2]
#
# ID: Student #599929149953505
# Lottery: 32609596d89143cfa04547c79a1e451d
# Scores: [64.46, 3, 5]
# Policies: [1, 2]
#
# ID: Student #418788077217692
# Lottery: 3262cb094f724a44a5ce20724a8faf6a
# Scores: [65.8, 3, 5]
# Policies: [1, 2]
#
# ID: Student #104382272450581
# Lottery: 328e9a8c00594bedaeb22f023dc2892d
# Scores: [67.48, 3, 5]
# Policies: [1, 2]
#
# ID: Student #468383414263173
# Lottery: 32cc5fd22377485eb3ae599c8bfee7e4
# Scores: [74.32, 3, 5]
# Policies: [1, 2]
#
# ID: Student #704661468111954
# Lottery: 3349cd7fc5b74f1086c6b2330b1ff515
# Scores: [77.49, 3, 4]
# Policies: [1, 2]
#
# ID: Student #286852435765263
# Lottery: 33d44386e11a4205a2635dbcdff5b53f
# Scores: [79.39, 2, 4]
# Policies: [1, 2]
#
# ID: Student #656134013638699
# Lottery: 34a98f6a71624621bf35000b08be0124
# Scores: [60.08, 3, 5]
# Policies: [1, 2]
#
# ID: Student #340489625717110
# Lottery: 34e4e7e6a29041068a36c4c90038623a
# Scores: [71.1, 3, 5]
# Policies: [1, 2]
#
# ID: Student #31322571481999
# Lottery: 3521d4f055604b76af14068947b0e4c5
# Scores: [63.29, 3, 5]
# Policies: [1, 2]
#
# ID: Student #693233578925001
# Lottery: 3537ef177a9f4198a8714e5667b6613c
# Scores: [62.98, 3, 5]
# Policies: [1, 2]
#
# ID: Student #608588955287479
# Lottery: 35778c04bc814c89a7b303f8310ae0cb
# Scores: [60.08, 3, 5]
# Policies: [1, 2]
#
# ID: Student #310214743672928
# Lottery: 3584d4768abb416289690fc19b7c1822
# Scores: [68.52, 3, 5]
# Policies: [1, 2]
#
# ID: Student #499484194160534
# Lottery: 359d963d0e8b4ad3ae0313510089393f
# Scores: [63.96, 3, 5]
# Policies: [1, 2]
#
# ID: Student #122585266654355
# Lottery: 35d26458b2f64fb5941bb95278d9277f
# Scores: [64.7, 3, 5]
# Policies: [1, 2]
#
# ID: Student #322488845980863
# Lottery: 369485c6cf364d7b85fd02faafa65081
# Scores: [63.38, 3, 5]
# Policies: [1, 2]
#
# ID: Student #499400124437943
# Lottery: 36ae070dc06b49a29cc8f9b56f64dbf8
# Scores: [71.03, 3, 5]
# Policies: [1, 2]
#
# ID: Student #462000963033568
# Lottery: 36b713e7930c45958282bd00e374a386
# Scores: [71.94, 3, 5]
# Policies: [1, 2]
#
# ID: Student #675456124793541
# Lottery: 37035cb1c6e3458692a4b00636e0ed3f
# Scores: [58.23, 3, 5]
# Policies: [1, 2]
#
# ID: Student #452929871232607
# Lottery: 37126b0bddb94193a30d26fc9209a481
# Scores: [50.03, 3, 5]
# Policies: [1, 2]
#
# ID: Student #211239348158805
# Lottery: 375fa0f9b335407682eb0142d7d28819
# Scores: [83.63, 2, 3]
# Policies: [1, 2]
#
# ID: Student #647850241137490
# Lottery: 37c78e60926a42ecbec462a681a7679b
# Scores: [77.2, 3, 4]
# Policies: [2, 1]
#
# ID: Student #524884294343147
# Lottery: 38178a10894c4d40b6cdaae70e3bc2c4
# Scores: [69.05, 3, 5]
# Policies: [1, 2]
#
# ID: Student #336995327166878
# Lottery: 38350a3c27c74a0aada202c67e70455c
# Scores: [57.72, 3, 5]
# Policies: [1, 2]
#
# ID: Student #199513086075698
# Lottery: 38a9ee144fb74be68738527d82ae8f83
# Scores: [70.98, 3, 5]
# Policies: [1, 2]
#
# ID: Student #42763274474830
# Lottery: 38fd18e02c91473fa94ec87bdf616b66
# Scores: [77.55, 2, 4]
# Policies: [1, 2]
#
# ID: Student #286077550283657
# Lottery: 3901728ff3f04536b16d1e630b96acd7
# Scores: [75.58, 3, 5]
# Policies: [1, 2]
#
# ID: Student #177946855859114
# Lottery: 393644f8c5604e19be596b6d193b074a
# Scores: [63.94, 3, 5]
# Policies: [1, 2]
#
# ID: Student #307120188625466
# Lottery: 393e4acbe75c41e6b3e2337c31bc1b93
# Scores: [65.5, 3, 5]
# Policies: [1, 2]
#
# ID: Student #190992512972335
# Lottery: 3a2ee3f684374c18ac11269682bb73db
# Scores: [41.99, 3, 5]
# Policies: [1, 2]
#
# ID: Student #455775963960319
# Lottery: 3a5840f3d30446e6b6c9ce3ef665be18
# Scores: [69.05, 3, 5]
# Policies: [1, 2]
#
# ID: Student #598284165376649
# Lottery: 3a77a99700314055893e83df2646f213
# Scores: [54.55, 3, 5]
# Policies: [1, 2]
#
# ID: Student #363341672502687
# Lottery: 3ac77cac7a9742d3806ae3b51b3660c9
# Scores: [61.75, 3, 5]
# Policies: [1, 2]
#
# ID: Student #334103433891424
# Lottery: 3afa1d473d3748bb86c9c92a848b2637
# Scores: [80.59, 2, 4]
# Policies: [1, 2]
#
# ID: Student #560705251987051
# Lottery: 3b088869ab0144c08135c0eb72c63661
# Scores: [67.94, 3, 5]
# Policies: [1, 2]
#
# ID: Student #146803413127100
# Lottery: 3b141c40b4684ff6925b8d7d6db6138a
# Scores: [69.66, 3, 5]
# Policies: [2, 1]
#
# ID: Student #588654579947715
# Lottery: 3b9e8961e40d490e868887533a114b9b
# Scores: [51.56, 3, 5]
# Policies: [1, 2]
#
# ID: Student #646394457185553
# Lottery: 3bc9a6c78a9e4e7baa0cd13b62e49534
# Scores: [74.98, 3, 5]
# Policies: [1, 2]
#
# ID: Student #6504607842599
# Lottery: 3bcaecfbfe7f4b68ab62108100019154
# Scores: [71.89, 3, 5]
# Policies: [2, 1]
#
# ID: Student #393234112687683
# Lottery: 3c41cec400024563813675e09795c478
# Scores: [66.1, 3, 5]
# Policies: [1, 2]
#
# ID: Student #281487677582856
# Lottery: 3c9f5377f8104679909763ea0086ccda
# Scores: [55.38, 3, 5]
# Policies: [1, 2]
#
# ID: Student #633829173484849
# Lottery: 3ccedc6012bc4126b1e719ee5ffa19ad
# Scores: [54.64, 3, 5]
# Policies: [2, 1]
#
# ID: Student #326805782109275
# Lottery: 3ce694fee13d43dea38301bac8b67009
# Scores: [63.28, 3, 5]
# Policies: [1, 2]
#
# ID: Student #420982696548011
# Lottery: 3cf487b01b9f43f8aeab56fb2ae3bdcd
# Scores: [70.88, 3, 5]
# Policies: [1, 2]
#
# ID: Student #705311548122331
# Lottery: 3d605f4ca78e4fe9b5c641ed5fa87f31
# Scores: [68.14, 3, 5]
# Policies: [1, 2]
#
# ID: Student #671716653699079
# Lottery: 3d8b52d8528547ea9cf86b65ba82d3d4
# Scores: [63.23, 3, 5]
# Policies: [1, 2]
#
# ID: Student #683103532599797
# Lottery: 3db613ec73774d4bbf51f8acd3c438fe
# Scores: [67.79, 3, 5]
# Policies: [1, 2]
#
# ID: Student #289621226012911
# Lottery: 3de1adaa923f4581a918ebd7e23c4d14
# Scores: [73.49, 3, 5]
# Policies: [1, 2]
#
# ID: Student #286074817937452
# Lottery: 3dfad6c8607e402d9e6f349098d34b2e
# Scores: [66.14, 3, 5]
# Policies: [1, 2]
#
# ID: Student #677988092789848
# Lottery: 3e53d9429e454f84b29ed7a51e11e4f7
# Scores: [71.79, 3, 5]
# Policies: [1, 2]
#
# ID: Student #263030146915777
# Lottery: 3e5dbc23006e41d2a81a1ea6f1c8fe64
# Scores: [71.84, 3, 5]
# Policies: [1, 2]
#
# ID: Student #564983675471151
# Lottery: 3e7284976efc44329f19867f9a6e8f81
# Scores: [75.57, 3, 5]
# Policies: [1, 2]
#
# ID: Student #607854014512373
# Lottery: 3e8258d718ef4b01ac58f45e3068e11f
# Scores: [70.93, 3, 5]
# Policies: [1, 2]
#
# ID: Student #376676682248192
# Lottery: 3e995e492e594ff89488d36262ab8de6
# Scores: [76.58, 3, 4]
# Policies: [2, 1]
#
# ID: Student #357079360511461
# Lottery: 3ea58cdf5bc64fd699c60a6d1ab8e163
# Scores: [71.76, 3, 5]
# Policies: [1, 2]
#
# ID: Student #60313270284407
# Lottery: 3f8d8795ae6c42f6b5ca07fc8d89b8ae
# Scores: [56.73, 3, 5]
# Policies: [1, 2]
#
# ID: Student #505014404997291
# Lottery: 3fd3039606da4bdfafbf4d28bd1c9ac9
# Scores: [69.44, 3, 5]
# Policies: [1, 2]
#
# ID: Student #66923256465927
# Lottery: 3ffd8ba911eb42efaddfef8f7812246d
# Scores: [62.12, 3, 5]
# Policies: [1, 2]
#
# ID: Student #652994514768654
# Lottery: 404ab2d424924498bac2f7a56537cba5
# Scores: [72.92, 3, 5]
# Policies: [1, 2]
#
# ID: Student #65045846381165
# Lottery: 407f32eb00054a4c959c1b08b422e796
# Scores: [73.73, 3, 5]
# Policies: [1, 2]
#
# ID: Student #290615734154443
# Lottery: 40aefe37cfe64214a7790b2369ee515f
# Scores: [75.0, 3, 5]
# Policies: [1, 2]
#
# ID: Student #504169573260472
# Lottery: 40c2b070c6f44faeb064e91f9c9af63f
# Scores: [73.8, 3, 5]
# Policies: [1, 2]
#
# ID: Student #159874249959958
# Lottery: 40dba4bd7f344421b8266ca200760f9a
# Scores: [71.14, 3, 5]
# Policies: [1, 2]
#
# ID: Student #142783603557652
# Lottery: 413d581e95414637b51d00215f4edd11
# Scores: [77.2, 3, 4]
# Policies: [1, 2]
#
# ID: Student #650481645754798
# Lottery: 41b4a952dff246dfac1c8e3a223975f3
# Scores: [77.32, 3, 4]
# Policies: [1, 2]
#
# ID: Student #701227317898288
# Lottery: 41fbdbb7cd9a42dbabf78f75a4d0042a
# Scores: [76.98, 3, 4]
# Policies: [1, 2]
#
# ID: Student #133064156849035
# Lottery: 41fe4696d145432e8700ff880051cc6d
# Scores: [73.18, 3, 5]
# Policies: [1, 2]
#
# ID: Student #60905791660393
# Lottery: 42048b77f8d24ad98dfe4e4232720e1a
# Scores: [68.58, 3, 5]
# Policies: [1, 2]
#
# ID: Student #574874261151254
# Lottery: 421a584554a04679a346f50ac6fc6ec5
# Scores: [75.29, 3, 5]
# Policies: [1, 2]
#
# ID: Student #467159689339466
# Lottery: 42381eca0008427f9ba08768bfcad44b
# Scores: [69.04, 3, 5]
# Policies: [2, 1]
#
# ID: Student #634755666144855
# Lottery: 423a2e2251c748f9bafc41b36c5a533b
# Scores: [68.69, 3, 5]
# Policies: [1, 2]
#
# ID: Student #274127196425505
# Lottery: 42402f1b27434495a9dfc6b000007b80
# Scores: [74.98, 3, 5]
# Policies: [2, 1]
#
# ID: Student #376410762500306
# Lottery: 42c29bb00e744a0ea2d6d80ef9dd8f8a
# Scores: [71.42, 3, 5]
# Policies: [1, 2]
#
# ID: Student #317095618988282
# Lottery: 42caf7d100214fc1b2fcff5ea0a6799f
# Scores: [61.13, 3, 5]
# Policies: [1, 2]
#
# ID: Student #464464540211485
# Lottery: 430c5be9a9464726b21e89b83fbfe286
# Scores: [63.19, 3, 5]
# Policies: [1, 2]
#
# ID: Student #238747920788266
# Lottery: 43108fd184dd4b3499e811109e5631e8
# Scores: [62.16, 3, 5]
# Policies: [1, 2]
#
# ID: Student #361997439137895
# Lottery: 4341d9d4001341308febe6789d20119e
# Scores: [78.91, 2, 4]
# Policies: [1, 2]
#
# ID: Student #561086099763344
# Lottery: 435778eb64944d87903fc819be04aaa8
# Scores: [67.75, 3, 5]
# Policies: [1, 2]
#
# ID: Student #160528930809968
# Lottery: 435afa81f6fb4fd69c42529d17387a63
# Scores: [56.27, 3, 5]
# Policies: [1, 2]
#
# ID: Student #239350339521396
# Lottery: 435fba15006645a9b88d56bccbf55748
# Scores: [53.95, 3, 5]
# Policies: [1, 2]
#
# ID: Student #88682680045712
# Lottery: 43a1f641b0754ab7b3a94c49d46c208d
# Scores: [81.16, 2, 4]
# Policies: [1, 2]
#
# ID: Student #201867081089574
# Lottery: 43a420a6643747f7a77aa2a4afba1a4e
# Scores: [68.25, 3, 5]
# Policies: [1, 2]
#
# ID: Student #96155281286591
# Lottery: 43f286b610aa4fc986e97d758cca22a4
# Scores: [65.04, 3, 5]
# Policies: [1, 2]
#
# ID: Student #614701070703613
# Lottery: 442c7baa003d45fda6260ca6d4151bc0
# Scores: [84.17, 2, 3]
# Policies: [1, 2]
#
# ID: Student #629912190796868
# Lottery: 443c591b8d6e4788a188e6a8005d2902
# Scores: [69.19, 3, 5]
# Policies: [1, 2]
#
# ID: Student #562230097398977
# Lottery: 4440dd36baa94064ab3f791386d1edc9
# Scores: [82.01, 2, 4]
# Policies: [1, 2]
#
# ID: Student #180547663434966
# Lottery: 448acdac4c0544c288c8ce10004f460e
# Scores: [60.95, 3, 5]
# Policies: [1, 2]
#
# ID: Student #507741453804274
# Lottery: 449cf4ff690e4496a491e5d800049e30
# Scores: [80.2, 2, 4]
# Policies: [1, 2]
#
# ID: Student #92032020708328
# Lottery: 44ed48d300e443129114843deab5990c
# Scores: [72.37, 3, 5]
# Policies: [1, 2]
#
# ID: Student #569444940525594
# Lottery: 44f910d46dac46f4b8b54694ad6dba18
# Scores: [74.87, 3, 5]
# Policies: [1, 2]
#
# ID: Student #707850566318703
# Lottery: 45f5e800947b435ba29fa543e1c2c01d
# Scores: [75.61, 3, 5]
# Policies: [1, 2]
#
# ID: Student #216637312173388
# Lottery: 460255d174fb4f9bb5bb1104d013e53a
# Scores: [75.92, 3, 5]
# Policies: [1, 2]
#
# ID: Student #403184889720517
# Lottery: 462dff90a07748029293bf91e77ada17
# Scores: [81.71, 2, 4]
# Policies: [1, 2]
#
# ID: Student #125670842336985
# Lottery: 4630d5f6d09b40fba419b4172e582004
# Scores: [70.68, 3, 5]
# Policies: [1, 2]
#
# ID: Student #692626450388396
# Lottery: 465676d0ef44467e915cc68cbf0d2c8e
# Scores: [68.35, 3, 5]
# Policies: [1, 2]
#
# ID: Student #187502322209368
# Lottery: 46a10346a5544238bd288e8d681afa4b
# Scores: [74.37, 3, 5]
# Policies: [1, 2]
#
# ID: Student #12150701909012
# Lottery: 46bde6e7973b45769722e098dbe42388
# Scores: [67.76, 3, 5]
# Policies: [1, 2]
#
# ID: Student #534988998140042
# Lottery: 46c862de004d4a1085527c671c9aa1db
# Scores: [75.88, 3, 5]
# Policies: [1, 2]
#
# ID: Student #395557303867379
# Lottery: 4736b5c20063463fa5aeedcd532b1ad2
# Scores: [67.04, 3, 5]
# Policies: [1, 2]
#
# ID: Student #661209246663210
# Lottery: 4740d990543145079e8b6deb57f1533b
# Scores: [68.38, 3, 5]
# Policies: [1, 2]
#
# ID: Student #594486722841960
# Lottery: 477e283bc3d745b8b2c937cac11e7f5d
# Scores: [74.17, 3, 5]
# Policies: [1, 2]
#
# ID: Student #683132365574931
# Lottery: 479af34387bc416ba8300ef236b1b4e4
# Scores: [42.95, 3, 5]
# Policies: [1, 2]
#
# ID: Student #320248380629905
# Lottery: 47ba893980e343d0af889f740f282a86
# Scores: [67.43, 3, 5]
# Policies: [1, 2]
#
# ID: Student #142605257673216
# Lottery: 47cb1b00d295480a98172a37000119a2
# Scores: [63.46, 3, 5]
# Policies: [2, 1]
#
# ID: Student #581265500291427
# Lottery: 4806ef0efc5646af8dd7ee41764229e4
# Scores: [62.91, 3, 5]
# Policies: [1, 2]
#
# ID: Student #428232054002703
# Lottery: 481750f1b13c4d3bb56b8b362c321ddf
# Scores: [77.15, 3, 4]
# Policies: [2, 1]
#
# ID: Student #385105004595647
# Lottery: 481c24ef137544ea85f958bb860318f8
# Scores: [63.96, 3, 5]
# Policies: [1, 2]
#
# ID: Student #512010686736520
# Lottery: 48c6066dc1954ac19bef194f003a85d3
# Scores: [85.87, 2, 3]
# Policies: [1, 2]
#
# ID: Student #203081037676785
# Lottery: 48f0115edd8b4fb78b8a3667007eb88f
# Scores: [66.89, 3, 5]
# Policies: [1, 2]
#
# ID: Student #111558958635937
# Lottery: 48fa32bc59e143c2855741d1c40c83e7
# Scores: [59.38, 3, 5]
# Policies: [2, 1]
#
# ID: Student #384112902854938
# Lottery: 49247847721244d88114c0e984b656c0
# Scores: [68.12, 3, 5]
# Policies: [1, 2]
#
# ID: Student #332974325439655
# Lottery: 49a086a9227142dba46feeaac9d7ac23
# Scores: [69.63, 3, 5]
# Policies: [1, 2]
#
# ID: Student #515724343732452
# Lottery: 49e39647168d4e038711469b34066a4b
# Scores: [77.96, 2, 4]
# Policies: [1, 2]
#
# ID: Student #618569181978600
# Lottery: 49eaf875d73f4fad80afdf144e524608
# Scores: [58.59, 3, 5]
# Policies: [1, 2]
#
# ID: Student #644904979304625
# Lottery: 4a4d5d313d594f57a9e750e2df290601
# Scores: [73.28, 3, 5]
# Policies: [1, 2]
#
# ID: Student #91136644699498
# Lottery: 4a67b1dd008c49dfa3797a6db9ca492a
# Scores: [63.09, 3, 5]
# Policies: [1, 2]
#
# ID: Student #567686560643943
# Lottery: 4a6c5b3227c7458ba09092b4ebffde85
# Scores: [61.04, 3, 5]
# Policies: [1, 2]
#
# ID: Student #195852135186735
# Lottery: 4a9884b4c8ea45c681b6f83f584479e0
# Scores: [85.94, 2, 3]
# Policies: [1, 2]
#
# ID: Student #241451321648019
# Lottery: 4aaf7f3683d540a4893e7ac9bf68562e
# Scores: [58.64, 3, 5]
# Policies: [1, 2]
#
# ID: Student #280379316468490
# Lottery: 4adae370e3804e0ab6ae3ede68a939af
# Scores: [67.36, 3, 5]
# Policies: [1, 2]
#
# ID: Student #663142608439733
# Lottery: 4b2e24d48cbb4ff9a96498a8ae21a75a
# Scores: [67.01, 3, 5]
# Policies: [2, 1]
#
# ID: Student #225467786911108
# Lottery: 4b4f85c5a8e540418c7092084e3fb514
# Scores: [61.54, 3, 5]
# Policies: [2, 1]
#
# ID: Student #343953315008895
# Lottery: 4b5958555bbd40769e12384f01720c2a
# Scores: [84.74, 2, 3]
# Policies: [1, 2]
#
# ID: Student #607035402505800
# Lottery: 4baa71d368ec4b30aed79f27aa1bd5ca
# Scores: [63.73, 3, 5]
# Policies: [1, 2]
#
# ID: Student #398006562719892
# Lottery: 4bd54ed4002d426eb39387b1a3381b7b
# Scores: [59.51, 3, 5]
# Policies: [1, 2]
#
# ID: Student #361024760822114
# Lottery: 4be16e099e39421eae69f0530003836c
# Scores: [85.35, 2, 3]
# Policies: [2, 1]
#
# ID: Student #238175222817269
# Lottery: 4be40600338d48a593a2ab28f2b53a98
# Scores: [49.68, 3, 5]
# Policies: [1, 2]
#
# ID: Student #642914244955094
# Lottery: 4c540af56b7a4b9bbe8259054c21aa03
# Scores: [66.36, 3, 5]
# Policies: [1, 2]
#
# ID: Student #640438824067435
# Lottery: 4c9f6f1ea3824aebae35f43601380a80
# Scores: [64.77, 3, 5]
# Policies: [1, 2]
#
# ID: Student #143716896488562
# Lottery: 4caf9376be864c5a876fa413928b116d
# Scores: [69.99, 3, 5]
# Policies: [1, 2]
#
# ID: Student #471877729570497
# Lottery: 4cbd5692f6824111b6601060cbf6f314
# Scores: [61.98, 3, 5]
# Policies: [1, 2]
#
# ID: Student #582846819538037
# Lottery: 4cc8d646d6d346ab85027c5183fa3dea
# Scores: [80.93, 2, 4]
# Policies: [1, 2]
#
# ID: Student #78464048046801
# Lottery: 4d3bca02c1544603b8aec89fb9b84ebb
# Scores: [65.47, 3, 5]
# Policies: [1, 2]
#
# ID: Student #156622722396195
# Lottery: 4d746d35267b4cf6ba5b3bb49233406b
# Scores: [52.12, 3, 5]
# Policies: [1, 2]
#
# ID: Student #447591345220965
# Lottery: 4d748969a9df4efa800e4b7f635b28b6
# Scores: [58.69, 3, 5]
# Policies: [1, 2]
#
# ID: Student #174198569527424
# Lottery: 4d8b48311e2045df94d40bb0e3a21900
# Scores: [64.59, 3, 5]
# Policies: [1, 2]
#
# ID: Student #309760949248874
# Lottery: 4dae5fdb5f18447f844ac43070694de5
# Scores: [84.79, 2, 3]
# Policies: [1, 2]
#
# ID: Student #505502368765432
# Lottery: 4e8fe06fe3a14b15b3592e78a21ea349
# Scores: [65.39, 3, 5]
# Policies: [1, 2]
#
# ID: Student #593903336312075
# Lottery: 4f21b4053c8049e1bdbb947a5cc632c6
# Scores: [56.08, 3, 5]
# Policies: [1, 2]
#
# ID: Student #502419611431810
# Lottery: 4f2c817126b449cf8002370d06cc2748
# Scores: [59.49, 3, 5]
# Policies: [2, 1]
#
# ID: Student #626560016781432
# Lottery: 4f30601a33e14bbca535fb49f5d8047d
# Scores: [65.99, 3, 5]
# Policies: [1, 2]
#
# ID: Student #668535574639313
# Lottery: 4f51797a002b4cec8ab923106a462ff6
# Scores: [68.0, 3, 5]
# Policies: [1, 2]
#
# ID: Student #225902253629436
# Lottery: 4f63bc5366f3430996c854fb30c71232
# Scores: [51.32, 3, 5]
# Policies: [1, 2]
#
# ID: Student #607694662581851
# Lottery: 4f672b131770438b9212e4580066036a
# Scores: [61.58, 3, 5]
# Policies: [1, 2]
#
# ID: Student #154526191673666
# Lottery: 4f9ce6a034f448ee853c9a1600078618
# Scores: [58.83, 3, 5]
# Policies: [2, 1]
#
# ID: Student #117982754095110
# Lottery: 4fd2a5cbcf544e3498729ebf0075b025
# Scores: [57.55, 3, 5]
# Policies: [1, 2]
#
# ID: Student #15805282128910
# Lottery: 5086e6d3e1e6401ea3aad92f3a8b19ef
# Scores: [67.05, 3, 5]
# Policies: [1, 2]
#
# ID: Student #187726253339153
# Lottery: 509438d5edc94b5d8f6f8fdfbd1cb50c
# Scores: [83.75, 2, 3]
# Policies: [1, 2]
#
# ID: Student #498769553364020
# Lottery: 50a163536103450b8ef2bc0b00226071
# Scores: [67.84, 3, 5]
# Policies: [1, 2]
#
# ID: Student #423277095291902
# Lottery: 50e9841362144ad2ab663c88bf3d2382
# Scores: [61.25, 3, 5]
# Policies: [1, 2]
#
# ID: Student #457710699416267
# Lottery: 51040e91095742f2808458400072f52b
# Scores: [69.34, 3, 5]
# Policies: [1, 2]
#
# ID: Student #294674928460536
# Lottery: 513bc915bd704e09b9bc2029ccebdf22
# Scores: [70.03, 3, 5]
# Policies: [1, 2]
#
# ID: Student #366859037237772
# Lottery: 5162b876416f480abec10b520081cb70
# Scores: [59.31, 3, 5]
# Policies: [1, 2]
#
# ID: Student #282009307231533
# Lottery: 5163520091664201be0b5b9573c69b31
# Scores: [71.65, 3, 5]
# Policies: [1, 2]
#
# ID: Student #558808552570003
# Lottery: 51958cae6aae4d19a00220026be9ffa3
# Scores: [69.56, 3, 5]
# Policies: [1, 2]
#
# ID: Student #451027120081324
# Lottery: 519e0ea4bb0849d29f51c38c14b7329b
# Scores: [79.54, 2, 4]
# Policies: [1, 2]
#
# ID: Student #580257575157909
# Lottery: 51a7ce1777f44e8fbbd52982296e8d73
# Scores: [77.18, 3, 4]
# Policies: [1, 2]
#
# ID: Student #622250253627976
# Lottery: 51be8308ada14a809581d8f16bc18a4f
# Scores: [72.66, 3, 5]
# Policies: [1, 2]
#
# ID: Student #324885246442779
# Lottery: 51c64d2b6d6d4677a6f367a428c0570c
# Scores: [66.71, 3, 5]
# Policies: [1, 2]
#
# ID: Student #445922535990448
# Lottery: 51f5d4589bce446e8dd9d59afb040fcd
# Scores: [71.86, 3, 5]
# Policies: [1, 2]
#
# ID: Student #235904587267849
# Lottery: 5248d7d77f774533802dd597c0d38c0f
# Scores: [74.03, 3, 5]
# Policies: [1, 2]
#
# ID: Student #202076365136351
# Lottery: 52aa245fa637462284baadff45b729c4
# Scores: [67.74, 3, 5]
# Policies: [1, 2]
#
# ID: Student #494410600878829
# Lottery: 5303eb798bd644a48085b59b26471cb3
# Scores: [69.84, 3, 5]
# Policies: [1, 2]
#
# ID: Student #322440728170597
# Lottery: 535d8ea7968546d5a0312aa2e833c0b9
# Scores: [71.12, 3, 5]
# Policies: [1, 2]
#
# ID: Student #103106392181251
# Lottery: 5371ddc541094fd4ab2b20e14bf2fea1
# Scores: [76.32, 3, 5]
# Policies: [1, 2]
#
# ID: Student #55136994109927
# Lottery: 5391078986444960a691e4e59eefd307
# Scores: [79.66, 2, 4]
# Policies: [1, 2]
#
# ID: Student #110161117661825
# Lottery: 53db145e0052484c921b1c4c47cd1ae4
# Scores: [76.22, 3, 5]
# Policies: [1, 2]
#
# ...
# Scores: [54.64, 3, 5]
# Policies: [1, 2]
#
# ID: Student #710214002925069
# Lottery: e15aa7c3723b4c4bbe12ac1f109bec22
# Scores: [80.22, 2, 4]
# Policies: [1, 2]
#
# ID: Student #711528259488801
# Lottery: e1621d00c18241c0ac172c5afc58c194
# Scores: [67.83, 3, 5]
# Policies: [1, 2]
#
# ID: Student #354144642385181
# Lottery: e16dc40e22c942558052def097c17a88
# Scores: [72.6, 3, 5]
# Policies: [1, 2]
#
# ID: Student #165396601877016
# Lottery: e1aa1c3375dd477f9280fdd9389b9e50
# Scores: [62.35, 3, 5]
# Policies: [1, 2]
#
# ID: Student #609173477073837
# Lottery: e1cfb7e904f04971a2ca3292843918d2
# Scores: [59.91, 3, 5]
# Policies: [1, 2]
#
# ID: Student #211881860920135
# Lottery: e1d5289a599e495f8ffd8961dcf448b7
# Scores: [74.3, 3, 5]
# Policies: [1, 2]
#
# ID: Student #538128813440938
# Lottery: e2b4526bc5754a54a1d534dfb15f5504
# Scores: [79.67, 2, 4]
# Policies: [1, 2]
#
# ID: Student #214903647220438
# Lottery: e3107d4322b64fb3a0df38ccd0f3592b
# Scores: [91.68, 1, 2]
# Policies: [1, 2]
#
# ID: Student #537843230004042
# Lottery: e32cafd5b1a34ca1b2d3ee7c74f17ad9
# Scores: [78.63, 2, 4]
# Policies: [2, 1]
#
# ID: Student #418084594395235
# Lottery: e3329d7443344ceb82e14809f95cb5c7
# Scores: [58.83, 3, 5]
# Policies: [1, 2]
#
# ID: Student #150066737042647
# Lottery: e34a0b242fce4c2dacc729cc97a7a406
# Scores: [75.16, 3, 5]
# Policies: [1, 2]
#
# ID: Student #95023385459846
# Lottery: e38c4a7400094f858c421e6580bf6f95
# Scores: [80.84, 2, 4]
# Policies: [2, 1]
#
# ID: Student #605728564720408
# Lottery: e3cfd98c9e104f6fbd1c74d0eae43615
# Scores: [42.17, 3, 5]
# Policies: [2, 1]
#
# ID: Student #156854979891074
# Lottery: e4424551651b4559a310c54387cfe33e
# Scores: [59.74, 3, 5]
# Policies: [2, 1]
#
# ID: Student #324234183634557
# Lottery: e462f45e0ba148d1bd7fd9fcc60d3510
# Scores: [64.16, 3, 5]
# Policies: [2, 1]
#
# ID: Student #297473615795527
# Lottery: e4950582304e4318b7b43ec33d0b714a
# Scores: [77.31, 3, 4]
# Policies: [1, 2]
#
# ID: Student #608901315150703
# Lottery: e4a6a01204774f09a755c6789b28f0ae
# Scores: [64.68, 3, 5]
# Policies: [1, 2]
#
# ID: Student #172716408014894
# Lottery: e4e0227ab887463ebf484da7fd412bac
# Scores: [62.96, 3, 5]
# Policies: [1, 2]
#
# ID: Student #80866309470192
# Lottery: e56712b0a99e44748a6edebd197e2584
# Scores: [73.99, 3, 5]
# Policies: [1, 2]
#
# ID: Student #573557091764140
# Lottery: e579db12968b4484a45628e586c22779
# Scores: [64.68, 3, 5]
# Policies: [1, 2]
#
# ID: Student #590716092074426
# Lottery: e594986a840f490c9ebcaf623d6cfed5
# Scores: [62.23, 3, 5]
# Policies: [1, 2]
#
# ID: Student #328455067974144
# Lottery: e5b3cb47b5434d0d83ad8440000e6cb3
# Scores: [74.39, 3, 5]
# Policies: [2, 1]
#
# ID: Student #426181806862976
# Lottery: e5b575f1f28647d993e025b670ce3a77
# Scores: [76.49, 3, 4]
# Policies: [1, 2]
#
# ID: Student #317624951201703
# Lottery: e5def7bfbc8e452da35ff167d81e4ad7
# Scores: [66.77, 3, 5]
# Policies: [1, 2]
#
# ID: Student #295251789694590
# Lottery: e6314ea5eac3432b918720db83ef53f6
# Scores: [67.24, 3, 5]
# Policies: [1, 2]
#
# ID: Student #614202622353002
# Lottery: e699b76e284d464181a464ce7d4e632f
# Scores: [79.6, 2, 4]
# Policies: [1, 2]
#
# ID: Student #198252018548515
# Lottery: e6dc879691704d90a89d1f190991f36f
# Scores: [80.16, 2, 4]
# Policies: [1, 2]
#
# ID: Student #402448997465341
# Lottery: e72fea69f74442d3b6c843a0d8056cc3
# Scores: [57.74, 3, 5]
# Policies: [1, 2]
#
# ID: Student #671998388919655
# Lottery: e79a6591c5e0430094939731fbfa0170
# Scores: [65.16, 3, 5]
# Policies: [1, 2]
#
# ID: Student #524110020403571
# Lottery: e7c30e0343d94f7187268ddb8536d87a
# Scores: [61.54, 3, 5]
# Policies: [1, 2]
#
# ID: Student #404273059433668
# Lottery: e7f2eefd34844f1b8126b6e71e80b522
# Scores: [82.76, 2, 3]
# Policies: [1, 2]
#
# ID: Student #485268688252405
# Lottery: e7fca9cd743c42fc8a8b12630002dcac
# Scores: [78.97, 2, 4]
# Policies: [2, 1]
#
# ID: Student #478174983054893
# Lottery: e81b83a87e774bde8a15945a9c65be4a
# Scores: [75.56, 3, 5]
# Policies: [1, 2]
#
# ID: Student #577640181528232
# Lottery: e82d897553224e4ca0c08fcb0038560c
# Scores: [81.99, 2, 4]
# Policies: [1, 2]
#
# ID: Student #670864466055543
# Lottery: e82e7169e4164a3c84ceac7c004f67d0
# Scores: [73.52, 3, 5]
# Policies: [1, 2]
#
# ID: Student #56119363213835
# Lottery: e8a00d2ee5b14d708d286b4eadfd5b03
# Scores: [66.62, 3, 5]
# Policies: [1, 2]
#
# ID: Student #266373643703971
# Lottery: e8b989456fad40e897d8996cb8e6f77d
# Scores: [73.36, 3, 5]
# Policies: [2, 1]
#
# ID: Student #530008114252375
# Lottery: e8d95dfe5a2e4bfb8265839600039e4e
# Scores: [61.52, 3, 5]
# Policies: [2, 1]
#
# ID: Student #67690365342875
# Lottery: e928068972264aa296b33a5de2b61c02
# Scores: [64.52, 3, 5]
# Policies: [1, 2]
#
# ID: Student #317718663818018
# Lottery: e94049ca4c98477c86cf4ae8b9a7688a
# Scores: [74.69, 3, 5]
# Policies: [1, 2]
#
# ID: Student #503370887053481
# Lottery: e945485cfe9e48a69f54973a3eb2e93b
# Scores: [69.03, 3, 5]
# Policies: [1, 2]
#
# ID: Student #299346336781914
# Lottery: e9544a905f424046b44298a2558205c5
# Scores: [60.09, 3, 5]
# Policies: [1, 2]
#
# ID: Student #554538056757205
# Lottery: ea005bde001f4f68b158f4033343b718
# Scores: [69.37, 3, 5]
# Policies: [1, 2]
#
# ID: Student #292642686298249
# Lottery: ea076b02d43045f684c473ccea97d822
# Scores: [68.78, 3, 5]
# Policies: [1, 2]
#
# ID: Student #690368725730953
# Lottery: ea259dcf14b7476ab36ae81dd9f53b5d
# Scores: [72.04, 3, 5]
# Policies: [1, 2]
#
# ID: Student #94581266357030
# Lottery: ea3098bcbd80449db9622b5a46e25e6f
# Scores: [61.69, 3, 5]
# Policies: [1, 2]
#
# ID: Student #662946590004839
# Lottery: ea6af467004541d6bf231ea6bde456c3
# Scores: [88.85, 1, 3]
# Policies: [1, 2]
#
# ID: Student #287844645525309
# Lottery: eaf883daf042441490865a4b97bb06d9
# Scores: [76.17, 3, 5]
# Policies: [1, 2]
#
# ID: Student #588030386613106
# Lottery: eb5f7f4d9ce24cb5b2ffd9b98f6f77e8
# Scores: [80.63, 2, 4]
# Policies: [2, 1]
#
# ID: Student #577759128075912
# Lottery: eb7ca6b167dc465d881198fe9e9f24c6
# Scores: [69.95, 3, 5]
# Policies: [1, 2]
#
# ID: Student #276784731848545
# Lottery: eb8e1ca6c6be44749117e8a7ab9ae47f
# Scores: [60.59, 3, 5]
# Policies: [1, 2]
#
# ID: Student #222124015172462
# Lottery: eb8e810bd2b74f3e85991f2600345ab1
# Scores: [68.63, 3, 5]
# Policies: [1, 2]
#
# ID: Student #528733146876779
# Lottery: ebafaaf292fa487782d9fdc100866ec5
# Scores: [80.83, 2, 4]
# Policies: [1, 2]
#
# ID: Student #313773320147499
# Lottery: ebbebb470cbe4a678dbbbb30c132b7bb
# Scores: [90.65, 1, 2]
# Policies: [1, 2]
#
# ID: Student #221048124109920
# Lottery: ebe975f7f3194a3ab8e13439e71ec82a
# Scores: [52.43, 3, 5]
# Policies: [1, 2]
#
# ID: Student #588735378320342
# Lottery: ecc18b2f98c647ea84b87eff1d0ae2d6
# Scores: [84.62, 2, 3]
# Policies: [1, 2]
#
# ID: Student #62773900639418
# Lottery: ecca7192d88545db85067e198e6548a9
# Scores: [67.97, 3, 5]
# Policies: [1, 2]
#
# ID: Student #32716634185756
# Lottery: ecf3faa092324a82b51db75ae786ec47
# Scores: [58.05, 3, 5]
# Policies: [1, 2]
#
# ID: Student #614510512075093
# Lottery: ed80dcb015794e77abc4291a92f01796
# Scores: [68.33, 3, 5]
# Policies: [1, 2]
#
# ID: Student #184537349015564
# Lottery: eda2369a0a4a45c5818dc616ea594bc0
# Scores: [67.39, 3, 5]
# Policies: [1, 2]
#
# ID: Student #537812384646882
# Lottery: ee287fcd2e8a45259afa0166c5ec7a4e
# Scores: [47.93, 3, 5]
# Policies: [1, 2]
#
# ID: Student #400275699430583
# Lottery: ee2d7add70994160b21ed40dc8dfba2c
# Scores: [64.76, 3, 5]
# Policies: [1, 2]
#
# ID: Student #398985320221504
# Lottery: ee5cdf8900134e34a00d0dbcb358ca02
# Scores: [84.44, 2, 3]
# Policies: [1, 2]
#
# ID: Student #327403041423860
# Lottery: ee6381bfab8348d2a1ad0eadfdbb4c4a
# Scores: [73.8, 3, 5]
# Policies: [1, 2]
#
# ID: Student #279302725323957
# Lottery: ee8462996ee24993a01e369b0426fd28
# Scores: [67.87, 3, 5]
# Policies: [1, 2]
#
# ID: Student #173821005632548
# Lottery: eec1090c0c7a4131893cdea87fadae69
# Scores: [51.51, 3, 5]
# Policies: [1, 2]
#
# ID: Student #309425971476601
# Lottery: eece50c41d1c49af924c039458ca38cb
# Scores: [60.07, 3, 5]
# Policies: [1, 2]
#
# ID: Student #173162154845780
# Lottery: ef14122a54ba4b00af1fbb9e6e0ffc98
# Scores: [71.97, 3, 5]
# Policies: [1, 2]
#
# ID: Student #294733373716395
# Lottery: ef2ed841bc1843949c5a48969c76e223
# Scores: [69.5, 3, 5]
# Policies: [1, 2]
#
# ID: Student #576411405280480
# Lottery: ef6b10622a6d465f9bef9efd004f8279
# Scores: [56.14, 3, 5]
# Policies: [1, 2]
#
# ID: Student #246639313431340
# Lottery: ef6fce30e6694e8f8ec94ba31c04f44c
# Scores: [66.54, 3, 5]
# Policies: [1, 2]
#
# ID: Student #642315750730974
# Lottery: ef7076aa95ed4fadbc06d09e4e4db970
# Scores: [53.02, 3, 5]
# Policies: [1, 2]
#
# ID: Student #462367526699958
# Lottery: ef90df8259944ef48d82cde56ec1ed15
# Scores: [74.42, 3, 5]
# Policies: [1, 2]
#
# ID: Student #489581097756316
# Lottery: f013f71a7a3041a199441a1f26a8a59c
# Scores: [58.74, 3, 5]
# Policies: [1, 2]
#
# ID: Student #339958491832966
# Lottery: f02e7d9a006043caaf7d1f1825c95381
# Scores: [62.44, 3, 5]
# Policies: [1, 2]
#
# ID: Student #61431518557781
# Lottery: f0d97c6d006f42959c736d0b29679864
# Scores: [64.63, 3, 5]
# Policies: [1, 2]
#
# ID: Student #485928028886515
# Lottery: f0f5a01221494982afe310edbccbfc7b
# Scores: [68.14, 3, 5]
# Policies: [1, 2]
#
# ID: Student #590373762561355
# Lottery: f0fe992c7dd844e0b0f26a65fcb67776
# Scores: [73.08, 3, 5]
# Policies: [1, 2]
#
# ID: Student #369827236605141
# Lottery: f129cb94942a44c6bcac63326d7a8955
# Scores: [62.08, 3, 5]
# Policies: [1, 2]
#
# ID: Student #486910704045059
# Lottery: f12efc708ac6497ab77eba118a982dc8
# Scores: [56.4, 3, 5]
# Policies: [1, 2]
#
# ID: Student #701489289625715
# Lottery: f147dc7b4eb9444c8b4568e4dec41f39
# Scores: [70.94, 3, 5]
# Policies: [1, 2]
#
# ID: Student #358616582596487
# Lottery: f155d20f7ebe4560a2aca1539ae03a18
# Scores: [70.14, 3, 5]
# Policies: [1, 2]
#
# ID: Student #373566218358391
# Lottery: f2211bb203bd4b51bfdeaa44e4ebd06d
# Scores: [72.21, 3, 5]
# Policies: [1, 2]
#
# ID: Student #333191792266035
# Lottery: f2e0bc354df64716910fe0d30befe1c2
# Scores: [57.42, 3, 5]
# Policies: [1, 2]
#
# ID: Student #381592636755283
# Lottery: f32aa06f6f224137b0f2c0294d89bef5
# Scores: [65.64, 3, 5]
# Policies: [1, 2]
#
# ID: Student #163368640974201
# Lottery: f3a8532eaf2a45abb4feca6187c5de09
# Scores: [73.92, 3, 5]
# Policies: [1, 2]
#
# ID: Student #315458045133344
# Lottery: f3d648e9addd47f49b723adc42e7b5ba
# Scores: [71.18, 3, 5]
# Policies: [2, 1]
#
# ID: Student #605942280014136
# Lottery: f3df7a48f2ab49df9c3d269a0404a143
# Scores: [62.92, 3, 5]
# Policies: [1, 2]
#
# ID: Student #588501076754926
# Lottery: f3e53935486e4fe6af58cefc86580dc0
# Scores: [69.95, 3, 5]
# Policies: [1, 2]
#
# ID: Student #333655011990641
# Lottery: f46318c11bf24296809fdd2817845681
# Scores: [83.13, 2, 3]
# Policies: [1, 2]
#
# ID: Student #114176568943749
# Lottery: f496f3f1003444d8bb3b55eafe301fa4
# Scores: [76.7, 3, 4]
# Policies: [1, 2]
#
# ID: Student #6044568156879
# Lottery: f4f8bc12002b4308aded138db2ce69fe
# Scores: [66.35, 3, 5]
# Policies: [1, 2]
#
# ID: Student #337484953108025
# Lottery: f51d913f8ff0448882758cb61e6ce1ef
# Scores: [71.62, 3, 5]
# Policies: [1, 2]
#
# ID: Student #521416080961469
# Lottery: f555b93f005f47a0a6cb5b6b64d5dd0f
# Scores: [68.8, 3, 5]
# Policies: [1, 2]
#
# ID: Student #644886024923793
# Lottery: f57269989985439f94fadaad00675352
# Scores: [71.78, 3, 5]
# Policies: [1, 2]
#
# ID: Student #84522400398245
# Lottery: f5a731dfe42544229407b9cd2162b75a
# Scores: [55.89, 3, 5]
# Policies: [1, 2]
#
# ID: Student #219427132973370
# Lottery: f5dc6a0f21de47b0ac21db576de61f3b
# Scores: [53.7, 3, 5]
# Policies: [1, 2]
#
# ID: Student #441723127109088
# Lottery: f5dfd078007f44c9adc65edc294d88c9
# Scores: [91.26, 1, 2]
# Policies: [1, 2]
#
# ID: Student #337134334451281
# Lottery: f6633c25915d4f3fa70f0b4ad999bc31
# Scores: [70.96, 3, 5]
# Policies: [1, 2]
#
# ID: Student #216158515271515
# Lottery: f6c1c19739ab456b8bd708cc7daf7909
# Scores: [72.65, 3, 5]
# Policies: [1, 2]
#
# ID: Student #228945888246405
# Lottery: f6d640d270ca4aeba082d493996121fe
# Scores: [69.79, 3, 5]
# Policies: [1, 2]
#
# ID: Student #542427424929985
# Lottery: f6ecd1bff1084d409d4532a8b4515314
# Scores: [59.91, 3, 5]
# Policies: [2, 1]
#
# ID: Student #83172042068834
# Lottery: f6f06bfec10c40688174874e14b7caff
# Scores: [62.87, 3, 5]
# Policies: [1, 2]
#
# ID: Student #682407164157230
# Lottery: f7290ab8de6b4fa9959694d1f45be83b
# Scores: [76.23, 3, 5]
# Policies: [1, 2]
#
# ID: Student #462348243702195
# Lottery: f7476bf397e041d8a64b7bca4cfaf9a6
# Scores: [80.99, 2, 4]
# Policies: [1, 2]
#
# ID: Student #404628368673513
# Lottery: f85bedbb17f3454392debf220e2a21ba
# Scores: [60.93, 3, 5]
# Policies: [1, 2]
#
# ID: Student #570667989094208
# Lottery: f87c7a4725f347fd8430f79f2d5ce69b
# Scores: [68.22, 3, 5]
# Policies: [2, 1]
#
# ID: Student #165715560240309
# Lottery: f8bda2b124914ee799599372b981e6eb
# Scores: [72.77, 3, 5]
# Policies: [1, 2]
#
# ID: Student #535872461612689
# Lottery: f94d718f25074743a61517d09c3edd87
# Scores: [65.33, 3, 5]
# Policies: [1, 2]
#
# ID: Student #128544070811982
# Lottery: f9932cff0c334381815e09b5abae2c19
# Scores: [77.85, 2, 4]
# Policies: [1, 2]
#
# ID: Student #211206622395001
# Lottery: f9f10c0102c443798733dbc6006f4520
# Scores: [62.76, 3, 5]
# Policies: [1, 2]
#
# ID: Student #621669986909581
# Lottery: fae623c55fd445899f95fa37b3766b66
# Scores: [77.15, 3, 4]
# Policies: [1, 2]
#
# ID: Student #213854931433746
# Lottery: faf3f051677a4cee98220666e8a23eaf
# Scores: [61.68, 3, 5]
# Policies: [1, 2]
#
# ID: Student #127883534090386
# Lottery: fb0c30ec11654067ae7f87c4133355f5
# Scores: [77.96, 2, 4]
# Policies: [1, 2]
#
# ID: Student #630966209636146
# Lottery: fb8f9fdb326a462fae865f0e4f509841
# Scores: [62.41, 3, 5]
# Policies: [1, 2]
#
# ID: Student #414238595061736
# Lottery: fbacbd4d3ad040d7a277333f00423de2
# Scores: [73.03, 3, 5]
# Policies: [1, 2]
#
# ID: Student #73529641716648
# Lottery: fbc0a1a8007c4baa8333fe4f64ab0fcc
# Scores: [73.57, 3, 5]
# Policies: [1, 2]
#
# ID: Student #693300199508451
# Lottery: fbd74e1ae1a446a999f5782c653b0af2
# Scores: [75.87, 3, 5]
# Policies: [1, 2]
#
# ID: Student #403992879622608
# Lottery: fbe93e89855a46ab80af1c83c66110eb
# Scores: [69.62, 3, 5]
# Policies: [1, 2]
#
# ID: Student #427121837454535
# Lottery: fc1c5870dd204975b2cf32ed94bc2e06
# Scores: [63.17, 3, 5]
# Policies: [1, 2]
#
# ID: Student #480990735126536
# Lottery: fc43480583014a679985f229ce58b07d
# Scores: [62.95, 3, 5]
# Policies: [2, 1]
#
# ID: Student #4549213636387
# Lottery: fc6c4cd4509948c4b0a2868c00430c79
# Scores: [81.01, 2, 4]
# Policies: [1, 2]
#
# ID: Student #593679930709772
# Lottery: fc700bdf10f1403e9987a498d729f721
# Scores: [71.05, 3, 5]
# Policies: [2, 1]
#
# ID: Student #125174857859473
# Lottery: fcb4b4b0149b4ab6a11f8fe69025a973
# Scores: [73.12, 3, 5]
# Policies: [2, 1]
#
# ID: Student #621977652547931
# Lottery: fd1e63260eef45a9ada354bba5262d5b
# Scores: [70.31, 3, 5]
# Policies: [2, 1]
#
# ID: Student #416890133700071
# Lottery: fd6629c4d65c41e29bb97f84004bcd60
# Scores: [79.85, 2, 4]
# Policies: [1, 2]
#
# ID: Student #608057241974327
# Lottery: fd709da038f64a9694c8f476c227bc79
# Scores: [71.83, 3, 5]
# Policies: [1, 2]
#
# ID: Student #393350733540409
# Lottery: fe14062f7bef4d06b1b6a2aa966a0b73
# Scores: [71.29, 3, 5]
# Policies: [1, 2]
#
# ID: Student #430899501894617
# Lottery: fe147fd83ed34f3a92d0a66a318b7a4f
# Scores: [70.65, 3, 5]
# Policies: [1, 2]
#
# ID: Student #520095169413248
# Lottery: fe1ad41885574b8f948395040fdcc844
# Scores: [78.34, 2, 4]
# Policies: [1, 2]
#
# ID: Student #429506230226405
# Lottery: fe6613ee99de490999a2c34f4337ddd2
# Scores: [52.62, 3, 5]
# Policies: [1, 2]
#
# ID: Student #70045636534337
# Lottery: fe7903218c4549b18aa5b1baadfe52f9
# Scores: [69.62, 3, 5]
# Policies: [1, 2]
#
# ID: Student #349137267987521
# Lottery: fe82e4e35cc14b2bb818a182d018f7a0
# Scores: [54.87, 3, 5]
# Policies: [2, 1]
#
# ID: Student #133192529926724
# Lottery: feb1bd08c7d84a1b81125868ed49c694
# Scores: [70.66, 3, 5]
# Policies: [2, 1]
#
# ID: Student #101249185464031
# Lottery: fec78a4052fb4b5bb5170c9e530c0838
# Scores: [56.36, 3, 5]
# Policies: [1, 2]
#
# ID: Student #528724663528664
# Lottery: ff40f3e2879247e196562121cdcbe4ad
# Scores: [80.48, 2, 4]
# Policies: [1, 2]
#
# ID: Student #226587418061400
# Lottery: ff4901eeb26f4323952457c64fb5f20b
# Scores: [78.41, 2, 4]
# Policies: [1, 2]
#
# ID: Student #628437972611951
# Lottery: ff6c84bde72e4f0f9998c89200be8b4d
# Scores: [80.03, 2, 4]
# Policies: [1, 2]
#
# ID: Student #461714011744094
# Lottery: ff70b9c07da14f7b8702bf349b35670a
# Scores: [60.99, 3, 5]
# Policies: [1, 2]
#
# ID: Student #274828463435637
# Lottery: ff7d1ff42c2e44c6bd2f7b3dc536418a
# Scores: [70.33, 3, 5]
# Policies: [1, 2]
#
# ID: Student #335443690450172
# Lottery: ff86ef69844a49009eec0d82bccc0330
# Scores: [77.38, 3, 4]
# Policies: [1, 2]
#
# ID: Student #499746961932350
# Lottery: ffbcd76307934e8c99e3e9978af48a47
# Scores: [62.06, 3, 5]
# Policies: [1, 2]
#
# ID: Student #529543079538360
# Lottery: ffbd6d386fb54664b7dacdf4178d9db9
# Scores: [65.2, 3, 5]
# Policies: [1, 2]
#
# ID: Student #474149687261043
# Lottery: ffdd4c5beef4426991d1b6f7dba78fc4
# Scores: [74.18, 3, 5]
# Policies: [1, 2]

# %%
# SAVE RESULTS
newpath = cwd + "/Data/Generated/simulation_results_rs" + str(simstate)
if not os.path.exists(newpath):
    os.makedirs(newpath)

np.save(newpath+"/student_rankings.npy", student_prefs)
np.save(newpath+"/school_rankings.npy", school_prefs)

list_students = dict([[str(stud), stud.to_list()] for stud in students.values()])
np.save(newpath+"/student_info.npy", list_students)
list_schools = dict([[str(schol), schol.to_list()] for schol in schools.values()])
np.save(newpath+"/school_info.npy", list_schools)
    
print("Simulation state", simstate, "saved at\n", newpath+'/')
# Out:
# Simulation state 1 saved at
#  /Users/korahughes/Documents/GitHub/DataLife/BackEnd/Data/Generated/simulation_results_rs1/

# %% [markdown]
# #  LEGACY CODE (can ignore if you're not a developer)
#
#
#
# # Task 1) Load student demographics and preferences

# %%
student_df = pd.read_csv(cwd+"/Data/student_info_with_demographics.csv")
student_df
# Out:
#           Student_Id          Residential_District  swd  poverty  sex  ell  \
# 0      student_36332  Residential District Unknown    0        0    1    0
# 1      student_36144  Residential District Unknown    0        1    0    0
# 2      student_37038  Residential District Unknown    1        1    1    0
# 3        student_614  Residential District Unknown    0        0    1    0
# 4      student_21981  Residential District Unknown    1        0    1    0
# ...              ...                           ...  ...      ...  ...  ...
# 71245  student_22462       Residential District 01    0        0    1    0
# 71246  student_30857       Residential District 01    1        0    1    0
# 71247  student_57833       Residential District 01    0        0    0    0
# 71248  student_32259       Residential District 01    0        1    0    0
# 71249  student_68963       Residential District 01    1        0    1    0
#
#          ENI  Black  Hispanic  Multi-Racial  White  Asian  Native American  \
# 0      0.723      0         1             0      0      0                0
# 1      0.684      0         1             0      0      0                0
# 2      0.881      0         1             0      0      0                0
# 3      0.191      0         0             0      1      0                0
# 4      0.304      0         0             0      1      0                0
# ...      ...    ...       ...           ...    ...    ...              ...
# 71245  0.650      0         1             0      0      0                0
# 71246  0.621      0         0             0      0      1                0
# 71247  0.256      1         0             0      0      0                0
# 71248  0.950      0         0             0      0      1                0
# 71249  0.630      0         1             0      0      0                0
#
#        Missing Race/Ethnicity Data  school  Math_score  ELA_score
# 0                                0  30Q127    2.000000   3.125000
# 1                                0  27Q137    2.153846   2.750000
# 2                                0  24Q061    2.846154   1.753425
# 3                                0  02M114    4.275862   4.181818
# 4                                0  02M312    4.017241   3.125000
# ...                            ...     ...         ...        ...
# 71245                            0  01M450    2.000000   1.972603
# 71246                            0  01M184    3.000000   3.125000
# 71247                            0  01M539    2.615385   4.030303
# 71248                            0  01M188    3.083333   2.000000
# 71249                            0  01M839    2.692308   2.312500
#
# [71250 rows x 17 columns]

# %%
student_df.describe()
# Out:
#                 swd       poverty           sex           ell           ENI  \
# count  71250.000000  71250.000000  71250.000000  71250.000000  71250.000000
# mean       0.218709      0.753839      0.490021      0.136730      0.713503
# std        0.413373      0.430777      0.499904      0.343564      0.188389
# min        0.000000      0.000000      0.000000      0.000000      0.136000
# 25%        0.000000      1.000000      0.000000      0.000000      0.600000
# 50%        0.000000      1.000000      0.000000      0.000000      0.755000
# 75%        0.000000      1.000000      1.000000      0.000000      0.869000
# max        1.000000      1.000000      1.000000      1.000000      0.950000
#
#               Black      Hispanic  Multi-Racial         White         Asian  \
# count  71250.000000  71250.000000  71250.000000  71250.000000  71250.000000
# mean       0.225937      0.426765      0.011775      0.147804      0.173389
# std        0.418201      0.494611      0.107875      0.354908      0.378586
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      1.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        Native American  Missing Race/Ethnicity Data    Math_score  \
# count     71250.000000                 71250.000000  71250.000000
# mean          0.011663                     0.002667      2.648380
# std           0.107365                     0.051571      0.902626
# min           0.000000                     0.000000      1.000000
# 25%           0.000000                     0.000000      1.893333
# 50%           0.000000                     0.000000      2.384615
# 75%           0.000000                     0.000000      3.416667
# max           1.000000                     1.000000      4.500000
#
#           ELA_score      fake_gpa          seat        screen
# count  71250.000000  71250.000000  71250.000000  71250.000000
# mean       2.976645      2.509633      1.994063      2.995116
# std        0.869921      0.638444      0.815440      1.411225
# min        1.054795      1.200000      1.000000      1.000000
# 25%        2.125000      1.970000      1.000000      2.000000
# 50%        3.000000      2.470000      2.000000      3.000000
# 75%        3.875000      2.970000      3.000000      4.000000
# max        4.500000      4.000000      3.000000      5.000000

# %%
ranking_df = pd.read_csv(cwd + "/Data/student_prefs.csv")
ranking_df
# Out:
#            Student_Id  School  Rank    Rating
# 0       student_68963  02M411     0  1.000000
# 1       student_68963  02M376     1  0.500000
# 2       student_68963  02M316     2  0.333333
# 3       student_68963  02M438     3  0.250000
# 4       student_68963  01M448     4  0.200000
# ...               ...     ...   ...       ...
# 492363  student_36332  02M414     2  0.333333
# 492364  student_36332  20K490     3  0.250000
# 492365  student_36332  18K637     4  0.200000
# 492366  student_36332  28Q686     5  0.166667
# 492367  student_36332  24Q585     6  0.142857
#
# [492368 rows x 4 columns]

# %% [markdown]
# # Task 2) Generate & Export Student Preferences
# > Note: decide how many schools each student should rank and which preference
#
# ### Case 1: full random with no weight
# ### *Case 2: full random, ordered by popularity buckets
# ### Case 3: popularity_bucket-weighted randomness
# ### *Case 4: popularity_bucket-weighted randomness, ordered by popularity buckets

# %%
student_ids = list(ranking_df["Student_Id"].unique())  # get student ids
if testing:  # subset of data for testing
    student_ids = student_ids[:200]

# GET NUMBER OF SCHOOLS RANKED PER STUDENTS
full_list = True  # **students rank 12 schools, ELSE students rank schools based on real-world distribution
student_school_counts = {}  # student_id: #schools to choose
max_num_schools = 12  # maximum number of rankings a student can have
if full_list:
    student_school_counts = dict([[sid, max_num_schools] for sid in student_ids])
else:
    student_school_counts = dict([[sid, 0] for sid in student_ids])
    for i, row in tqdm(ranking_df.iterrows()):  # for each ranking, add 1 to student
        assert row["Student_Id"] in student_school_counts, row["Student_Id"]
        student_school_counts[row["Student_Id"]] += 1

# show descriptive stats (sanity check)
pd.DataFrame(student_school_counts.values()).describe()
# Out:
#              0
# count  71250.0
# mean      12.0
# std        0.0
# min       12.0
# 25%       12.0
# 50%       12.0
# 75%       12.0
# max       12.0

# %%
school_ids = list(ranking_df["School"].unique())

# MAKING STUDENT_RANKINGS STRUCTURE
unknown_val = "nan"  # placeholder for no rankings
student_rankings = dict([ [sid, [unknown_val for i in range(max_num_schools)]] for sid in student_ids])  # initializing dict

for sid in tqdm(student_rankings.keys()):
    # CASE 1: RANDOM IMPLEMENTATION
    student_rankings[sid] = np.random.choice(school_ids, size=student_school_counts[sid], replace=False).tolist()
print("\nExample Student Ranking\n", student_rankings[np.random.choice(student_ids)])
# Out:
# 100%|███████████████████████████████████████| 71250/71250 [00:06<00:00, 11153.44it/s]
# Example Student Ranking
#  ['27Q309', '27Q475', '02M416', '29Q272', '05M670', '17K543', '10X442', '14K610', '11X275', '12X251', '06M348', '23K697']

# %%
# stats for sanity check
rank_avg = np.mean([len(rank) for sid, rank in student_rankings.items()])
print("Current average number of schools ranked per student:", rank_avg)
# Out:
# Current average number of schools ranked per student: 12.0

# %%
# saving student rankings
np.save(cwd+"/Data/Generated/student_rankings_stage1.npy", student_rankings)
print("saved at", "/Data/Generated/student_rankings_stage1.npy")
# Out:
# saved at /Data/Generated/student_rankings_stage1.npy

# %% [markdown]
# ## Subtask) Deriving School Popularity via True Applicant Rate

# %%
""" Data: https://github.com/KoraSHughes/DataLife/blob/main/BackEnd/Data/school_directory.xlsx
DV-EF = applicants
EG-ER = applicant/seats
MN-MY = total seats

TODO parse csv, used tommaso's structure - derive popularity for stage 2
TODO: CHECK ARE THE MOST POPULAR SCHOOLS GETTING THE MOST APPLICATIONS (num applicants) -- sanity check for simulation results
"""
# placeholder data
school_to_pop = dict([[sid, random.randint(1, 5)] for sid in school_ids])
school_to_pop  # Note: dict is more efficient than dataframe for sorting
# Out:
# {'02M411': 5,
#  '02M376': 4,
#  '02M316': 3,
#  '02M438': 5,
#  '01M448': 4,
#  '02M298': 4,
#  '03M402': 3,
#  '01M696': 5,
#  '02M412': 4,
#  '02M416': 1,
#  '02M294': 4,
#  '01M292': 4,
#  '25Q281': 3,
#  '02M543': 5,
#  '02M418': 4,
#  '02M422': 1,
#  '05M362': 3,
#  '02M551': 3,
#  '02M414': 2,
#  '02M439': 4,
#  '04M435': 5,
#  '02M288': 5,
#  '01M539': 2,
#  '01M450': 2,
#  '03M541': 5,
#  '02M605': 2,
#  '02M400': 3,
#  '02M615': 1,
#  '02M600': 1,
#  '32K168': 5,
#  '03M479': 4,
#  '02M407': 1,
#  '02M139': 2,
#  '02M545': 3,
#  '27Q309': 5,
#  '02M282': 2,
#  '02M308': 2,
#  '15K684': 3,
#  '02M413': 5,
#  '07X625': 4,
#  '30Q580': 5,
#  '02M580': 2,
#  '02M305': 3,
#  '24Q560': 5,
#  '13K605': 4,
#  '02M534': 5,
#  '02M135': 5,
#  '21K690': 2,
#  '06M540': 2,
#  '02M489': 4,
#  '02M392': 3,
#  '01M515': 1,
#  '06M346': 3,
#  '04M555': 1,
#  '27Q260': 3,
#  '02M374': 1,
#  '02M630': 1,
#  '02M546': 5,
#  '22K555': 2,
#  '04M610': 5,
#  '10X439': 1,
#  '05M369': 4,
#  '24Q299': 1,
#  '20K445': 1,
#  '02M419': 3,
#  '02M399': 1,
#  '02M533': 3,
#  '02M260': 3,
#  '13K439': 2,
#  '32K556': 4,
#  '13K527': 4,
#  '13K350': 5,
#  '02M047': 3,
#  '25Q525': 4,
#  '01M458': 4,
#  '02M420': 1,
#  '02M425': 3,
#  '32K552': 3,
#  '24Q264': 1,
#  '11X508': 1,
#  '02M393': 5,
#  '02M280': 1,
#  '09X403': 3,
#  '19K615': 4,
#  '03M492': 4,
#  '05M499': 4,
#  '06M468': 5,
#  '24Q530': 1,
#  '30Q501': 4,
#  '10X565': 3,
#  '11X299': 5,
#  '14K478': 2,
#  '14K477': 4,
#  '10X438': 1,
#  '23K493': 1,
#  '24Q610': 3,
#  '09X525': 2,
#  '15K656': 5,
#  '02M586': 5,
#  '13K595': 5,
#  '19K409': 2,
#  '02M520': 5,
#  '13K674': 3,
#  '17K751': 4,
#  '02M560': 2,
#  '03M415': 2,
#  '07X600': 4,
#  '02M432': 4,
#  '12X242': 5,
#  '03M417': 1,
#  '07X473': 1,
#  '09X413': 1,
#  '16K455': 5,
#  '06M348': 5,
#  '13K594': 1,
#  '30Q575': 4,
#  '02M437': 4,
#  '22K535': 5,
#  '14K454': 3,
#  '32K403': 2,
#  '02M408': 2,
#  '02M394': 1,
#  '04M495': 3,
#  '13K670': 3,
#  '02M542': 2,
#  '16K688': 4,
#  '13K419': 4,
#  '21K620': 5,
#  '13K483': 4,
#  '29Q498': 4,
#  '27Q650': 2,
#  '08X561': 2,
#  '19K660': 2,
#  '18K629': 1,
#  '13K963': 2,
#  '17K539': 3,
#  '21K540': 3,
#  '28Q690': 4,
#  '08X312': 1,
#  '14K558': 2,
#  '15K429': 3,
#  '02M500': 4,
#  '02M300': 3,
#  '22K405': 1,
#  '02M544': 5,
#  '02M519': 3,
#  '28Q310': 4,
#  '14K488': 3,
#  '11X455': 2,
#  '03M403': 2,
#  '02M507': 2,
#  '17K382': 3,
#  '29Q243': 1,
#  '30Q450': 1,
#  '17K543': 5,
#  '18K633': 3,
#  '02M529': 5,
#  '17K590': 4,
#  '30Q301': 3,
#  '20K490': 2,
#  '23K644': 1,
#  '15K960': 2,
#  '02M459': 1,
#  '10X213': 2,
#  '06M211': 4,
#  '07X495': 2,
#  '06M293': 5,
#  '05M157': 1,
#  '10X353': 5,
#  '06M467': 2,
#  '24Q485': 5,
#  '05M670': 4,
#  '08X349': 1,
#  '19K510': 4,
#  '28Q620': 5,
#  '08X636': 1,
#  '03M494': 4,
#  '21K468': 5,
#  '22K425': 2,
#  '06M462': 3,
#  '02M449': 2,
#  '02M550': 1,
#  '11X270': 3,
#  '13K553': 4,
#  '17K408': 5,
#  '10X141': 3,
#  '26Q430': 3,
#  '28Q284': 1,
#  '15K462': 3,
#  '07X221': 4,
#  '03M859': 1,
#  '02M296': 1,
#  '19K404': 1,
#  '10X374': 1,
#  '15K464': 2,
#  '07X548': 4,
#  '12X267': 4,
#  '15K519': 1,
#  '07X500': 2,
#  '17K548': 1,
#  '02M427': 5,
#  '20K485': 1,
#  '07X223': 3,
#  '25Q241': 5,
#  '14K561': 5,
#  '16K498': 5,
#  '31R440': 4,
#  '10X243': 4,
#  '21K572': 2,
#  '13K412': 1,
#  '11X290': 3,
#  '28Q896': 3,
#  '12X511': 2,
#  '21K337': 4,
#  '02M313': 3,
#  '11X544': 2,
#  '10X264': 3,
#  '28Q440': 5,
#  '10X440': 4,
#  '19K504': 1,
#  '09X412': 4,
#  '04M680': 5,
#  '14K610': 1,
#  '11X545': 2,
#  '24Q550': 4,
#  '06M463': 1,
#  '15K448': 2,
#  '07X551': 3,
#  '24Q585': 3,
#  '09X329': 3,
#  '24Q600': 2,
#  '03M291': 5,
#  '02M655': 3,
#  '11X542': 1,
#  '10X368': 3,
#  '15K497': 4,
#  '17K546': 2,
#  '18K637': 2,
#  '07X522': 4,
#  '11X288': 1,
#  '17K537': 2,
#  '11X275': 1,
#  '03M307': 1,
#  '03M860': 2,
#  '32K554': 2,
#  '08X320': 2,
#  '05M304': 5,
#  '29Q272': 2,
#  '12X682': 5,
#  '02M531': 3,
#  '06M552': 5,
#  '15K667': 3,
#  '24Q267': 4,
#  '31R047': 4,
#  '02M303': 1,
#  '10X477': 5,
#  '07X259': 4,
#  '21K525': 3,
#  '31R445': 1,
#  '29Q313': 5,
#  '07X527': 2,
#  '10X546': 4,
#  '17K122': 5,
#  '17K600': 5,
#  '03M299': 4,
#  '04M372': 1,
#  '07X427': 5,
#  '17K745': 5,
#  '32K549': 2,
#  '29Q265': 4,
#  '10X342': 5,
#  '14K071': 3,
#  '08X530': 1,
#  '16K765': 3,
#  '30Q417': 4,
#  '25Q425': 1,
#  '21K344': 5,
#  '31R450': 3,
#  '08X376': 3,
#  '19K502': 2,
#  '26Q315': 4,
#  '13K265': 4,
#  '27Q323': 3,
#  '10X437': 4,
#  '19K507': 2,
#  '30Q445': 3,
#  '28Q328': 5,
#  '11X418': 4,
#  '21K348': 4,
#  '18K563': 2,
#  '10X225': 5,
#  '28Q167': 3,
#  '12X521': 1,
#  '05M148': 2,
#  '27Q400': 4,
#  '22K611': 5,
#  '12X550': 3,
#  '09X260': 4,
#  '23K697': 4,
#  '28Q686': 4,
#  '24Q455': 5,
#  '14K586': 1,
#  '27Q262': 2,
#  '14K474': 4,
#  '24Q236': 4,
#  '24Q296': 5,
#  '10X228': 5,
#  '10X442': 1,
#  '30Q258': 1,
#  '19K764': 5,
#  '26Q495': 4,
#  '25Q670': 5,
#  '11X253': 1,
#  '19K639': 5,
#  '11X249': 1,
#  '09X365': 3,
#  '10X237': 4,
#  '27Q302': 2,
#  '09X231': 3,
#  '26Q566': 5,
#  '09X568': 3,
#  '19K618': 3,
#  '17K547': 4,
#  '10X549': 4,
#  '09X327': 4,
#  '24Q520': 4,
#  '08X367': 4,
#  '12X684': 2,
#  '18K567': 4,
#  '28Q505': 5,
#  '09X324': 4,
#  '30Q502': 5,
#  '08X293': 4,
#  '10X434': 5,
#  '10X268': 5,
#  '08X432': 1,
#  '19K659': 2,
#  '19K583': 4,
#  '20K505': 4,
#  '09X517': 1,
#  '07X670': 2,
#  '09X297': 4,
#  '06M423': 1,
#  '09X505': 4,
#  '11X513': 4,
#  '12X251': 3,
#  '21K559': 2,
#  '08X282': 2,
#  '31R455': 4,
#  '10X284': 2,
#  '17K528': 2,
#  '17K524': 2,
#  '08X269': 3,
#  '09X404': 5,
#  '30Q286': 2,
#  '08X537': 4,
#  '29Q492': 1,
#  '08X405': 2,
#  '07X334': 1,
#  '09X227': 4,
#  '09X250': 5,
#  '12X478': 5,
#  '09X564': 3,
#  '09X252': 2,
#  '11X514': 2,
#  '10X351': 2,
#  '10X433': 4,
#  '09X543': 3,
#  '29Q327': 1,
#  '25Q252': 5,
#  '25Q460': 3,
#  '25Q285': 2,
#  '12X388': 2,
#  '09X263': 5,
#  '12X271': 3,
#  '26Q415': 3,
#  '24Q293': 5,
#  '09X241': 4,
#  '12X248': 4,
#  '10X524': 4,
#  '12X479': 2,
#  '32K545': 3,
#  '23K514': 1,
#  '08X348': 1,
#  '08X452': 3,
#  '28Q680': 1,
#  '19K683': 1,
#  '11X509': 3,
#  '25Q263': 1,
#  '18K642': 1,
#  '26Q435': 1,
#  '19K422': 2,
#  '13K616': 1,
#  '27Q480': 5,
#  '29Q326': 2,
#  '11X265': 1,
#  '31R460': 5,
#  '27Q351': 5,
#  '09X350': 3,
#  '08X558': 3,
#  '20K609': 3,
#  '14K685': 1,
#  '12X446': 2,
#  '18K617': 4,
#  '21K410': 5,
#  '25Q240': 5,
#  '19K953': 4,
#  '27Q475': 5,
#  '18K569': 2,
#  '29Q283': 4,
#  '17K531': 4,
#  '27Q308': 5,
#  '15K463': 4,
#  '29Q248': 5,
#  '27Q334': 3,
#  '27Q314': 5,
#  '18K566': 1,
#  '29Q259': 3,
#  '14K614': 1,
#  '30Q555': 3,
#  '28Q350': 2,
#  '31R064': 4,
#  '18K576': 2,
#  '17K646': 3,
#  '31R028': 1,
#  '28Q325': 2,
#  '15K592': 1,
#  '15K423': 2,
#  '31R080': 1,
#  '23K647': 2,
#  '31R600': 5,
#  '27Q324': 4,
#  '22K630': 2,
#  '18K635': 2,
#  '25Q792': 4,
#  '21K728': 5,
#  '25Q540': 1}

# %%
# save generated popularity
translation = [[sid, pop] for sid, pop in school_to_pop.items()]
np.save(cwd+"/Data/Generated/school_demographics.npy", pd.DataFrame(translation, columns=["Name", "Popularity"]))
print("saved at", "/Data/Generated/school_demographics.npy")
# Out:
# saved at /Data/Generated/school_demographics.npy

# %%
# add popularity-ordering to ranking
s2_student_rankings = {}
for sid, ranks in tqdm(student_rankings.items()):
    new_ranks = sorted(ranks, key=lambda x: school_to_pop[x], reverse=True)  # sort by dict vals
    s2_student_rankings[sid] = new_ranks  # append new rank
s2_student_rankings[np.random.choice(student_ids)]
# Out:
# 100%|██████████████████████████████████████| 71250/71250 [00:00<00:00, 151916.78it/s]
# ['17K543',
#  '18K567',
#  '23K697',
#  '03M492',
#  '10X524',
#  '17K539',
#  '06M462',
#  '11X509',
#  '02M533',
#  '02M308',
#  '03M859',
#  '07X334']

# %%
# saving student rankings
np.save(cwd+"/Data/Generated/student_rankings_stage2.npy", s2_student_rankings)
print("saved at", "/Data/Generated/student_rankings_stage2.npy")
# Out:
# saved at /Data/Generated/student_rankings_stage2.npy

# %%
# add popularity weighted choice
s3_student_rankings = {}
weighted_schools = []
for school, prio in tqdm(school_to_pop.items()):  # generate school list weighted by popularity
    for i in range(prio**2):
        weighted_schools.append(school)
print("Note: number of schools is", len(weighted_schools), "which should be <", len(school_to_pop), "* 5")
        
for sid, ranks in tqdm(student_rankings.items()):  # choose from weighted list
    new_ranks = np.random.choice(weighted_schools, size=student_school_counts[sid], replace=False).tolist()
    s3_student_rankings[sid] = new_ranks
    
s3_student_rankings[np.random.choice(student_ids)]
# Out:
# 100%|██████████████████████████████████████████| 437/437 [00:00<00:00, 385957.22it/s]
# Note: number of schools is 4913 which should be < 437 * 5
# 100%|█████████████████████████████████████████| 71250/71250 [01:19<00:00, 896.52it/s]
# ['07X548',
#  '18K617',
#  '27Q324',
#  '05M304',
#  '08X282',
#  '14K477',
#  '11X513',
#  '11X299',
#  '19K409',
#  '15K463',
#  '11X514',
#  '13K439']

# %%
# saving student rankings
np.save(cwd+"/Data/Generated/student_rankings_stage3.npy", s3_student_rankings)
print("saved at", "/Data/Generated/student_rankings_stage3.npy")
# Out:
# saved at /Data/Generated/student_rankings_stage3.npy

# %%
# add popularity weighted choice AND popularity-ordering to ranking
s4_student_rankings = {}
for sid, ranks in tqdm(s3_student_rankings.items()):
    new_ranks = sorted(ranks, key=lambda x: school_to_pop[x], reverse=True)  # sort by dict vals
    s4_student_rankings[sid] = new_ranks  # append new rank
    
s4_student_rankings[np.random.choice(student_ids)]
# Out:
# 100%|██████████████████████████████████████| 71250/71250 [00:00<00:00, 188950.53it/s]
# ['27Q314',
#  '17K408',
#  '16K498',
#  '02M534',
#  '27Q309',
#  '31R460',
#  '09X327',
#  '10X437',
#  '27Q400',
#  '13K419',
#  '12X251',
#  '02M308']

# %%
# saving student rankings
np.save(cwd+"/Data/Generated/student_rankings_stage4.npy", s4_student_rankings)
print("saved at", "/Data/Generated/student_rankings_stage4.npy")
# Out:
# saved at /Data/Generated/student_rankings_stage4.npy

# %%
# adding lotterly number
lnums = [uuid.uuid4().hex for i in range(len(student_df))]
student_df["Lottery"] = lnums
student_df
# Out:
#           Student_Id          Residential_District  swd  poverty  sex  ell  \
# 0      student_36332  Residential District Unknown    0        0    1    0
# 1      student_36144  Residential District Unknown    0        1    0    0
# 2      student_37038  Residential District Unknown    1        1    1    0
# 3        student_614  Residential District Unknown    0        0    1    0
# 4      student_21981  Residential District Unknown    1        0    1    0
# ...              ...                           ...  ...      ...  ...  ...
# 71245  student_22462       Residential District 01    0        0    1    0
# 71246  student_30857       Residential District 01    1        0    1    0
# 71247  student_57833       Residential District 01    0        0    0    0
# 71248  student_32259       Residential District 01    0        1    0    0
# 71249  student_68963       Residential District 01    1        0    1    0
#
#          ENI  Black  Hispanic  Multi-Racial  White  Asian  Native American  \
# 0      0.723      0         1             0      0      0                0
# 1      0.684      0         1             0      0      0                0
# 2      0.881      0         1             0      0      0                0
# 3      0.191      0         0             0      1      0                0
# 4      0.304      0         0             0      1      0                0
# ...      ...    ...       ...           ...    ...    ...              ...
# 71245  0.650      0         1             0      0      0                0
# 71246  0.621      0         0             0      0      1                0
# 71247  0.256      1         0             0      0      0                0
# 71248  0.950      0         0             0      0      1                0
# 71249  0.630      0         1             0      0      0                0
#
#        Missing Race/Ethnicity Data  school  Math_score  ELA_score  \
# 0                                0  30Q127    2.000000   3.125000
# 1                                0  27Q137    2.153846   2.750000
# 2                                0  24Q061    2.846154   1.753425
# 3                                0  02M114    4.275862   4.181818
# 4                                0  02M312    4.017241   3.125000
# ...                            ...     ...         ...        ...
# 71245                            0  01M450    2.000000   1.972603
# 71246                            0  01M184    3.000000   3.125000
# 71247                            0  01M539    2.615385   4.030303
# 71248                            0  01M188    3.083333   2.000000
# 71249                            0  01M839    2.692308   2.312500
#
#                                 Lottery
# 0      4c4ef64abb8044588343460f6eeab8db
# 1      57835b4ba9a44375be70514c28639cee
# 2      359e444aef7344ccb33f871a762360e8
# 3      536468d353324cb08da75344b7f0d1e8
# 4      c195ec0c32e4452ca62a122327f7bfa6
# ...                                 ...
# 71245  1eeb5307efa84090ba4f2a9eb2dcbb4b
# 71246  5c810ec67fbe444cb1e9629751879cbc
# 71247  fd4f0ebe302b47459d04352e35e92b49
# 71248  9fa7ba94beda4bcfbfafbc2cad29db52
# 71249  acea35e3c3ef43b1a1d46351c100a5c0
#
# [71250 rows x 18 columns]

# %%
# adding gpa, seat, and screen attributes

def add_fake_gpa(students):
    """ adds a gpa attribute based on the students ELA and Math scores """
    students["fake_gpa"] = students["Math_score"] + students["ELA_score"]
    max_score = max(students["fake_gpa"])
    students["fake_gpa"] = students["fake_gpa"].apply(lambda score: round(4*score/max_score, 2))  # gpa-normalized
    return students
    
def add_edopt(students):
    """ adds gpa percentile in 3rds for ed opt schools """
    lower = students["fake_gpa"].quantile(1/3)
    upper = students["fake_gpa"].quantile(2/3)
    seated = lambda x: 1 if x >= upper else (2 if x >= lower else 3)
    students["seat"] = students["fake_gpa"].apply(seated)
    return students

def add_screen(students):
    """ adds gpa percentile in 5ths for screen schools """
    lower1 = students["fake_gpa"].quantile(1/5)
    lower2 = students["fake_gpa"].quantile(2/5)
    upper1 = students["fake_gpa"].quantile(3/5)
    upper2 = students["fake_gpa"].quantile(4/5)
    def screened(gpa):
        if gpa >= upper2:
            return 1
        elif gpa >= upper1:
            return 2
        elif gpa >= lower2:
            return 3
        elif gpa >= lower1:
            return 4
        else:
            return 5
        
    students["screen"] = students["fake_gpa"].apply(lambda x: screened(x))
    return students

student_df = add_fake_gpa(student_df)
student_df = add_edopt(student_df)
student_df = add_screen(student_df)
student_df
# Out:
#           Student_Id          Residential_District  swd  poverty  sex  ell  \
# 0      student_36332  Residential District Unknown    0        0    1    0
# 1      student_36144  Residential District Unknown    0        1    0    0
# 2      student_37038  Residential District Unknown    1        1    1    0
# 3        student_614  Residential District Unknown    0        0    1    0
# 4      student_21981  Residential District Unknown    1        0    1    0
# ...              ...                           ...  ...      ...  ...  ...
# 71245  student_22462       Residential District 01    0        0    1    0
# 71246  student_30857       Residential District 01    1        0    1    0
# 71247  student_57833       Residential District 01    0        0    0    0
# 71248  student_32259       Residential District 01    0        1    0    0
# 71249  student_68963       Residential District 01    1        0    1    0
#
#          ENI  Black  Hispanic  Multi-Racial  ...  Asian  Native American  \
# 0      0.723      0         1             0  ...      0                0
# 1      0.684      0         1             0  ...      0                0
# 2      0.881      0         1             0  ...      0                0
# 3      0.191      0         0             0  ...      0                0
# 4      0.304      0         0             0  ...      0                0
# ...      ...    ...       ...           ...  ...    ...              ...
# 71245  0.650      0         1             0  ...      0                0
# 71246  0.621      0         0             0  ...      1                0
# 71247  0.256      1         0             0  ...      0                0
# 71248  0.950      0         0             0  ...      1                0
# 71249  0.630      0         1             0  ...      0                0
#
#        Missing Race/Ethnicity Data  school Math_score  ELA_score  \
# 0                                0  30Q127   2.000000   3.125000
# 1                                0  27Q137   2.153846   2.750000
# 2                                0  24Q061   2.846154   1.753425
# 3                                0  02M114   4.275862   4.181818
# 4                                0  02M312   4.017241   3.125000
# ...                            ...     ...        ...        ...
# 71245                            0  01M450   2.000000   1.972603
# 71246                            0  01M184   3.000000   3.125000
# 71247                            0  01M539   2.615385   4.030303
# 71248                            0  01M188   3.083333   2.000000
# 71249                            0  01M839   2.692308   2.312500
#
#                                 Lottery fake_gpa  seat  screen
# 0      4c4ef64abb8044588343460f6eeab8db     2.29     2       3
# 1      57835b4ba9a44375be70514c28639cee     2.19     2       4
# 2      359e444aef7344ccb33f871a762360e8     2.05     3       4
# 3      536468d353324cb08da75344b7f0d1e8     3.77     1       1
# 4      c195ec0c32e4452ca62a122327f7bfa6     3.19     1       1
# ...                                 ...      ...   ...     ...
# 71245  1eeb5307efa84090ba4f2a9eb2dcbb4b     1.77     3       5
# 71246  5c810ec67fbe444cb1e9629751879cbc     2.73     2       2
# 71247  fd4f0ebe302b47459d04352e35e92b49     2.96     1       2
# 71248  9fa7ba94beda4bcfbfafbc2cad29db52     2.27     2       3
# 71249  acea35e3c3ef43b1a1d46351c100a5c0     2.23     2       4
#
# [71250 rows x 21 columns]

# %%
# saving school demographics with updated attributes
np.save(cwd+"/Data/Generated/student_demographics.npy", student_df)
print("saved at", "/Data/Generated/student_demographics.npy")
# Out:
# saved at /Data/Generated/student_demographics.npy

# %% [markdown]
# ## Step 3.5) Add profiles for school rankings

# %%
schools_criterion = ["District", "Lottery", "ELA_Score", "Math_Score", "Poverty_Index", "fake_gpa", "seat", "screen"]

# BASIC SCHOOL PROFILES (intuition)
# Note: these weights are in powers of 10 so they are closer to discrete ordering than pure ratios
district_school = [3, 1, 0, 0, 0, 0, 0, 0]
balanced_school = [3, 1, 2, 2, 1, 0, 0, 0]
stem_school =     [3, 1, 2, 5, 1, 0, 0, 0]  # Note: most schools weight ELA and math equivalently (less realistic)
lottery_school =  [1, 5, 0, 0, 0, 0, 0, 0]
elite_school =    [0, 1, 4, 4, 0, 0, 0, 0]
basic_school_profiles = [district_school, balanced_school, stem_school, lottery_school, elite_school]

def basic_rand_pref():
    """ generate a random school preference profile """
    return random.choice(basic_school_profiles)

# %%
"""
Open schools: exlcusively lottery
Ed Opt schools: 1/3rd seat for high/medium/low gpa (known) + lottery for inter-group tiebreaker
Screen schools: 5 group distribution of gpa but highest to lowest (known) + lottery tie breaker
Audition/Assessment: some sort of examination with ranking (school provides a score) + lottery tiebreaker

Note: most have set-asides & zoning regulations
Note: careful of skew (students with high seats disproportionally apply more to more popular schools)
# Open, Ed Opt, Screened, Audtion/Assessment
"""
#  ["District", "Lottery", "ELA_Score", "Math_Score", "Poverty_Index", "gpa", "seat", "screen"]
open_school = ["Lottery"]  # [0, 1, 0, 0, 0, 0, 0, 0]
edopt_school = ["seat", "Lottery"]  # [0, 1, 0, 0, 0, 0, 2, 0]
screen_school = ["screen", "Lottery"]  # [0, 0, 0, 0, 0, 0, 0, 1]
# audition_school = [0, 1, 0, 0, 0, 0, 0]
complex_school_profiles = [open_school, edopt_school, screen_school]

student_df.sort_values(edopt_school, ascending=True)
# Out:
#           Student_Id     Residential_District  swd  poverty  sex  ell    ENI  \
# 32359  student_45916  Residential District 21    0        1    1    0  0.403
# 16358  student_36399  Residential District 27    0        0    1    0  0.823
# 69101  student_34762  Residential District 02    0        0    0    0  0.265
# 4502   student_15957  Residential District 31    0        1    0    0  0.515
# 3423   student_34553  Residential District 31    0        1    0    0  0.450
# ...              ...                      ...  ...      ...  ...  ...    ...
# 59982  student_16145  Residential District 08    1        0    1    0  0.912
# 41853  student_67379  Residential District 17    1        1    0    0  0.834
# 37918  student_64944  Residential District 20    0        1    1    1  0.792
# 59660  student_44321  Residential District 09    0        1    0    1  0.947
# 64622  student_52179  Residential District 06    0        1    0    0  0.905
#
#        Black  Hispanic  Multi-Racial  ...  Asian  Native American  \
# 32359      0         0             0  ...      1                0
# 16358      0         1             0  ...      0                0
# 69101      0         0             1  ...      0                0
# 4502       0         0             0  ...      1                0
# 3423       0         0             0  ...      0                0
# ...      ...       ...           ...  ...    ...              ...
# 59982      0         1             0  ...      0                0
# 41853      1         0             0  ...      0                0
# 37918      0         0             0  ...      1                0
# 59660      0         1             0  ...      0                0
# 64622      0         1             0  ...      0                0
#
#        Missing Race/Ethnicity Data  school Math_score  ELA_score  \
# 32359                            0  21K239   3.916667   3.125000
# 16358                            0  27Q282   4.379310   2.437500
# 69101                            0  02M167   4.172414   4.121212
# 4502                             0  31R072   3.333333   3.437500
# 3423                             0  31R048   4.068966   4.287879
# ...                            ...     ...        ...        ...
# 59982                            0  08X376   1.933333   1.986301
# 41853                            0  17K246   1.413333   1.904110
# 37918                            0  20K227   1.666667   1.821918
# 59660                            0  09X313   1.653333   1.849315
# 64622                            0  06M143   2.000000   2.062500
#
#                                 Lottery fake_gpa  seat  screen
# 32359  0004a77607bc4e3482b0fe742bd2a1b7     3.14     1       1
# 16358  00089b79bdc048f9bb0208a647356301     3.04     1       2
# 69101  000accfcd3e4424486a67561d74c41c5     3.70     1       1
# 4502   001a96ce38234040a179dd93e1a57e7c     3.02     1       2
# 3423   001b393e98e24bcca34c7d9b22a5a41f     3.73     1       1
# ...                                 ...      ...   ...     ...
# 59982  fff745d3ceab4f1d9ced363f33275c01     1.75     3       5
# 41853  fff7d4e0921b41a288846c54d8779b7e     1.48     3       5
# 37918  fff96412729044f786afa02c3e4885e2     1.56     3       5
# 59660  fffc9ef37fff4dd6b03266b40e221006     1.56     3       5
# 64622  fffcaa214cb443b6ab370f231ee2f933     1.81     3       5
#
# [71250 rows x 21 columns]

# %%
# %%time
students_open = student_df.sort_values(open_school, ascending=True)["Student_Id"].tolist()
students_edopt = student_df.sort_values(edopt_school, ascending=True)["Student_Id"].tolist()
students_screen = student_df.sort_values(screen_school, ascending=True)["Student_Id"].tolist()
student_ordering_choices = [students_open, students_edopt, students_screen]

def gen_school_choices(ids, choice_weights):
    assert len(choice_weights) == len(student_ordering_choices), "choices should follow schema:"+str(len(student_ordering_choices))
    weighted_choices = ""  # creates a string representing indicies of the choices
    for i, weight in enumerate(choice_weights):
        weighted_choices += str(i)*weight
            
    school_choices = {}  # generate student choices
    for sid in ids:
        choice_type = int(weighted_choices[np.random.randint(len(weighted_choices))])
        school_choices[sid] = student_ordering_choices[choice_type]  # add corresponding choice
    return school_choices
# Out:
# CPU times: user 235 ms, sys: 15.2 ms, total: 251 ms
# Wall time: 257 ms

# %%
# TODO: ensure order by discrete --> think SQL 'order_by' (next attribute is only looked at for tie-breakers)
# prioirity students always take presidence
# Note: recall you can affect capacity of school
# TODO: add student preferences proportional to school policy
# TODO: add distance from school's popularity
# TODO: take a better look at student preference generation
# TODO: add school district
# get_district = dict([[sid, random.choice(student_df["Residential_District"].unique())] for sid in school_ids])
# get_district[random.choice(school_ids)]

# Next steps: make one-shot function & seperate python file

# %% [markdown]
# ## Task 3: Generate School Rankings from profiles
# ### Subgoal) Create randomized school profiles
# #### Case 1: all open school (lottery only)
# #### Case 2: add screen and or ed opt policies
# #### Case 3: add policy-weighted randomness for variation between schools

# %%
# %%time
# generate profile
all_open = gen_school_choices(school_ids, [1,0,0])
# saving school rankings
np.save(cwd+"/Data/Generated/school_rankings_open.npy", all_open)
print("saved at", "/Data/Generated/school_rankings_open.npy")
# Out:
# saved at /Data/Generated/school_rankings_open.npy
# CPU times: user 10.1 ms, sys: 2.21 ms, total: 12.4 ms
# Wall time: 11.5 ms

# %%
# %%time
# generate profile
all_edopt = gen_school_choices(school_ids, [0,1,0])
# saving school rankings
np.save(cwd+"/Data/Generated/school_rankings_edopt.npy", all_edopt)
print("saved at", "/Data/Generated/school_rankings_edopt.npy")
# Out:
# saved at /Data/Generated/school_rankings_edopt.npy
# CPU times: user 10 ms, sys: 1.8 ms, total: 11.8 ms
# Wall time: 10.4 ms

# %%
# %%time
# generate profile
all_screen = gen_school_choices(school_ids, [0,0,1])
# saving school rankings
np.save(cwd+"/Data/Generated/school_rankings_screen.npy", all_screen)
print("saved at", "/Data/Generated/school_rankings_screen.npy")
# Out:
# saved at /Data/Generated/school_rankings_screen.npy
# CPU times: user 9.86 ms, sys: 1.73 ms, total: 11.6 ms
# Wall time: 10.5 ms

# %%
# %%time
# generate profile
all_combo = gen_school_choices(school_ids, [1,1,1])
# saving school rankings
np.save(cwd+"/Data/Generated/school_rankings_combo.npy", all_combo)
print("saved at", "/Data/Generated/school_rankings_combo.npy")

# NOTE: EVERYTHING <400ms
# Out:
# saved at /Data/Generated/school_rankings_combo.npy
# CPU times: user 17.8 ms, sys: 2.74 ms, total: 20.5 ms
# Wall time: 19.4 ms

# %%
print(len(student_df), "students ranked alongside", len(all_combo), "schools")
# Out:
# 71250 students ranked alongside 437 schools

# %%
def insert_student(student_data, df):
    """ insert a student into a ranked category """
    # TODO: find a more efficient way of doing this
    return ...

# %%
# TODO collinearity matrix between ranking and student attributes like test scores/lottery number
# TODO: add gale-shapley priority => 'set asside'

# %%
# looking at real admissions data
school_info = np.load("Data/schools_info_incomplete.npy", allow_pickle=True).item()
# {name: (dbn, capacity, true applicants, total applicants)}

temp = []
for name, data in school_info.items():
    temp.append([name]+[d for d in data])
school_df = pd.DataFrame(temp, columns=["name", "dbn", "capacity", "true_applicants", "total_applicants"])
ar = []
for i, row in school_df.iterrows():
    if row["capacity"]==0 or row["total_applicants"]==0:
        ar.append(0)
    else:
        ar.append(row["total_applicants"] / row["capacity"])
school_df["likeability"] = ar
# Note: true applicants not found yet
school_df
# Out:
#                                                   name     dbn  capacity  \
# 0                           Orchard Collegiate Academy  01M292        90
# 1                  University Neighborhood High School  01M448       105
# 2                           East Side Community School  01M450        95
# 3                            Forsyth Satellite Academy  01M458        28
# 4              Lower East Side Preparatory High School  01M515        60
# ..                                                 ...     ...       ...
# 442            Brooklyn School for Social Justice, The  32K549       115
# 443     Academy of Urban Planning and Engineering, The  32K552       113
# 444               All City Leadership Secondary School  32K554        62
# 445  Bushwick Leaders High School for Academic Exce...  32K556       100
# 446                                             33K960  33K960         0
#
#      true_applicants  total_applicants  likeability
# 0                  0                50     0.555556
# 1                  0               445     4.238095
# 2                  0               413     4.347368
# 3                  0                 5     0.178571
# 4                  0                43     0.716667
# ..               ...               ...          ...
# 442                0                39     0.339130
# 443                0               134     1.185841
# 444                0               397     6.403226
# 445                0               131     1.310000
# 446                0                 0     0.000000
#
# [447 rows x 6 columns]

# %%
school_df.describe()
# Out:
#           capacity  true_applicants  total_applicants  likeability
# count   447.000000            447.0        447.000000   447.000000
# mean    145.073826              0.0        418.225951     2.453505
# std     128.510565              0.0        918.341377     4.072874
# min       0.000000              0.0          0.000000     0.000000
# 25%      88.500000              0.0         60.000000     0.542457
# 50%     108.000000              0.0        133.000000     1.049383
# 75%     141.000000              0.0        332.000000     2.529259
# max    1060.000000              0.0       8994.000000    34.200000

# %%
import plotly.express as px

px.scatter(school_df, x="capacity", y="total_applicants", color="likeability")
# px.scatter(school_df, x="total_applicants", y="popularity", color="capacity")
# Out:
# <div>                            <div id="659f85b4-51d1-45ca-ae27-fb3fc64b03cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("659f85b4-51d1-45ca-ae27-fb3fc64b03cd")) {                    Plotly.newPlot(                        "659f85b4-51d1-45ca-ae27-fb3fc64b03cd",                        [{"hovertemplate":"capacity=%{x}<br>total_applicants=%{y}<br>likeability=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.5555555555555556,4.238095238095238,4.347368421052631,0.17857142857142858,0.7166666666666667,12.653333333333334,20.976,0.8405797101449275,0.782608695652174,0.8148148148148148,11.75438596491228,0.9732142857142857,1.432,2.685185185185185,7.506172839506172,0.32558139534883723,2.41875,0.37962962962962965,0.5420560747663551,0.59,1.0315789473684212,0.84,0.225,1.1862745098039216,12.152542372881356,1.7962962962962963,1.6434108527131783,0.21666666666666667,0.11194029850746269,2.2333333333333334,5.885245901639344,4.645161290322581,25.033333333333335,20.923076923076923,7.018518518518518,9.935483870967742,34.2,20.16875,0.54,2.6538461538461537,0.6018518518518519,0.2463768115942029,0.37037037037037035,1.1777777777777778,0.3220338983050847,0.7352941176470589,13.26,1.3454545454545455,1.4470588235294117,0.0,1.45,0.3368421052631579,3.7962962962962963,2.647727272727273,0.19166666666666668,0.315,1.8666666666666667,1.348623853211009,1.8938053097345133,1.651851851851852,1.512,0.1,4.722222222222222,5.433333333333334,0.24,1.542857142857143,0.32,0.5125,0.5333333333333333,1.7763713080168777,3.1272727272727274,1.1008403361344539,4.55064935064935,0.39473684210526316,5.2555555555555555,0.24166666666666667,0.49107142857142855,1.3148148148148149,1.0,1.4453125,4.425925925925926,13.747222222222222,0.0,1.2142857142857142,1.2357142857142858,26.194444444444443,3.12,0.631578947368421,1.5,6.069478908188586,7.23,14.8,2.765432098765432,1.475,0.37,0.41975308641975306,0.46296296296296297,17.098214285714285,0.6481481481481481,0.725,1.0740740740740742,0.0,2.7037037037037037,5.419753086419753,2.4,2.1913043478260867,0.3,0.9478260869565217,0.5066666666666667,0.47560975609756095,0.2702702702702703,0.6616052060737527,0.9529411764705882,2.769230769230769,4.845238095238095,0.7736625514403292,0.49382716049382713,0.3333333333333333,0.5555555555555556,8.853846153846154,4.308641975308642,0.8928571428571429,1.5052631578947369,1.328,1.382716049382716,2.0657894736842106,0.6323529411764706,0.38666666666666666,2.0123456790123457,0.28703703703703703,1.8058252427184467,1.7746478873239437,0.5370370370370371,0.37962962962962965,1.2314814814814814,0.9479166666666666,0.654320987654321,1.3394495412844036,1.1358024691358024,0.4537037037037037,0.69,0.4,0.762962962962963,1.3583333333333334,0.0,2.7578947368421054,2.2153846153846155,2.164383561643836,1.5648148148148149,1.9540229885057472,7.824074074074074,0.5,1.08130081300813,2.432098765432099,3.4444444444444446,0.6851851851851852,0.36,3.75,0.7407407407407407,0.1388888888888889,0.556390977443609,3.0987654320987654,3.3365384615384617,0.4166666666666667,0.6544117647058824,0.3148148148148148,0.8641975308641975,1.9876543209876543,2.088397790055249,0.7720588235294118,1.1470588235294117,0.5481481481481482,2.8777777777777778,2.1018518518518516,0.3425925925925926,0.9076923076923077,1.0493827160493827,0.6866666666666666,2.088607594936709,2.107142857142857,5.407407407407407,0.9270833333333334,2.814814814814815,5.324074074074074,4.333333333333333,3.8703703703703702,1.2369791666666667,1.1857142857142857,0.0,2.9074074074074074,0.8641975308641975,0.734375,1.7592592592592593,0.9166666666666666,0.0,2.5185185185185186,0.4074074074074074,0.2540983606557377,1.8395061728395061,0.8111111111111111,6.991666666666666,0.9259259259259259,2.23728813559322,3.1875,0.39866666666666667,5.4945054945054945,0.648148148148 ...

# %%
# true applicant rate
# stage 0: capacity-weighted popularity
# making the mean lottery number values into medians
# making y-scale of graphs of stage 1&3 and 2&4
# revise intro slide description (not true applicant "rate", not changing matching algorithm, "ranking" --> "matching")

""" LONGTERM NOTES:
students in the same district will have similar patterns -- higher preference for ranking schools in their own districts or close to accesisble subway lines
clustering based on applicants per district
"""
