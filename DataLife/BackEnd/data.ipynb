# %%
import pandas as pd

COL_NAME = 'School Name'
COL_DBN = 'School DBN'
COL_APPS = 'Grade 9 Total Applicants'
COL_TRUE_APPS = 'Grade 9 True Applicants'
COL_SEATS = 'Grade 9 Seats Available'
COL_OFFERS = 'Grade 9 Offers'

# %%
file_path = 'Data/fall-2023-admissions.xlsx'
df = pd.read_excel(file_path, sheet_name='School')

# %%
schools_to_exclude = ['03M485', '02M475', '05M692', '10X445', '10X696', '13K430', '14K449', '28Q687', '31R605']
columns = ['School District', COL_DBN, COL_NAME, COL_SEATS, COL_APPS, COL_TRUE_APPS, COL_OFFERS]

# %%
df_all = df[df['Category'] == 'All Students']
df_all = df_all[~ df_all['School DBN'].isin(schools_to_exclude)]
df_grade9 = df_all.dropna(subset=[COL_APPS])
df_grade9[COL_SEATS] = df_grade9[COL_SEATS].apply(lambda x: x.split(';')[0] if isinstance(x, str) else x).replace(['N/A', '0', 0], None)
df_grade9[COL_OFFERS] = df_grade9[COL_OFFERS].replace('N/A', None)

data = df_grade9[columns]
# Out:
# C:\Users\Tommaso\AppData\Local\Temp\ipykernel_12220\1874305094.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_grade9[COL_SEATS] = df_grade9[COL_SEATS].apply(lambda x: x.split(';')[0] if isinstance(x, str) else x).replace(['N/A', '0', 0], None)
# C:\Users\Tommaso\AppData\Local\Temp\ipykernel_12220\1874305094.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_grade9[COL_OFFERS] = df_grade9[COL_OFFERS].replace('N/A', None)

# %%
import numpy as np

seed = 142
rng = np.random.default_rng(seed=seed)

def replace_suppressed(row):
	return row.apply(lambda x: rng.integers(low=1, high=5, endpoint=True) if x == 's' else x)

def replace_suppressed_by_diff(row):
	if row[COL_OFFERS] == 's^':
		row[COL_OFFERS] = row[COL_TRUE_APPS]
	return row

# %%
data = data.dropna(axis=0)

data = data.apply(replace_suppressed, axis=1)
data = data.apply(replace_suppressed_by_diff, axis=1)

data[COL_SEATS] = data[COL_SEATS].astype('int64')
data[COL_OFFERS] = data[COL_OFFERS].astype('int64')
data
# Out:
#         School District School DBN  \
# 775                   1     01M292
# 1308                  1     01M448
# 1533                  1     01M450
# 1739                  1     01M458
# 1802                  1     01M515
# ...                 ...        ...
# 120263               32     32K545
# 120342               32     32K549
# 120413               32     32K552
# 120571               32     32K554
# 120736               32     32K556
#
#                                               School Name  \
# 775                            Orchard Collegiate Academy
# 1308                  University Neighborhood High School
# 1533                           East Side Community School
# 1739                            Forsyth Satellite Academy
# 1802              Lower East Side Preparatory High School
# ...                                                   ...
# 120263      EBC High School for Public Service - Bushwick
# 120342             The Brooklyn School for Social Justice
# 120413      The Academy of Urban Planning and Engineering
# 120571               All City Leadership Secondary School
# 120736  Bushwick Leaders High School for Academic Exce...
#
#         Grade 9 Seats Available  Grade 9 Total Applicants  \
# 775                          90                       361
# 1308                        105                      1625
# 1533                         95                      1011
# 1739                         28                        59
# 1802                         60                       173
# ...                         ...                       ...
# 120263                      126                       534
# 120342                      115                       357
# 120413                      113                       922
# 120571                       62                       963
# 120736                      100                       561
#
#         Grade 9 True Applicants  Grade 9 Offers
# 775                          95              95
# 1308                        314             150
# 1533                        333             109
# 1739                          6               6
# 1802                         28              28
# ...                         ...             ...
# 120263                      107             119
# 120342                       50              50
# 120413                      171             171
# 120571                      291              63
# 120736                      108             108
#
# [439 rows x 7 columns]

# %%
export_dict = {}

for _, row in data.iterrows():
	name = row[COL_DBN] if pd.isna(row[COL_NAME]) else row[COL_NAME]
	dbn = row[COL_DBN]
	true_applicants = row[COL_TRUE_APPS]
	total_applicants = row[COL_APPS]
	capacity = row[COL_SEATS]
	# offers = row[COL_OFFERS]

	export_dict[name] = (dbn, capacity, true_applicants, total_applicants)

np.save('Data/schools_info.npy', export_dict, allow_pickle=True)
export_dict
# Out:
# {'Orchard Collegiate Academy': ('01M292', 90, 95, 361),
#  'University Neighborhood High School': ('01M448', 105, 314, 1625),
#  'East Side Community School': ('01M450', 95, 333, 1011),
#  'Forsyth Satellite Academy': ('01M458', 28, 6, 59),
#  'Lower East Side Preparatory High School': ('01M515', 60, 28, 173),
#  'New Explorations into Science, Technology and Math High School': ('01M539',
#   150,
#   1842,
#   3347),
#  'Bard High School Early College': ('01M696', 125, 2602, 4801),
#  '47 The American Sign Language and English Secondary School': ('02M047',
#   69,
#   73,
#   385),
#  'The Urban Assembly School for Emergency Management': ('02M135',
#   115,
#   48,
#   334),
#  'Stephen T. Mather Building Arts & Craftsmanship High School': ('02M139',
#   108,
#   96,
#   472),
#  'The Clinton School': ('02M260', 134, 1128, 2547),
#  'Manhattan Early College School for Advertising': ('02M280', 112, 88, 482),
#  'Urban Assembly Maker Academy': ('02M282', 125, 160, 1032),
#  'Food and Finance High School': ('02M288', 150, 260, 1058),
#  'Essex Street Academy': ('02M294', 81, 561, 2269),
#  'High School of Hospitality Management': ('02M296', 130, 35, 339),
#  'Pace High School': ('02M298', 160, 288, 1578),
#  'Urban Assembly School of Design and Construction, The': ('02M300',
#   108,
#   48,
#   385),
#  'Facing History School, The': ('02M303', 107, 38, 303),
#  'Urban Assembly Academy of Government and Law, The': ('02M305', 100, 50, 424),
#  'Lower Manhattan Arts Academy': ('02M308', 95, 102, 644),
#  'James Baldwin School, The: A School for Expeditionary Learning': ('02M313',
#   25,
#   17,
#   69),
#  'Urban Assembly School of Business for Young Women, the': ('02M316',
#   120,
#   11,
#   107),
#  'Gramercy Arts High School': ('02M374', 204, 283, 1290),
#  'NYC iSchool': ('02M376', 118, 1172, 2878),
#  'Manhattan Business Academy': ('02M392', 108, 197, 1266),
#  'Business Of Sports School': ('02M393', 129, 221, 1125),
#  'Emma Lazarus High School': ('02M394', 60, 19, 94),
#  'The High School For Language And Diplomacy': ('02M399', 134, 21, 178),
#  'High School for Environmental Studies': ('02M400', 344, 589, 2556),
#  'Institute for Collaborative Education': ('02M407', 61, 278, 745),
#  'Professional Performing Arts High School': ('02M408', 124, 394, 1160),
#  'Baruch College Campus High School': ('02M411', 120, 2716, 6239),
#  'N.Y.C. Lab School for Collaborative Studies': ('02M412', 109, 1387, 3288),
#  'School of the Future High School': ('02M413', 108, 776, 2165),
#  'N.Y.C. Museum School': ('02M414', 124, 1136, 3310),
#  'Eleanor Roosevelt High School': ('02M416', 125, 3844, 7816),
#  'Millennium High School': ('02M418', 150, 2650, 5709),
#  'Landmark High School': ('02M419', 100, 54, 455),
#  'High School for Health Professions and Human Services': ('02M420',
#   442,
#   830,
#   2671),
#  'Quest to Learn': ('02M422', 108, 40, 217),
#  'Leadership and Public Service High School': ('02M425', 276, 43, 436),
#  'Manhattan Academy For Arts & Language': ('02M427', 108, 45, 265),
#  'Murray Hill Academy': ('02M432', 115, 57, 392),
#  'Hudson High School of Learning Technologies': ('02M437', 120, 39, 373),
#  'International High School at Union Square': ('02M438', 68, 61, 286),
#  'Manhattan Village Academy': ('02M439', 100, 1533, 4115),
#  'Vanguard High School': ('02M449', 110, 99, 481),
#  'Manhattan International High School': ('02M459', 85, 95, 484),
#  'High School of Economics and Finance': ('02M489', 200, 253, 1304),
#  'Unity Center for Urban Technologies': ('02M500', 95, 27, 230),
#  'Urban Assembly Gateway School for Technology': ('02M507', 108, 289, 1362),
#  'Talent Unlimited High School': ('02M519', 147, 500, 1518),
#  'Murry Bergtraum High School for Business Careers': ('02M520', 240, 44, 220),
#  'Jacqueline Kennedy Onassis High School': ('02M529', 204, 81, 553),
#  'Repertory Company High School for Theatre Arts': ('02M531', 60, 86, 413),
#  'Union Square Academy for Health Sciences': ('02M533', 109, 124, 617),
#  'Harvest Collegiate High School': ('02M534', 114, 156, 1240),
#  'Manhattan Bridges High School': ('02M542', 172, 162, 616),
#  'New Design High School': ('02M543', 125, 142, 773),
#  'Independence High School': ('02M544', 30, 1, 23),
#  'High School for Dual Language and Asian Studies': ('02M545', 108, 493, 1048),
#  'Academy for Software Engineering': ('02M546', 125, 585, 2507),
#  'Liberty High School Academy for Newcomers': ('02M550', 50, 10, 67),
#  'Urban Assembly New York Harbor School': ('02M551', 151, 241, 785),
#  'High School M560 - City As School': ('02M560', 25, 1, 39),
#  'Richard R. Green High School of Teaching': ('02M580', 160, 119, 827),
#  'Harvey Milk High School': ('02M586', 45, 10, 44),
#  'The High School of Fashion Industries': ('02M600', 477, 799, 2078),
#  'Humanities Preparatory Academy': ('02M605', 65, 115, 738),
#  'Chelsea Career and Technical Education High School': ('02M615',
#   121,
#   131,
#   867),
#  'Art and Design High School': ('02M630', 385, 1547, 3634),
#  'The High School for Climate Justice': ('02M655', 152, 42, 340),
#  'West End Secondary School': ('03M291', 90, 480, 1138),
#  'The Maxine Greene HS for Imaginative Inquiry': ('03M299', 120, 18, 153),
#  'Urban Assembly School for Media Studies, The': ('03M307', 126, 63, 327),
#  'The Urban Assembly School for Green Careers': ('03M402', 120, 119, 696),
#  'The Global Learning Collaborative': ('03M403', 108, 105, 759),
#  'Wadleigh Secondary School for the Performing & Visual Arts': ('03M415',
#   128,
#   234,
#   956),
#  'Frank McCourt High School': ('03M417', 120, 429, 1328),
#  'Beacon High School': ('03M479', 360, 4503, 7994),
#  'High School for Law, Advocacy and Community Justice': ('03M492',
#   150,
#   104,
#   544),
#  'High School of Arts and Technology': ('03M494', 140, 130, 881),
#  'Manhattan / Hunter Science High School': ('03M541', 108, 2638, 5285),
#  'Special Music School': ('03M859', 50, 151, 391),
#  'Frederick Douglass Academy II Secondary School': ('03M860', 95, 76, 401),
#  'Esperanza Preparatory Academy': ('04M372', 78, 103, 291),
#  'Manhattan Center for Science and Mathematics': ('04M435', 407, 2217, 5091),
#  'Park East High School': ('04M495', 100, 718, 2268),
#  'Central Park East High School': ('04M555', 125, 1508, 4324),
#  "Young Women's Leadership School": ('04M610', 81, 161, 492),
#  'Heritage School, The': ('04M680', 80, 83, 439),
#  'Eagle Academy for Young Men of Harlem': ('05M148', 100, 70, 224),
#  'The Urban Assembly School for Global Commerce': ('05M157', 81, 40, 262),
#  'Mott Hall High School': ('05M304', 108, 63, 359),
#  'Columbia Secondary School': ('05M362', 112, 1731, 3927),
#  'Urban Assembly School for the Performing Arts': ('05M369', 108, 54, 408),
#  'Frederick Douglass Academy': ('05M499', 324, 207, 919),
#  'Thurgood Marshall Academy for Learning and Social Change': ('05M670',
#   108,
#   98,
#   366),
#  'Inwood Early College for Health and Information Technologies': ('06M211',
#   81,
#   207,
#   817),
#  'City College Academy of the Arts': ('06M293', 81, 519, 1309),
#  'Community Health Academy of the Heights': ('06M346', 75, 180, 649),
#  'Washington Heights Expeditionary Learning School': ('06M348', 115, 234, 745),
#  'High School for Excellence and Innovation': ('06M423', 60, 11, 50),
#  'The College Academy': ('06M462', 124, 113, 588),
#  'High School for Media and Communications': ('06M463', 150, 44, 383),
#  'High School for Law and Public Service': ('06M467', 168, 58, 448),
#  'High School for Health Careers and Sciences': ('06M468', 268, 77, 615),
#  'A. Philip Randolph Campus High School': ('06M540', 471, 430, 1989),
#  'Gregorio Luperon High School for Science and Mathematics': ('06M552',
#   150,
#   168,
#   461),
#  'South Bronx Preparatory: A College Board School': ('07X221', 91, 237, 1070),
#  'The Laboratory School of Finance and Technology: X223': ('07X223',
#   89,
#   284,
#   991),
#  'H.E.R.O. High (Health, Education, and Research Occupations High School)': ('07X259',
#   243,
#   256,
#   1215),
#  'International Community High School': ('07X334', 81, 36, 188),
#  'Community School for Social Justice': ('07X427', 81, 23, 158),
#  'Mott Haven Village Preparatory High School': ('07X473', 81, 45, 250),
#  'University Heights Secondary School': ('07X495', 140, 961, 2617),
#  'Hostos-Lincoln Academy of Science': ('07X500', 83, 189, 995),
#  'Bronx Design and Construction Academy': ('07X522', 140, 119, 661),
#  'Bronx Leadership Academy II High School': ('07X527', 111, 122, 773),
#  'Careers in Sports High School': ('07X548', 125, 175, 877),
#  'The Urban Assembly Bronx Academy of Letters': ('07X551', 108, 95, 387),
#  'Alfred E. Smith Career and Technical Education High School': ('07X600',
#   152,
#   337,
#   1339),
#  'Bronx Legacy High School': ('07X625', 68, 101, 509),
#  'Health Opportunities High School': ('07X670', 75, 28, 383),
#  'Bronx Studio School for Writers and Artists': ('08X269', 81, 140, 529),
#  "Women's Academy of Excellence": ('08X282', 108, 25, 147),
#  'Renaissance High School for Musical Theater and the Arts': ('08X293',
#   103,
#   164,
#   744),
#  'Millennium Art Academy': ('08X312', 112, 87, 496),
#  'Pelham Lab High School': ('08X320', 108, 44, 584),
#  'Schuylerville Preparatory High School': ('08X348', 108, 38, 303),
#  'Bronx River High School': ('08X349', 108, 150, 884),
#  'Archimedes Academy for Math, Science and Technology Applications': ('08X367',
#   96,
#   102,
#   474),
#  'Antonia Pantoja Preparatory Academy: A College Board School': ('08X376',
#   84,
#   87,
#   366),
#  'Herbert H. Lehman High School': ('08X405', 501, 470, 1981),
#  'Bronx Bridges High School': ('08X432', 81, 68, 429),
#  'Gotham Collaborative High School': ('08X452', 113, 52, 278),
#  'Longwood Preparatory Academy': ('08X530', 100, 132, 707),
#  'Bronx Arena High School': ('08X537', 10, 4, 52),
#  'Westchester Square Academy': ('08X558', 135, 97, 808),
#  'Bronx Compass High School': ('08X561', 120, 131, 728),
#  'A School Without Walls (virtual program)': ('08X636', 100, 84, 286),
#  'Bronx Collegiate Academy': ('09X227', 100, 174, 1139),
#  'Eagle Academy for Young Men': ('09X231', 80, 113, 424),
#  'Urban Assembly School for Applied Math and Science, The': ('09X241',
#   73,
#   140,
#   554),
#  'Eximius College Preparatory Academy: A College Board School': ('09X250',
#   108,
#   128,
#   860),
#  'Mott Hall Bronx High School': ('09X252', 87, 163, 1075),
#  'Bronx Center for Science and Mathematics': ('09X260', 108, 747, 2611),
#  'Validus Preparatory Academy': ('09X263', 90, 34, 244),
#  'Morris Academy for Collaborative Studies': ('09X297', 123, 129, 662),
#  'Bronx Early College Academy for Teaching & Learning': ('09X324',
#   81,
#   131,
#   699),
#  'Comprehensive Model School Project M.S. 327': ('09X327', 92, 253, 761),
#  'DreamYard Preparatory School': ('09X329', 108, 73, 462),
#  'New Directions Secondary School': ('09X350', 25, 10, 69),
#  'Academy for Language and Technology': ('09X365', 92, 214, 692),
#  'Bronx International High School': ('09X403', 108, 71, 599),
#  'School for Excellence': ('09X404', 116, 17, 190),
#  'Bronx High School of Business': ('09X412', 133, 73, 740),
#  'Bronx High School for Medical Science': ('09X413', 81, 172, 939),
#  'Bronx School for Law, Government and Justice': ('09X505', 120, 332, 1302),
#  'Frederick Douglass Academy III Secondary School': ('09X517', 108, 51, 366),
#  'Bronx Leadership Academy High School': ('09X525', 136, 115, 912),
#  'High School for Violin and Dance': ('09X543', 108, 40, 219),
#  'Claremont International HS': ('09X564', 81, 40, 346),
#  "Young Women's Leadership School of the Bronx": ('09X568', 81, 106, 507),
#  'Riverdale / Kingsbridge Academy (Middle School / High School 141)': ('10X141',
#   181,
#   359,
#   799),
#  'Bronx Engineering and Technology Academy': ('10X213', 142, 77, 599),
#  'Theatre Arts Production Company School': ('10X225', 170, 154, 806),
#  'Jonas Bronck Academy': ('10X228', 90, 4, 1),
#  'The Marie Curie School for Medicine, Nursing, and Health Professions': ('10X237',
#   135,
#   93,
#   586),
#  'West Bronx Academy for the Future': ('10X243', 90, 248, 1128),
#  'Bronx Academy for Software Engineering (BASE)': ('10X264', 108, 228, 1340),
#  'Kingsbridge International High School': ('10X268', 108, 36, 241),
#  'Bronx School of Law and Finance': ('10X284', 130, 79, 493),
#  'International School for Liberal Arts': ('10X342', 81, 80, 242),
#  'Bronx Collaborative High School': ('10X351', 150, 86, 556),
#  'World View High School': ('10X353', 150, 305, 1339),
#  'In-Tech Academy (M.S. / High School 368)': ('10X368', 140, 272, 804),
#  'Knowledge and Power Preparatory Academy International High School (Kappa)': ('10X374',
#   108,
#   442,
#   2039),
#  'High School for Teaching and the Professions': ('10X433', 102, 82, 391),
#  'Belmont Preparatory High School': ('10X434', 108, 191, 1038),
#  'Fordham High School for the Arts': ('10X437', 108, 478, 1785),
#  'Fordham Leadership Academy': ('10X438', 108, 466, 2191),
#  'Bronx High School for Law and Community Service': ('10X439', 108, 283, 1424),
#  'DeWitt Clinton High School': ('10X440', 391, 586, 2433),
#  'Celia Cruz Bronx High School of Music, The': ('10X442', 140, 161, 471),
#  'Marble Hill High School for International Studies': ('10X477',
#   108,
#   235,
#   890),
#  'Crotona International High School': ('10X524', 81, 55, 371),
#  'Bronx Theatre High School': ('10X546', 128, 58, 493),
#  'Discovery High School': ('10X549', 108, 103, 744),
#  'High School for Energy and Technology': ('10X565', 120, 82, 626),
#  'Bronx Health Sciences High School': ('11X249', 108, 183, 1075),
#  'Bronx High School for Writing and Communication Arts': ('11X253',
#   108,
#   29,
#   270),
#  'Bronx Lab School': ('11X265', 123, 32, 284),
#  'Academy for Scholarship and Entrepreneurship: A College Board School': ('11X270',
#   86,
#   122,
#   712),
#  'High School of Computers and Technology': ('11X275', 183, 127, 837),
#  'Collegiate Institute for Math and Science': ('11X288', 120, 313, 1704),
#  'Bronx Academy of Health Careers': ('11X290', 108, 95, 854),
#  'Astor Collegiate Academy': ('11X299', 120, 219, 1495),
#  'Bronx High School for the Visual Arts': ('11X418', 102, 182, 983),
#  'Harry S Truman High School': ('11X455', 786, 338, 1568),
#  'Bronxdale High School': ('11X508', 112, 311, 1839),
#  'High School of Language and Innovation': ('11X509', 108, 67, 270),
#  'New World High School': ('11X513', 108, 134, 534),
#  'The Bronxwood Preparatory Academy': ('11X514', 108, 112, 551),
#  'Pelham Preparatory Academy': ('11X542', 118, 528, 2431),
#  'High School for Contemporary Arts': ('11X544', 128, 61, 541),
#  'Bronx Aerospace High School': ('11X545', 189, 54, 408),
#  'Mott Hall V': ('12X242', 81, 335, 1129),
#  'Metropolitan High School, The': ('12X248', 145, 52, 314),
#  'Explorations Academy H.S.': ('12X251', 117, 53, 414),
#  'Bronx Latin': ('12X267', 81, 201, 971),
#  'East Bronx Academy for the Future': ('12X271', 81, 104, 489),
#  'Pan American International High School at Monroe': ('12X388', 108, 73, 340),
#  'Arturo A. Schomburg Satellite Academy Bronx': ('12X446', 50, 15, 146),
#  'The Cinema School': ('12X478', 81, 163, 743),
#  'Bronx Career and College Preparatory High School': ('12X479', 81, 33, 490),
#  'Bronx Envision Academy': ('12X511', 108, 86, 652),
#  'The Metropolitan Soundview High School': ('12X521', 120, 81, 376),
#  'High School of World Cultures': ('12X550', 108, 68, 372),
#  'Bard Bronx': ('12X641', 100, 1, 5),
#  'Fannie Lou Hamer Freedom High School': ('12X682', 110, 91, 506),
#  'Wings Academy': ('12X684', 150, 45, 414),
#  'Dr. Susan S. McKinney Secondary School of the Arts': ('13K265', 83, 60, 473),
#  'Urban Assembly School of Music and Art': ('13K350', 108, 32, 259),
#  'Brooklyn Community Arts & Media High School (BCAM)': ('13K412',
#   142,
#   110,
#   774),
#  'Science Skills Center High School for Science, Technology and the Creative Arts': ('13K419',
#   258,
#   178,
#   1050),
#  'Brooklyn International High School': ('13K439', 81, 66, 314),
#  'The Urban Assembly School for Law and Justice': ('13K483', 115, 155, 677),
#  'Urban Assembly Institute of Math and Science for Young Women': ('13K527',
#   81,
#   75,
#   259),
#  'Brooklyn Academy High School': ('13K553', 22, 48, 375),
#  'Gotham Professional Arts Academy': ('13K594', 81, 59, 337),
#  'Bedford Academy High School': ('13K595', 81, 708, 2753),
#  'George Westinghouse Career and Technical Education High School': ('13K605',
#   254,
#   217,
#   1330),
#  'Brooklyn High School for Leadership and Community Service': ('13K616',
#   60,
#   17,
#   180),
#  'Benjamin Banneker Academy': ('13K670', 225, 442, 1802),
#  'City Polytechnic High School of Engineering, Architecture, and Technology': ('13K674',
#   108,
#   297,
#   1258),
#  'Design Works High School': ('13K963', 81, 37, 232),
#  'Juan Morel Campos Secondary School': ('14K071', 102, 93, 355),
#  'The Williamsburg High School of Art and Technology': ('14K454',
#   116,
#   129,
#   847),
#  'PROGRESS High School for Professional Careers': ('14K474', 153, 73, 390),
#  'East Williamsburg Scholars Academy': ('14K477', 234, 85, 556),
#  'The High School for Enterprise, Business and Technology': ('14K478',
#   249,
#   133,
#   1024),
#  'Brooklyn Preparatory High School': ('14K488', 153, 227, 1168),
#  'Williamsburg High School for Architecture and Design': ('14K558',
#   155,
#   306,
#   1362),
#  'Williamsburg Preparatory School': ('14K561', 180, 281, 1200),
#  'Lyons Community School': ('14K586', 81, 54, 192),
#  'A-Tech High School': ('14K610', 238, 251, 1160),
#  "Young Women's Leadership School of Brooklyn": ('14K614', 93, 41, 232),
#  'El Puente Academy for Peace and Justice': ('14K685', 70, 48, 168),
#  'Brooklyn Frontiers High School': ('15K423', 65, 10, 34),
#  'Digital Arts and Cinema Technology High School': ('15K429', 90, 175, 750),
#  'Brooklyn Collaborative Studies': ('15K448', 90, 134, 806),
#  'John Jay School for Law': ('15K462', 125, 224, 975),
#  'Cyberarts Studio Academy': ('15K463', 125, 23, 176),
#  'Park Slope Collegiate': ('15K464', 102, 129, 738),
#  'The Boerum Hill School for International Studies': ('15K497',
#   100,
#   241,
#   1168),
#  'Cobble Hill School of American Studies': ('15K519', 226, 54, 421),
#  'Khalil Gibran International Academy': ('15K592', 81, 14, 85),
#  'Brooklyn High School of the Arts': ('15K656', 254, 640, 2188),
#  'Sunset Park High School': ('15K667', 354, 336, 1017),
#  'Millennium Brooklyn HS': ('15K684', 175, 2351, 5324),
#  'A School Without Walls (hybrid program)': ('15K960', 100, 41, 220),
#  'Boys and Girls High School': ('16K455', 285, 94, 715),
#  'Brooklyn High School for Law and Technology': ('16K498', 151, 233, 1477),
#  'The Brooklyn Academy of Global Finance': ('16K688', 108, 59, 394),
#  'Nelson Mandela High School': ('16K765', 114, 25, 213),
#  'Pathways in Technology Early College High School (P-Tech)': ('17K122',
#   135,
#   192,
#   771),
#  'Academy for College Preparation and Career Exploration: A College Board School': ('17K382',
#   108,
#   135,
#   857),
#  'Academy of Hospitality and Tourism': ('17K408', 118, 82, 495),
#  'International High School at Prospect Heights': ('17K524', 108, 38, 207),
#  'The High School for Global Citizenship': ('17K528', 100, 46, 508),
#  'School for Human Rights, The': ('17K531', 120, 31, 301),
#  'High School for Youth and Community Development at Erasmus': ('17K537',
#   140,
#   106,
#   430),
#  'High School for Service & Learning at Erasmus': ('17K539', 108, 40, 272),
#  'Science, Technology and Research Early College High School at Erasmus': ('17K543',
#   130,
#   214,
#   810),
#  'High School for Public Service: Heroes of Tomorrow': ('17K546',
#   130,
#   84,
#   648),
#  'Brooklyn Academy of Science and the Environment': ('17K547', 108, 64, 436),
#  'Brooklyn School for Music & Theatre': ('17K548', 108, 99, 602),
#  'Medgar Evers College Preparatory School': ('17K590', 220, 716, 2237),
#  'Clara Barton High School': ('17K600', 434, 256, 1015),
#  'Aspirations Diploma Plus High School': ('17K646', 40, 2, 15),
#  'Brooklyn Institute for Liberal Arts': ('17K745', 150, 117, 666),
#  'Academy for Health Careers': ('17K751', 108, 62, 620),
#  'It Takes a Village Academy': ('18K563', 162, 53, 397),
#  'Brooklyn Community High School for Excellence and Equity': ('18K566',
#   75,
#   52,
#   371),
#  'Brooklyn Theatre Arts High School': ('18K567', 120, 76, 350),
#  'Kurt Hahn Expeditionary Learning School': ('18K569', 81, 30, 128),
#  'Victory Collegiate High School': ('18K576', 140, 36, 231),
#  'High School for Innovation in Advertising and Media': ('18K617',
#   81,
#   102,
#   417),
#  'Cultural Academy for the Arts and Sciences': ('18K629', 108, 59, 473),
#  'High School for Medical Professions': ('18K633', 108, 125, 676),
#  'Olympus Academy': ('18K635', 15, 2, 28),
#  'Academy for Conservation and the Environment': ('18K637', 120, 104, 814),
#  'Urban Action Academy': ('18K642', 107, 25, 151),
#  'Academy for Young Writers': ('19K404', 92, 98, 579),
#  'East New York Family Academy': ('19K409', 122, 221, 673),
#  'Spring Creek Community School': ('19K422', 71, 88, 458),
#  'FDNY - Captain Vernon A. Richard High School for Fire and Life Safety': ('19K502',
#   108,
#   67,
#   338),
#  'High School for Civil Rights': ('19K504', 108, 37, 417),
#  'Performing Arts and Technology High School': ('19K507', 125, 152, 1026),
#  'World Academy for Total Community Health High School': ('19K510',
#   68,
#   28,
#   242),
#  'Multicultural High School': ('19K583', 111, 47, 241),
#  'Transit Tech Career and Technical Education High School': ('19K615',
#   315,
#   241,
#   1113),
#  'Academy of Innovative Technology': ('19K618', 108, 188, 1107),
#  'Brooklyn Lab School': ('19K639', 102, 135, 759),
#  'Cypress Hills Collegiate Preparatory School': ('19K659', 99, 117, 530),
#  'W. H. Maxwell Career and Technical Education High School': ('19K660',
#   305,
#   124,
#   813),
#  'School for Classics High School': ('19K683', 108, 73, 242),
#  'The Urban Assembly School for Collaborative Healthcare': ('19K764',
#   81,
#   96,
#   455),
#  'The East New York Arts and Civics High School': ('19K953', 68, 28, 185),
#  'New Utrecht High School': ('20K445', 678, 1624, 4370),
#  'High School of Telecommunication Arts and Technology': ('20K485',
#   310,
#   1336,
#   3255),
#  'Fort Hamilton High School': ('20K490', 972, 1988, 4483),
#  'Franklin Delano Roosevelt High School': ('20K505', 758, 928, 3027),
#  'Urban Assembly School for Leadership and Empowerment': ('20K609',
#   100,
#   69,
#   280),
#  'International High School at Lafayette': ('21K337', 90, 91, 293),
#  'Rachel Carson High School for Coastal Studies': ('21K344', 148, 116, 427),
#  'High School of Sports Management': ('21K348', 176, 50, 325),
#  'Abraham Lincoln High School': ('21K410', 774, 583, 2069),
#  'Kingsborough Early College School': ('21K468', 110, 397, 1141),
#  'Edward R. Murrow High School': ('21K525', 934, 2498, 6007),
#  'John Dewey High School': ('21K540', 578, 655, 2311),
#  'Life Academy High School for Film and Music': ('21K559', 81, 21, 169),
#  'Leaders High School': ('21K572', 95, 89, 378),
#  'William E. Grady Career and Technical Education High School': ('21K620',
#   303,
#   207,
#   822),
#  'Brooklyn Studio Secondary School': ('21K690', 104, 296, 803),
#  'Liberation Diploma Plus': ('21K728', 30, 3, 4),
#  'Midwood High School': ('22K405', 910, 5459, 10400),
#  'James Madison High School': ('22K425', 860, 2916, 6362),
#  'Leon M. Goldstein High School for the Sciences': ('22K535', 255, 2186, 4085),
#  'Brooklyn College Academy': ('22K555', 160, 1008, 2863),
#  'Origins High School': ('22K611', 108, 99, 308),
#  'Professional Pathways High School': ('22K630', 30, 5, 8),
#  'Brooklyn Collegiate: A College Board School': ('23K493', 126, 154, 707),
#  'Frederick Douglass Academy VII High School': ('23K514', 108, 69, 472),
#  'Brooklyn Democracy Academy': ('23K643', 30, 2, 2),
#  'Eagle Academy for Young Men II': ('23K644', 92, 139, 439),
#  'Metropolitan Diploma Plus High School': ('23K647', 30, 3, 17),
#  'Teachers Preparatory High School': ('23K697', 85, 29, 189),
#  'International High School for Health Sciences': ('24Q236', 81, 98, 503),
#  'Academy of Finance and Enterprise': ('24Q264', 124, 585, 2132),
#  'High School of Applied Communication': ('24Q267', 136, 103, 559),
#  'Civic Leadership Academy': ('24Q293', 142, 318, 1163),
#  'Pan American International High School': ('24Q296', 108, 134, 440),
#  'Bard High School Early College Queens': ('24Q299', 125, 2900, 4916),
#  'Newtown High School': ('24Q455', 478, 268, 1180),
#  'Grover Cleveland High School': ('24Q485', 422, 358, 1381),
#  'Middle College High School at LaGuardia Community College': ('24Q520',
#   97,
#   542,
#   1611),
#  'International High School at LaGuardia Community College': ('24Q530',
#   119,
#   364,
#   877),
#  'High School for Arts and Business': ('24Q550', 191, 602, 2163),
#  'Robert F. Wagner, Jr. Secondary School for Arts and Technology': ('24Q560',
#   120,
#   338,
#   1475),
#  'Maspeth High School': ('24Q585', 270, 2127, 5196),
#  'Queens Technical High School': ('24Q600', 350, 1122, 3344),
#  'Aviation Career & Technical Education High School': ('24Q610',
#   530,
#   1576,
#   3540),
#  'Veritas Academy': ('25Q240', 130, 65, 401),
#  'Queens High School for Language Studies': ('25Q241', 108, 103, 397),
#  'Queens School of Inquiry, The': ('25Q252', 89, 205, 584),
#  'Flushing International High School': ('25Q263', 90, 162, 537),
#  'East-West School of International Studies': ('25Q281', 89, 295, 763),
#  'World Journalism Preparatory: A College Board School': ('25Q285',
#   81,
#   218,
#   492),
#  'John Bowne High School': ('25Q425', 604, 710, 2662),
#  'Flushing High School': ('25Q460', 563, 337, 1359),
#  'Townsend Harris High School': ('25Q525', 290, 5863, 8022),
#  'Queens Academy High School': ('25Q540', 20, 3, 6),
#  'Robert F. Kennedy Community High School': ('25Q670', 150, 242, 957),
#  'North Queens Community High School': ('25Q792', 15, 3, 9),
#  'Business Technology Early College High School': ('26Q315', 140, 238, 867),
#  'Benjamin N. Cardozo High School': ('26Q415', 669, 1710, 4164),
#  'Francis Lewis High School': ('26Q430', 933, 4080, 8017),
#  'Martin Van Buren High School': ('26Q435', 358, 236, 976),
#  'Bayside High School': ('26Q495', 893, 2799, 6156),
#  'Queens High School of Teaching, Liberal Arts and the Sciences': ('26Q566',
#   260,
#   239,
#   627),
#  'Frederick Douglass Academy VI High School': ('27Q260', 102, 52, 372),
#  'Channel View School for Research': ('27Q262', 214, 366, 772),
#  'Queens High School for Information, Research, and Technology': ('27Q302',
#   108,
#   218,
#   643),
#  'Robert H. Goddard High School of Communication Arts and Technology': ('27Q308',
#   140,
#   506,
#   1207),
#  'Academy of Medical Technology: A College Board School': ('27Q309',
#   105,
#   141,
#   527),
#  'Epic High School - South': ('27Q314', 95, 162, 562),
#  "Scholars' Academy": ('27Q323', 154, 600, 1161),
#  'Rockaway Park High School for Environmental Sustainability': ('27Q324',
#   108,
#   35,
#   173),
#  'Epic High School - North': ('27Q334', 70, 180, 674),
#  'Rockaway Collegiate High School': ('27Q351', 135, 46, 202),
#  'August Martin High School': ('27Q400', 250, 210, 939),
#  'Richmond Hill High School': ('27Q475', 368, 388, 1296),
#  'John Adams High School': ('27Q480', 672, 447, 2080),
#  'High School for Construction Trades, Engineering and Architecture': ('27Q650',
#   246,
#   1069,
#   2507),
#  'Metropolitan Expeditionary Learning School': ('28Q167', 119, 528, 1271),
#  'York Early College Academy': ('28Q284', 81, 558, 1492),
#  'Queens Collegiate: A College Board School': ('28Q310', 94, 79, 424),
#  'Hillside Arts & Letters Academy': ('28Q325', 108, 77, 381),
#  'High School for Community Leadership': ('28Q328', 130, 116, 516),
#  'Jamaica Gateway to the Sciences': ('28Q350', 130, 162, 846),
#  'Forest Hills High School': ('28Q440', 705, 2411, 6279),
#  'Hillcrest High School': ('28Q505', 730, 589, 2348),
#  'Thomas A. Edison Career and Technical Education High School': ('28Q620',
#   487,
#   2210,
#   5300),
#  'Queens Gateway to Health Sciences Secondary School': ('28Q680',
#   108,
#   405,
#   1216),
#  'Queens Metropolitan High School': ('28Q686', 230, 858, 2087),
#  'High School for Law Enforcement and Public Safety': ('28Q690',
#   166,
#   102,
#   401),
#  "Young Women's Leadership School, Queens": ('28Q896', 81, 106, 366),
#  'Institute for Health Professions at Cambria Heights': ('29Q243',
#   108,
#   74,
#   392),
#  'Queens Preparatory Academy': ('29Q248', 60, 44, 355),
#  'Pathways College Preparatory School: A College Board School': ('29Q259',
#   186,
#   135,
#   373),
#  'Excelsior Preparatory High School': ('29Q265', 108, 64, 358),
#  'George Washington Carver High School for the Sciences': ('29Q272',
#   93,
#   138,
#   598),
#  'Preparatory Academy for Writers: A College Board School': ('29Q283',
#   75,
#   36,
#   203),
#  'Benjamin Franklin High School for Finance & Information Technology': ('29Q313',
#   108,
#   128,
#   692),
#  'Cambria Heights Academy': ('29Q326', 81, 110, 554),
#  'Eagle Academy for Young Men III': ('29Q327', 75, 119, 300),
#  'Mathematics, Science Research and Technology Magnet High School': ('29Q492',
#   150,
#   84,
#   456),
#  'Health, Arts, Robotics, and Technology High School': ('29Q498',
#   196,
#   257,
#   1220),
#  'Energy Tech High School': ('30Q258', 109, 369, 1481),
#  "Young Women's Leadership School, Astoria": ('30Q286', 81, 199, 509),
#  'Academy for Careers in Television and Film': ('30Q301', 136, 460, 1518),
#  'Gotham Tech High School': ('30Q417', 100, 108, 460),
#  'William Cullen Bryant High School': ('30Q445', 488, 346, 1602),
#  'Long Island City High School': ('30Q450', 831, 405, 1488),
#  'Frank Sinatra School of the Arts High School': ('30Q501', 227, 1714, 3415),
#  'Information Technology High School': ('30Q502', 221, 227, 969),
#  'Newcomers High School': ('30Q555', 81, 128, 399),
#  'Academy of American Studies': ('30Q575', 170, 952, 2671),
#  'Baccalaureate School for Global Education': ('30Q580', 102, 1422, 2541),
#  'The Eagle Academy for Young Men of Staten Island': ('31R028', 81, 39, 102),
#  'CSI High School for International Studies': ('31R047', 127, 859, 1720),
#  'Gaynor McCown Expeditionary Learning School': ('31R064', 146, 353, 746),
#  'The Michael J. Petrides School': ('31R080', 127, 321, 748),
#  'New Dorp High School': ('31R440', 703, 970, 2138),
#  'Port Richmond High School': ('31R445', 613, 348, 1024),
#  'Curtis High School': ('31R450', 763, 710, 1505),
#  'Tottenville High School': ('31R455', 1188, 1703, 2503),
#  'Susan E. Wagner High School': ('31R460', 650, 987, 2177),
#  'Ralph R. McKee Career and Technical Education High School': ('31R600',
#   290,
#   211,
#   525),
#  'The Brooklyn School for Math and Research': ('32K168', 108, 75, 712),
#  'Academy for Excellence in Leadership': ('32K403', 108, 82, 614),
#  'EBC High School for Public Service - Bushwick': ('32K545', 126, 107, 534),
#  'The Brooklyn School for Social Justice': ('32K549', 115, 50, 357),
#  'The Academy of Urban Planning and Engineering': ('32K552', 113, 171, 922),
#  'All City Leadership Secondary School': ('32K554', 62, 291, 963),
#  'Bushwick Leaders High School for Academic Excellence': ('32K556',
#   100,
#   108,
#   561)}
